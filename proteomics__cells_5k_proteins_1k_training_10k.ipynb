# %% [markdown]
# # Single-cell Proteomics Synthetic Data Generation

# %% [markdown]
# The goal of this notebook is to simulate a crude single-cell proteomics datasets with a MNAR mechanism, and show that not-MIWAE performs better than MIWAE.

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

from MIWAE import MIWAE
from notMIWAE import notMIWAE
import trainer
import utils

np.random.seed(42)
# Out:
# 2023-11-21 00:15:51.471109: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-11-21 00:15:51.472728: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-21 00:15:51.496729: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-21 00:15:51.496756: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-21 00:15:51.496773: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-21 00:15:51.501450: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-21 00:15:51.501849: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-21 00:15:52.332862: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# Plotting functions for later.

# %%
def scatter_compare_individual_entries_panel(x_obs, x_miss, x_est_obs, x_est_miss):
    fig, axes = plt.subplots(ncols=2, figsize=(12, 5))
    
    ax = axes[0]
    ax.scatter(x_obs, x_est_obs, s=1, alpha=0.1)
    lims = [np.min([ax.get_xlim(), ax.get_ylim()]), np.max([ax.get_xlim(), ax.get_ylim()])]
    ax.plot(lims, lims, "--", c="k")

    mse = np.mean((x_obs - x_est_obs)**2)
    ax.text(0.05, 0.95, f"MSE: {mse:.2f}", transform=ax.transAxes, fontsize=12, verticalalignment="top", bbox=dict(facecolor="white", alpha=0.8))

    ax.set_xlabel("Observed")
    ax.set_ylabel("Imputed")
    ax.set_title("Observed")
    ax.grid(True)
    ax.set_axisbelow(True)

    ax = axes[1]
    ax.scatter(x_miss, x_est_miss, s=1, alpha=0.1)
    lims = [np.min([ax.get_xlim(), ax.get_ylim()]), np.max([ax.get_xlim(), ax.get_ylim()])]
    ax.plot(lims, lims, "--", c="k")

    mse = np.mean((x_miss - x_est_miss)**2)
    ax.text(0.05, 0.95, f"MSE: {mse:.2f}", transform=ax.transAxes, fontsize=12, verticalalignment="top", bbox=dict(facecolor="white", alpha=0.8))

    ax.set_xlabel("Observed")
    ax.set_ylabel("Imputed")
    ax.set_title("Missing")
    ax.grid(True)

# %%
def hist_compare_individual_entries(x_obs, x_miss, x_est_obs, x_est_miss):
    fig, axes = plt.subplots(ncols=2, figsize=(12, 5))

    x_min = np.min([np.min(x_obs), np.min(x_miss), np.min(x_est_obs), np.min(x_est_miss)])
    x_max = np.max([np.max(x_obs), np.max(x_miss), np.max(x_est_obs), np.max(x_est_miss)])

    ax = axes[0]
    ax.hist([x_obs, x_miss], color=["blue", "red"], bins=50, edgecolor="black", linewidth=1.2, stacked=True)
    ax.set_title("Data")
    ax.set_xlabel("x")
    ax.set_ylabel("(stacked) count")
    ax.set_xlim(x_min, x_max)
    ax.grid(True)
    ax.set_axisbelow(True)
    ax.legend(labels=["$x_{obs}$", "$x_{miss}$"], fontsize=12)

    ax = axes[1]
    ax.hist([x_est_obs, x_est_miss], color=["blue", "red"], bins=50, edgecolor="black", linewidth=1.2, stacked=True)
    ax.set_title("Model")
    ax.set_xlabel("x")
    ax.set_ylabel("(stacked) count")
    ax.set_xlim(x_min, x_max)
    ax.grid(True)
    ax.set_axisbelow(True)
    ax.legend(labels=["$x_{obs}$", "$x_{miss}$"], fontsize=12)

# %% [markdown]
# ## Data generation

# %% [markdown]
# Let's start by generating the synthetic data and visualizing it.

# %%
def logistic(x, k=1, x0=0, L=1):
    return L / (1 + np.exp(-k * (x - x0)))

def sigmoid(x):
    return 1 / (1 + np.exp(-x))


def simulate_data(n_cells=1000, n_proteins=5000):
    # all cells are from the same group (cell-type)
    # the cell type has some protein distribution / signature
    cell_type_signature = np.random.uniform(5, 12, n_proteins)

    # each cell is a bit different
    cell_variation = np.random.normal(0, 1, n_cells)

    intensity = cell_type_signature.reshape(1, -1) + cell_variation.reshape(-1, 1)

    # the measurement is noisy
    x = np.random.normal(intensity, 0.1)

    # MNAR mechanism: self-masking (x -> m)
    # entries with low intensity are less likely to be sampled
    #detection_prob = logistic(x, k=2, x0=7) # set x0=6, if you want less missing values
    detection_prob = sigmoid(2*x - 14)

    # sample using a bernoulli distribution
    mask = np.random.binomial(1, detection_prob)
    mask = mask.astype(bool)

    return x, detection_prob, mask

# %% [markdown]
# Let's simulate some data:

# %%
x_data, detection_prob, mask = simulate_data()

# %%
x_nan = x_data.copy()
x_nan[~mask] = np.nan

x_0 = x_data.copy()
x_0[~mask] = 0

# %%
print("Missing entries: {:.2f}%".format(np.isnan(x_nan).sum() / x_nan.size * 100))
# Out:
# Missing entries: 30.26%

# %% [markdown]
# Let's plot the data. "White" are the missing values.

# %%
fig, ax = plt.subplots(figsize=(8, 5))
sns.heatmap(x_nan, cmap="viridis", xticklabels=False, yticklabels=False, ax=ax)
ax.set_xlabel("Proteins")
ax.set_ylabel("Cells")
ax.set_title("Expression matrix with missing values")
# Out:
# Text(0.5, 1.0, 'Expression matrix with missing values')

# %% [markdown]
# Let's look at the missigness pattern entry-wise and protein-wise:

# %%
fig, axes = plt.subplots(ncols=2, figsize=(12, 5))

# plot entry intensity vs detection probability
ax = axes[0]

p_obs = detection_prob[mask]
x_obs = x_data[mask]

p_miss = detection_prob[~mask]
x_miss = x_data[~mask]

n = 5_000

ax.scatter(x_miss[:n], p_miss[:n], color="red", alpha=.1, s=4)
ax.scatter(x_obs[:n], p_obs[:n], color="blue", alpha=.1, s=4)
ax.set_title("entry intensity vs detection probability")
ax.set_xlabel("entry intensity")
ax.set_ylabel("detection probability")
ax.grid(True)
ax.set_axisbelow(True)

# plot the average protein intensity vs the detection proportion
ax = axes[1]
x_obs_protein = np.nanmean(x_nan, axis=0)
p_protein = 1 - np.nanmean(np.isnan(x_nan), axis=0)

ax.scatter(x_obs_protein, p_protein, color="blue", alpha=1, s=6)
ax.set_title("avg protein intensity vs detection proportion")
ax.set_xlabel("protein intensity")
ax.set_ylabel("detection proportion")
ax.grid(True)
ax.set_axisbelow(True)

# %%
fig, ax = plt.subplots(1, 1, figsize=(5, 5))

ax.hist([x_obs, x_miss], color=["blue", "red"], bins=50, edgecolor="black", linewidth=1.2, stacked=True)
ax.set_title("Data")
ax.set_xlabel("x")
ax.set_ylabel("(stacked) count")
ax.set_xlim(np.min(x_data), np.max(x_data))
ax.grid(True)
ax.set_axisbelow(True)
ax.legend(labels=["$x_{obs}$", "$x_{miss}$"], fontsize=12)

# %% [markdown]
# ## Model Comparison

# %% [markdown]
# Set the parameters for the models.

# %%
name = '/tmp/best'

# model specification
n_hidden = 128
n_samples = 20
n_latent = 16
out_dist='gauss'

# training
max_iter = 10_000
batch_size = 64

# imputation
L = 1000

# %% [markdown]
# Let's run.

# %%
N, D = x_data.shape

Xtrain = x_data.copy()
Xval_org = x_data.copy()

Xnan = x_nan.copy()
Xz = x_0.copy()
S = mask.copy()

Xval = x_nan.copy()
Xvalz = x_0.copy()

# %%
tf.compat.v1.disable_eager_execution()

# %% [markdown]
# ### MIWAE

# %%
miwae = MIWAE(Xnan, Xval, n_latent=n_latent, n_samples=n_samples, n_hidden=n_hidden, name=name, out_dist=out_dist)

# ---- do the training
trainer.train(miwae, batch_size=batch_size, max_iter=max_iter, name=name + 'miwae')

# ---- find imputation RMSE
RMSE_miwae, x_miwae = utils.imputationRMSE(miwae, Xtrain, Xz, Xnan, S, L)

np.save('x_miwae.npy', x_miwae)
# Out:
# Creating graph...
# 2023-11-21 00:16:01.674949: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:382] MLIR V1 optimization pass is not enabled
# Saving session...
# Saving session...
# 0/10000 updates, 0.48 s, 351221.97 train_loss, 338607.86 val_loss
# Saving session...
# 100/10000 updates, 14.85 s, 11361.70 train_loss, 10458.40 val_loss
# Saving session...
# 200/10000 updates, 14.91 s, 8376.37 train_loss, 8279.56 val_loss
# Saving session...
# 300/10000 updates, 14.95 s, 6957.28 train_loss, 7000.15 val_loss
# Saving session...
# 400/10000 updates, 14.61 s, 5373.74 train_loss, 5520.65 val_loss
# Saving session...
# 500/10000 updates, 14.72 s, 3112.71 train_loss, 3061.32 val_loss
# Saving session...
# 600/10000 updates, 13.14 s, 1548.07 train_loss, 1379.19 val_loss
# Saving session...
# 700/10000 updates, 14.31 s, -10.61 train_loss, -33.53 val_loss
# Saving session...
# 800/10000 updates, 14.15 s, -408.24 train_loss, -406.15 val_loss
# Saving session...
# 900/10000 updates, 14.38 s, -505.50 train_loss, -410.32 val_loss
# Saving session...
# 1000/10000 updates, 13.87 s, -830.65 train_loss, -678.64 val_loss
# 1100/10000 updates, 13.64 s, -479.14 train_loss, -586.81 val_loss
# 1200/10000 updates, 14.18 s, -1098.83 train_loss, -414.22 val_loss
# Saving session...
# 1300/10000 updates, 14.32 s, -1016.10 train_loss, -884.68 val_loss
# 1400/10000 updates, 12.72 s, -952.93 train_loss, -852.43 val_loss
# Saving session...
# 1500/10000 updates, 13.33 s, -962.10 train_loss, -910.68 val_loss
# 1600/10000 updates, 15.23 s, -472.54 train_loss, -827.06 val_loss
# 1700/10000 updates, 14.72 s, -1083.81 train_loss, -760.86 val_loss
# 1800/10000 updates, 14.71 s, -445.22 train_loss, -751.57 val_loss
# 1900/10000 updates, 14.41 s, -1056.85 train_loss, -824.89 val_loss
# 2000/10000 updates, 14.64 s, -900.56 train_loss, -830.06 val_loss
# 2100/10000 updates, 14.47 s, -388.46 train_loss, -497.33 val_loss
# 2200/10000 updates, 14.67 s, -593.92 train_loss, -703.46 val_loss
# 2300/10000 updates, 14.30 s, -625.02 train_loss, -387.79 val_loss
# 2400/10000 updates, 14.54 s, -847.32 train_loss, -816.60 val_loss
# 2500/10000 updates, 14.32 s, -963.64 train_loss, -886.72 val_loss
# Saving session...
# 2600/10000 updates, 14.53 s, -1207.63 train_loss, -919.50 val_loss
# 2700/10000 updates, 14.45 s, -894.47 train_loss, -861.64 val_loss
# 2800/10000 updates, 13.05 s, -1018.67 train_loss, -912.83 val_loss
# 2900/10000 updates, 13.10 s, -689.08 train_loss, -382.94 val_loss
# 3000/10000 updates, 14.64 s, -282.14 train_loss, -391.99 val_loss
# 3100/10000 updates, 13.50 s, -585.39 train_loss, -849.62 val_loss
# 3200/10000 updates, 13.40 s, -803.95 train_loss, -783.36 val_loss
# 3300/10000 updates, 13.38 s, -872.88 train_loss, -908.86 val_loss
# 3400/10000 updates, 13.31 s, -1162.93 train_loss, -783.52 val_loss
# 3500/10000 updates, 13.37 s, -780.23 train_loss, -888.49 val_loss
# 3600/10000 updates, 13.46 s, -1201.34 train_loss, -854.20 val_loss
# 3700/10000 updates, 13.41 s, -889.56 train_loss, -795.43 val_loss
# 3800/10000 updates, 13.48 s, -602.37 train_loss, -802.31 val_loss
# 3900/10000 updates, 13.52 s, -644.37 train_loss, -795.96 val_loss
# 4000/10000 updates, 13.77 s, -935.09 train_loss, -576.20 val_loss
# 4100/10000 updates, 13.33 s, -517.38 train_loss, -701.44 val_loss
# 4200/10000 updates, 14.15 s, -591.59 train_loss, -820.61 val_loss
# 4300/10000 updates, 13.76 s, -468.00 train_loss, -44.47 val_loss
# 4400/10000 updates, 13.82 s, -520.24 train_loss, -597.41 val_loss
# 4500/10000 updates, 13.92 s, -359.90 train_loss, -824.58 val_loss
# 4600/10000 updates, 13.70 s, 302.35 train_loss, -828.44 val_loss
# Saving session...
# 4700/10000 updates, 13.85 s, -681.23 train_loss, -925.19 val_loss
# 4800/10000 updates, 13.84 s, -658.55 train_loss, -383.32 val_loss
# 4900/10000 updates, 13.77 s, -426.87 train_loss, -733.77 val_loss
# 5000/10000 updates, 13.90 s, -259.73 train_loss, -660.15 val_loss
# 5100/10000 updates, 12.36 s, -826.72 train_loss, -805.01 val_loss
# 5200/10000 updates, 12.66 s, -1239.85 train_loss, -844.12 val_loss
# Saving session...
# 5300/10000 updates, 13.25 s, -1291.64 train_loss, -1022.91 val_loss
# 5400/10000 updates, 14.01 s, -798.10 train_loss, -819.31 val_loss
# 5500/10000 updates, 13.09 s, -980.50 train_loss, -939.54 val_loss
# 5600/10000 updates, 11.95 s, -535.08 train_loss, -575.99 val_loss
# 5700/10000 updates, 11.47 s, -475.17 train_loss, -130.82 val_loss
# 5800/10000 updates, 12.05 s, -957.55 train_loss, -789.11 val_loss
# 5900/10000 updates, 11.36 s, -632.87 train_loss, -418.80 val_loss
# 6000/10000 updates, 12.32 s, -95.44 train_loss, -407.66 val_loss
# 6100/10000 updates, 11.52 s, -483.51 train_loss, -886.47 val_loss
# 6200/10000 updates, 11.90 s, -1311.83 train_loss, -792.53 val_loss
# 6300/10000 updates, 11.87 s, -1076.61 train_loss, -952.30 val_loss
# 6400/10000 updates, 11.84 s, -1335.94 train_loss, -970.74 val_loss
# 6500/10000 updates, 12.49 s, -468.73 train_loss, -702.95 val_loss
# 6600/10000 updates, 11.65 s, -1230.83 train_loss, -990.33 val_loss
# 6700/10000 updates, 11.35 s, -1025.20 train_loss, -833.97 val_loss
# 6800/10000 updates, 13.23 s, -1007.60 train_loss, -802.08 val_loss
# 6900/10000 updates, 12.86 s, -535.04 train_loss, -141.85 val_loss
# 7000/10000 updates, 12.85 s, -857.57 train_loss, -462.31 val_loss
# 7100/10000 updates, 12.78 s, -737.57 train_loss, -958.21 val_loss
# 7200/10000 updates, 12.84 s, -495.16 train_loss, -843.36 val_loss
# 7300/10000 updates, 12.82 s, -471.94 train_loss, -843.26 val_loss
# 7400/10000 updates, 12.80 s, -1104.88 train_loss, -773.56 val_loss
# 7500/10000 updates, 12.82 s, -868.11 train_loss, -924.46 val_loss
# 7600/10000 updates, 12.66 s, -592.89 train_loss, -776.16 val_loss
# 7700/10000 updates, 13.22 s, -847.69 train_loss, -712.82 val_loss
# 7800/10000 updates, 13.20 s, -1240.41 train_loss, -972.21 val_loss
# 7900/10000 updates, 13.71 s, -1238.08 train_loss, -572.80 val_loss
# 8000/10000 updates, 14.11 s, -810.82 train_loss, -987.03 val_loss
# 8100/10000 updates, 13.34 s, -294.00 train_loss, -985.97 val_loss
# 8200/10000 updates, 12.14 s, -313.08 train_loss, -915.21 val_loss
# 8300/10000 updates, 11.94 s, -646.04 train_loss, -1010.47 val_loss
# 8400/10000 updates, 13.00 s, -482.82 train_loss, -775.78 val_loss
# 8500/10000 updates, 12.85 s, -1169.11 train_loss, -889.89 val_loss
# 8600/10000 updates, 11.65 s, -1021.76 train_loss, -882.58 val_loss
# 8700/10000 updates, 11.42 s, -1976.27 train_loss, -886.95 val_loss
# 8800/10000 updates, 11.38 s, -737.27 train_loss, -615.11 val_loss
# 8900/10000 updates, 11.39 s, -936.31 train_loss, -947.48 val_loss
# 9000/10000 updates, 11.42 s, -1375.27 train_loss, -902.88 val_loss
# 9100/10000 updates, 11.40 s, -927.83 train_loss, -962.67 val_loss
# 9200/10000 updates, 11.37 s, -1329.36 train_loss, -925.59 val_loss
# 9300/10000 updates, 11.41 s, -1249.30 train_loss, -833.52 val_loss
# 9400/10000 updates, 11.42 s, -384.40 train_loss, -863.23 val_loss
# 9500/10000 updates, 11.37 s, -729.57 train_loss, -832.83 val_loss
# 9600/10000 updates, 11.39 s, -715.87 train_loss, -858.63 val_loss
# Saving session...
# 9700/10000 updates, 11.40 s, -905.97 train_loss, -1066.92 val_loss
# 9800/10000 updates, 11.45 s, -1113.88 train_loss, -852.15 val_loss
# 9900/10000 updates, 11.43 s, -678.03 train_loss, -647.41 val_loss
# 0 / 1000
# 100 / 1000
# 200 / 1000
# 300 / 1000
# 400 / 1000
# 500 / 1000
# 600 / 1000
# 700 / 1000
# 800 / 1000
# 900 / 1000

# %%
print("RMSE: {:.3f}".format(RMSE_miwae))
# Out:
# RMSE: 0.295

# %%
x_miwae = np.load('x_miwae.npy')

# %%
x_obs = x_data[mask]
x_miss = x_data[~mask]

x_est = x_miwae

x_est_obs = x_est[mask]
x_est_miss = x_est[~mask]

# %%
scatter_compare_individual_entries_panel(x_obs, x_miss, x_est_obs, x_est_miss)

# %%
hist_compare_individual_entries(x_obs, x_miss, x_est_obs, x_est_miss)

# %% [markdown]
# ### not-MIWAE (self-masking)

# %%
notmiwae = notMIWAE(Xnan, Xval, n_latent=n_latent, n_samples=n_samples, n_hidden=n_hidden, name=name, out_dist=out_dist, mechanism_weight=0.1, missing_process='selfmasking')

# ---- do the training
trainer.train(notmiwae, batch_size=batch_size, max_iter=max_iter, name=name + 'notmiwae')

# ---- find imputation RMSE
RMSE_notmiwae, x_notmiwae = utils.not_imputationRMSE(notmiwae, Xtrain, Xz, Xnan, S, L)

np.save('x_notmiwae.npy', x_notmiwae)
# Out:
# Creating graph...
# Saving session...
# Saving session...
# 0/10000 updates, 0.33 s, 352148.31 train_loss, 338935.78 val_loss
# Saving session...
# 100/10000 updates, 21.51 s, 10740.81 train_loss, 11086.08 val_loss
# Saving session...
# 200/10000 updates, 19.91 s, 8973.59 train_loss, 8878.34 val_loss
# Saving session...
# 300/10000 updates, 19.71 s, 7460.65 train_loss, 7548.40 val_loss
# Saving session...
# 400/10000 updates, 19.70 s, 5987.38 train_loss, 5911.55 val_loss
# Saving session...
# 500/10000 updates, 20.25 s, 3643.78 train_loss, 3618.73 val_loss
# Saving session...
# 600/10000 updates, 20.00 s, 2528.90 train_loss, 1616.03 val_loss
# Saving session...
# 700/10000 updates, 20.04 s, 311.04 train_loss, 472.52 val_loss
# Saving session...
# 800/10000 updates, 19.96 s, -145.48 train_loss, 193.93 val_loss
# Saving session...
# 900/10000 updates, 19.98 s, -1090.01 train_loss, -433.85 val_loss
# 1000/10000 updates, 19.99 s, 517.63 train_loss, -77.22 val_loss
# 1100/10000 updates, 19.93 s, -363.16 train_loss, -330.27 val_loss
# 1200/10000 updates, 19.89 s, -473.81 train_loss, -275.13 val_loss
# 1300/10000 updates, 19.90 s, 73.24 train_loss, -370.48 val_loss
# Saving session...
# 1400/10000 updates, 19.90 s, -425.98 train_loss, -494.83 val_loss
# 1500/10000 updates, 20.00 s, -390.64 train_loss, -476.27 val_loss
# 1600/10000 updates, 19.88 s, -535.52 train_loss, -339.50 val_loss
# 1700/10000 updates, 19.90 s, -1014.71 train_loss, -431.86 val_loss
# Saving session...
# 1800/10000 updates, 19.89 s, -961.55 train_loss, -516.74 val_loss
# 1900/10000 updates, 20.01 s, 1700.46 train_loss, -349.27 val_loss
# 2000/10000 updates, 20.27 s, -931.22 train_loss, -359.42 val_loss
# 2100/10000 updates, 19.76 s, -47.72 train_loss, -503.36 val_loss
# 2200/10000 updates, 19.76 s, -772.81 train_loss, -477.91 val_loss
# Saving session...
# 2300/10000 updates, 19.86 s, -470.77 train_loss, -531.41 val_loss
# 2400/10000 updates, 19.86 s, -256.44 train_loss, -485.72 val_loss
# 2500/10000 updates, 19.75 s, -449.71 train_loss, -215.26 val_loss
# Saving session...
# 2600/10000 updates, 19.81 s, -1130.56 train_loss, -588.89 val_loss
# Saving session...
# 2700/10000 updates, 19.86 s, -658.85 train_loss, -661.07 val_loss
# 2800/10000 updates, 19.80 s, -917.22 train_loss, -390.97 val_loss
# Saving session...
# 2900/10000 updates, 19.79 s, -962.80 train_loss, -704.23 val_loss
# Saving session...
# 3000/10000 updates, 19.86 s, -357.58 train_loss, -708.43 val_loss
# 3100/10000 updates, 19.88 s, 223.06 train_loss, -547.24 val_loss
# 3200/10000 updates, 19.73 s, -582.73 train_loss, -452.91 val_loss
# 3300/10000 updates, 19.70 s, -815.58 train_loss, -570.49 val_loss
# 3400/10000 updates, 19.70 s, -1103.13 train_loss, -387.14 val_loss
# 3500/10000 updates, 19.84 s, -817.84 train_loss, -566.35 val_loss
# 3600/10000 updates, 19.77 s, -1205.46 train_loss, -461.03 val_loss
# 3700/10000 updates, 19.77 s, -542.07 train_loss, -628.67 val_loss
# 3800/10000 updates, 19.72 s, -827.68 train_loss, -591.83 val_loss
# Saving session...
# 3900/10000 updates, 19.67 s, -446.11 train_loss, -824.95 val_loss
# 4000/10000 updates, 19.86 s, -556.99 train_loss, -709.84 val_loss
# 4100/10000 updates, 19.72 s, -105.48 train_loss, -712.43 val_loss
# 4200/10000 updates, 19.74 s, -639.99 train_loss, -651.12 val_loss
# 4300/10000 updates, 19.68 s, -918.74 train_loss, -690.27 val_loss
# 4400/10000 updates, 19.72 s, -598.24 train_loss, -773.38 val_loss
# 4500/10000 updates, 19.70 s, -934.99 train_loss, -443.39 val_loss
# 4600/10000 updates, 19.70 s, -261.17 train_loss, -283.33 val_loss
# Saving session...
# 4700/10000 updates, 19.76 s, -707.11 train_loss, -835.22 val_loss
# 4800/10000 updates, 19.76 s, -213.08 train_loss, -576.65 val_loss
# 4900/10000 updates, 19.66 s, -740.36 train_loss, -533.58 val_loss
# 5000/10000 updates, 19.70 s, -1215.16 train_loss, -754.48 val_loss
# 5100/10000 updates, 19.67 s, 94.88 train_loss, -472.68 val_loss
# 5200/10000 updates, 19.71 s, -659.96 train_loss, -667.37 val_loss
# 5300/10000 updates, 19.67 s, -638.20 train_loss, -499.26 val_loss
# 5400/10000 updates, 19.67 s, -53.63 train_loss, -665.92 val_loss
# 5500/10000 updates, 19.66 s, -728.76 train_loss, -680.47 val_loss
# 5600/10000 updates, 19.73 s, -913.11 train_loss, -562.34 val_loss
# 5700/10000 updates, 19.69 s, -106.86 train_loss, -121.51 val_loss
# 5800/10000 updates, 19.64 s, -428.00 train_loss, -453.11 val_loss
# 5900/10000 updates, 19.69 s, -114.99 train_loss, -683.76 val_loss
# 6000/10000 updates, 19.64 s, -902.28 train_loss, -439.38 val_loss
# 6100/10000 updates, 19.59 s, 1178.91 train_loss, 639.14 val_loss
# 6200/10000 updates, 20.05 s, -239.45 train_loss, -742.95 val_loss
# 6300/10000 updates, 19.64 s, 1117.01 train_loss, -656.75 val_loss
# 6400/10000 updates, 19.60 s, -698.28 train_loss, -601.83 val_loss
# 6500/10000 updates, 19.58 s, -976.69 train_loss, -645.93 val_loss
# 6600/10000 updates, 19.60 s, -1.93 train_loss, -616.22 val_loss
# 6700/10000 updates, 19.63 s, -313.01 train_loss, -598.69 val_loss
# 6800/10000 updates, 19.58 s, -547.49 train_loss, -552.10 val_loss
# 6900/10000 updates, 19.60 s, -360.89 train_loss, -419.59 val_loss
# 7000/10000 updates, 19.60 s, -868.77 train_loss, -653.66 val_loss
# 7100/10000 updates, 19.66 s, -938.40 train_loss, -685.26 val_loss
# 7200/10000 updates, 19.63 s, -963.86 train_loss, -693.10 val_loss
# Saving session...
# 7300/10000 updates, 19.55 s, -959.95 train_loss, -835.28 val_loss
# 7400/10000 updates, 19.70 s, -698.67 train_loss, -455.22 val_loss
# 7500/10000 updates, 19.64 s, 389.62 train_loss, -737.59 val_loss
# 7600/10000 updates, 19.66 s, -868.01 train_loss, -640.84 val_loss
# 7700/10000 updates, 19.61 s, -1298.31 train_loss, -511.24 val_loss
# 7800/10000 updates, 19.58 s, -524.91 train_loss, -545.09 val_loss
# 7900/10000 updates, 19.58 s, -878.60 train_loss, -677.37 val_loss
# 8000/10000 updates, 19.60 s, -797.82 train_loss, -575.91 val_loss
# 8100/10000 updates, 19.68 s, -701.75 train_loss, -713.15 val_loss
# 8200/10000 updates, 19.58 s, -1020.77 train_loss, -793.39 val_loss
# 8300/10000 updates, 19.62 s, -511.26 train_loss, -506.16 val_loss
# 8400/10000 updates, 19.66 s, -677.96 train_loss, -508.92 val_loss
# 8500/10000 updates, 19.59 s, -813.09 train_loss, -644.42 val_loss
# 8600/10000 updates, 19.58 s, -618.42 train_loss, -610.46 val_loss
# Saving session...
# 8700/10000 updates, 20.25 s, -1142.26 train_loss, -876.16 val_loss
# 8800/10000 updates, 23.52 s, -950.84 train_loss, -720.23 val_loss
# 8900/10000 updates, 22.79 s, -687.54 train_loss, -570.50 val_loss
# 9000/10000 updates, 19.87 s, -999.30 train_loss, -799.97 val_loss
# 9100/10000 updates, 22.22 s, -425.04 train_loss, -714.27 val_loss
# 9200/10000 updates, 19.18 s, -594.15 train_loss, -391.68 val_loss
# 9300/10000 updates, 19.02 s, -667.09 train_loss, -805.55 val_loss
# 9400/10000 updates, 18.98 s, -381.01 train_loss, -778.53 val_loss
# 9500/10000 updates, 18.99 s, -704.13 train_loss, -149.14 val_loss
# 9600/10000 updates, 19.00 s, -504.13 train_loss, -483.94 val_loss
# 9700/10000 updates, 19.02 s, -731.87 train_loss, -720.57 val_loss
# 9800/10000 updates, 19.01 s, -856.57 train_loss, -854.29 val_loss
# 9900/10000 updates, 19.00 s, -414.68 train_loss, -555.58 val_loss
# 0 / 1000
# 100 / 1000
# 200 / 1000
# 300 / 1000
# 400 / 1000
# 500 / 1000
# 600 / 1000
# 700 / 1000
# 800 / 1000
# 900 / 1000

# %%
print("RMSE: {:.3f}".format(RMSE_notmiwae))
# Out:
# RMSE: 0.193

# %%
x_notmiwae = np.load('x_notmiwae.npy')

# %%
x_obs = x_data[mask]
x_miss = x_data[~mask]

x_est = x_notmiwae

x_est_obs = x_est[mask]
x_est_miss = x_est[~mask]

# %%
scatter_compare_individual_entries_panel(x_obs, x_miss, x_est_obs, x_est_miss)

# %%
hist_compare_individual_entries(x_obs, x_miss, x_est_obs, x_est_miss)

# %%
W, b = notmiwae.sess.run([notmiwae.W, notmiwae.b])

# %%
fig, ax = plt.subplots(ncols=1, figsize=(6, 5))

p_obs = detection_prob[mask]
x_obs = x_data[mask]

p_miss = detection_prob[~mask]
x_miss = x_data[~mask]

n = 5_000

ax.scatter(x_miss[:n], p_miss[:n], color="red", alpha=.1, s=2)
ax.scatter(x_obs[:n], p_obs[:n], color="blue", alpha=.1, s=2)
ax.set_title("entry intensity vs detection probability")
ax.set_xlabel("entry intensity")
ax.set_ylabel("detection probability")
ax.grid(True)
ax.set_axisbelow(True)

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

for n in range(W.shape[-1]):
    xs = np.linspace(0, 18, 100)
    logit = W[0, 0, n] * xs + b[0, 0, n]
    ys = sigmoid(logit)
    ax.plot(xs, ys, color="black", alpha=.3, linewidth=4)

# %% [markdown]
# ### not-MIWAE (self-masking known)

# %%
notmiwae = notMIWAE(Xnan, Xval, n_latent=n_latent, n_samples=n_samples, n_hidden=n_hidden, name=name, out_dist=out_dist, mechanism_weight=0.1, missing_process='selfmasking_known')

# ---- do the training
trainer.train(notmiwae, batch_size=batch_size, max_iter=max_iter, name=name + 'notmiwae')

# ---- find imputation RMSE
RMSE_notmiwae, x_notmiwae = utils.not_imputationRMSE(notmiwae, Xtrain, Xz, Xnan, S, L)

np.save('x_notmiwae.npy', x_notmiwae)
# Out:
# Creating graph...
# Saving session...
# Saving session...
# 0/10000 updates, 0.31 s, 351380.31 train_loss, 333207.44 val_loss
# Saving session...
# 100/10000 updates, 18.70 s, 11199.64 train_loss, 10725.04 val_loss
# Saving session...
# 200/10000 updates, 18.95 s, 8326.81 train_loss, 8536.04 val_loss
# Saving session...
# 300/10000 updates, 18.76 s, 7080.71 train_loss, 7133.41 val_loss
# Saving session...
# 400/10000 updates, 18.68 s, 5143.88 train_loss, 5262.33 val_loss
# Saving session...
# 500/10000 updates, 18.71 s, 2902.27 train_loss, 2885.95 val_loss
# Saving session...
# 600/10000 updates, 18.65 s, 785.21 train_loss, 1143.35 val_loss
# Saving session...
# 700/10000 updates, 18.64 s, 1289.56 train_loss, 190.47 val_loss
# Saving session...
# 800/10000 updates, 22.41 s, -181.27 train_loss, -126.46 val_loss
# Saving session...
# 900/10000 updates, 23.21 s, 78.09 train_loss, -368.53 val_loss
# 1000/10000 updates, 23.91 s, 107.76 train_loss, -184.76 val_loss
# Saving session...
# 1100/10000 updates, 23.80 s, -725.74 train_loss, -513.09 val_loss
# 1200/10000 updates, 21.86 s, -540.05 train_loss, -488.26 val_loss
# Saving session...
# 1300/10000 updates, 25.24 s, -733.91 train_loss, -573.93 val_loss
# 1400/10000 updates, 25.58 s, -721.28 train_loss, -457.04 val_loss
# Saving session...
# 1500/10000 updates, 24.86 s, 413.73 train_loss, -630.45 val_loss
# Saving session...
# 1600/10000 updates, 25.09 s, -973.62 train_loss, -777.90 val_loss
# 1700/10000 updates, 25.08 s, -467.93 train_loss, -567.07 val_loss
# 1800/10000 updates, 24.71 s, -516.53 train_loss, -685.30 val_loss
# 1900/10000 updates, 25.19 s, -1179.90 train_loss, -460.66 val_loss
# 2000/10000 updates, 25.36 s, -723.08 train_loss, -636.44 val_loss
# Saving session...
# 2100/10000 updates, 25.18 s, -1045.78 train_loss, -793.00 val_loss
# 2200/10000 updates, 25.32 s, 2362.62 train_loss, -345.72 val_loss
# 2300/10000 updates, 24.83 s, -658.55 train_loss, -724.92 val_loss
# Saving session...
# 2400/10000 updates, 24.90 s, -712.91 train_loss, -804.91 val_loss
# 2500/10000 updates, 25.28 s, 736.68 train_loss, -781.32 val_loss
# 2600/10000 updates, 24.78 s, -578.97 train_loss, -639.76 val_loss
# Saving session...
# 2700/10000 updates, 22.59 s, -975.24 train_loss, -805.23 val_loss
# Saving session...
# 2800/10000 updates, 24.14 s, -386.47 train_loss, -871.64 val_loss
# 2900/10000 updates, 23.01 s, 65.32 train_loss, -629.51 val_loss
# Saving session...
# 3000/10000 updates, 22.77 s, -522.16 train_loss, -928.52 val_loss
# 3100/10000 updates, 23.24 s, -567.52 train_loss, -680.73 val_loss
# 3200/10000 updates, 21.77 s, -709.87 train_loss, -352.46 val_loss
# 3300/10000 updates, 21.32 s, -902.04 train_loss, -766.17 val_loss
# 3400/10000 updates, 22.77 s, -274.06 train_loss, -521.82 val_loss
# 3500/10000 updates, 22.86 s, -479.25 train_loss, -431.46 val_loss
# 3600/10000 updates, 22.92 s, -1273.26 train_loss, -692.39 val_loss
# 3700/10000 updates, 21.86 s, -691.57 train_loss, -848.64 val_loss
# 3800/10000 updates, 23.25 s, -474.20 train_loss, -770.00 val_loss
# 3900/10000 updates, 23.70 s, -683.87 train_loss, -762.43 val_loss
# 4000/10000 updates, 22.32 s, -309.13 train_loss, 21.06 val_loss
# 4100/10000 updates, 22.74 s, -372.23 train_loss, -489.18 val_loss
# 4200/10000 updates, 22.76 s, -214.46 train_loss, -301.58 val_loss
# 4300/10000 updates, 23.41 s, -44.51 train_loss, -315.63 val_loss
# 4400/10000 updates, 21.25 s, -981.74 train_loss, -791.58 val_loss
# 4500/10000 updates, 20.59 s, -470.60 train_loss, -630.41 val_loss
# 4600/10000 updates, 20.40 s, -742.00 train_loss, -684.83 val_loss
# 4700/10000 updates, 21.42 s, -880.05 train_loss, -827.17 val_loss
# 4800/10000 updates, 22.72 s, -1387.63 train_loss, -737.26 val_loss
# 4900/10000 updates, 22.52 s, -359.03 train_loss, -508.66 val_loss
# 5000/10000 updates, 21.17 s, -1077.99 train_loss, -613.45 val_loss
# 5100/10000 updates, 21.55 s, -996.64 train_loss, -777.19 val_loss
# 5200/10000 updates, 22.43 s, -1161.44 train_loss, -684.54 val_loss
# 5300/10000 updates, 22.11 s, -920.79 train_loss, -475.84 val_loss
# 5400/10000 updates, 22.77 s, -404.91 train_loss, -362.92 val_loss
# 5500/10000 updates, 23.44 s, -898.81 train_loss, -860.50 val_loss
# 5600/10000 updates, 23.52 s, -431.33 train_loss, -595.94 val_loss
# 5700/10000 updates, 22.78 s, -49.03 train_loss, -405.40 val_loss
# 5800/10000 updates, 22.75 s, -1108.61 train_loss, -846.85 val_loss
# 5900/10000 updates, 22.65 s, -366.84 train_loss, -705.69 val_loss
# 6000/10000 updates, 23.24 s, -489.90 train_loss, -722.06 val_loss
# 6100/10000 updates, 21.16 s, 1054.46 train_loss, -423.70 val_loss
# 6200/10000 updates, 20.51 s, -989.88 train_loss, -727.83 val_loss
# 6300/10000 updates, 23.21 s, -626.93 train_loss, -813.91 val_loss
# 6400/10000 updates, 22.38 s, -352.31 train_loss, -477.21 val_loss
# 6500/10000 updates, 22.75 s, -1083.27 train_loss, -432.44 val_loss
# 6600/10000 updates, 22.43 s, -665.24 train_loss, -677.74 val_loss
# 6700/10000 updates, 22.28 s, -613.16 train_loss, -821.93 val_loss
# 6800/10000 updates, 22.93 s, -924.01 train_loss, -854.60 val_loss
# 6900/10000 updates, 21.68 s, -692.96 train_loss, -651.06 val_loss
# 7000/10000 updates, 21.56 s, -638.90 train_loss, -582.92 val_loss
# 7100/10000 updates, 22.07 s, -680.17 train_loss, -681.10 val_loss
# 7200/10000 updates, 22.71 s, -1095.60 train_loss, -613.55 val_loss
# 7300/10000 updates, 23.28 s, -610.52 train_loss, -535.66 val_loss
# 7400/10000 updates, 22.92 s, 784.66 train_loss, 735.62 val_loss
# 7500/10000 updates, 22.93 s, -756.11 train_loss, -372.16 val_loss
# 7600/10000 updates, 22.89 s, -196.28 train_loss, -326.46 val_loss
# 7700/10000 updates, 22.97 s, -903.84 train_loss, -548.58 val_loss
# 7800/10000 updates, 22.99 s, -1111.50 train_loss, -433.15 val_loss
# 7900/10000 updates, 22.79 s, -1087.02 train_loss, -567.42 val_loss
# 8000/10000 updates, 22.85 s, -587.13 train_loss, -826.98 val_loss
# 8100/10000 updates, 22.97 s, -884.86 train_loss, -465.27 val_loss
# 8200/10000 updates, 22.94 s, -633.29 train_loss, -528.78 val_loss
# 8300/10000 updates, 22.83 s, -997.21 train_loss, -679.40 val_loss
# 8400/10000 updates, 22.84 s, -656.78 train_loss, -480.12 val_loss
# 8500/10000 updates, 23.00 s, -939.09 train_loss, -757.22 val_loss
# 8600/10000 updates, 22.85 s, -465.59 train_loss, -760.21 val_loss
# 8700/10000 updates, 23.19 s, -475.74 train_loss, -645.22 val_loss
# 8800/10000 updates, 23.72 s, -785.74 train_loss, -727.12 val_loss
# 8900/10000 updates, 24.45 s, -744.49 train_loss, -867.57 val_loss
# 9000/10000 updates, 24.41 s, -693.25 train_loss, -798.39 val_loss
# 9100/10000 updates, 24.39 s, -344.21 train_loss, -790.31 val_loss
# 9200/10000 updates, 24.22 s, -448.15 train_loss, -445.84 val_loss
# 9300/10000 updates, 24.23 s, -556.42 train_loss, -738.54 val_loss
# 9400/10000 updates, 24.15 s, -685.47 train_loss, -757.68 val_loss
# 9500/10000 updates, 24.23 s, -1206.40 train_loss, -640.90 val_loss
# 9600/10000 updates, 24.30 s, -504.49 train_loss, -427.08 val_loss
# 9700/10000 updates, 24.08 s, -947.83 train_loss, -909.28 val_loss
# 9800/10000 updates, 24.34 s, -809.72 train_loss, -849.11 val_loss
# 9900/10000 updates, 24.24 s, -1171.92 train_loss, -502.03 val_loss
# 0 / 1000
# 100 / 1000
# 200 / 1000
# 300 / 1000
# 400 / 1000
# 500 / 1000
# 600 / 1000
# 700 / 1000
# 800 / 1000
# 900 / 1000

# %%
print("RMSE: {:.3f}".format(RMSE_notmiwae))
# Out:
# RMSE: 0.257

# %%
x_notmiwae = np.load('x_notmiwae.npy')

# %%
x_obs = x_data[mask]
x_miss = x_data[~mask]

x_est = x_notmiwae

x_est_obs = x_est[mask]
x_est_miss = x_est[~mask]

# %%
scatter_compare_individual_entries_panel(x_obs, x_miss, x_est_obs, x_est_miss)

# %%
hist_compare_individual_entries(x_obs, x_miss, x_est_obs, x_est_miss)
