# %% [markdown]
# # Single-cell Proteomics Synthetic Data Generation

# %% [markdown]
# The goal of this notebook is to simulate a crude single-cell proteomics datasets with a MNAR mechanism, and show that not-MIWAE performs better than MIWAE.

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

from MIWAE import MIWAE
from notMIWAE import notMIWAE
import trainer
import utils

np.random.seed(42)
# Out:
# 2023-11-21 18:07:51.850805: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-11-21 18:07:51.852610: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-21 18:07:51.877031: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-21 18:07:51.877055: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-21 18:07:51.877078: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-21 18:07:51.882121: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-21 18:07:51.882475: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-21 18:07:52.533980: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# Plotting functions for later.

# %%
def scatter_compare_individual_entries_panel(x_obs, x_miss, x_est_obs, x_est_miss):
    fig, axes = plt.subplots(ncols=2, figsize=(12, 5))
    
    ax = axes[0]
    ax.scatter(x_obs, x_est_obs, s=1, alpha=0.1)
    lims = [np.min([ax.get_xlim(), ax.get_ylim()]), np.max([ax.get_xlim(), ax.get_ylim()])]
    ax.plot(lims, lims, "--", c="k")

    mse = np.mean((x_obs - x_est_obs)**2)
    ax.text(0.05, 0.95, f"MSE: {mse:.2f}", transform=ax.transAxes, fontsize=12, verticalalignment="top", bbox=dict(facecolor="white", alpha=0.8))

    ax.set_xlabel("Observed")
    ax.set_ylabel("Imputed")
    ax.set_title("Observed")
    ax.grid(True)
    ax.set_axisbelow(True)

    ax = axes[1]
    ax.scatter(x_miss, x_est_miss, s=1, alpha=0.1)
    lims = [np.min([ax.get_xlim(), ax.get_ylim()]), np.max([ax.get_xlim(), ax.get_ylim()])]
    ax.plot(lims, lims, "--", c="k")

    mse = np.mean((x_miss - x_est_miss)**2)
    ax.text(0.05, 0.95, f"MSE: {mse:.2f}", transform=ax.transAxes, fontsize=12, verticalalignment="top", bbox=dict(facecolor="white", alpha=0.8))

    ax.set_xlabel("Observed")
    ax.set_ylabel("Imputed")
    ax.set_title("Missing")
    ax.grid(True)

# %%
def hist_compare_individual_entries(x_obs, x_miss, x_est_obs, x_est_miss):
    fig, axes = plt.subplots(ncols=2, figsize=(12, 5))

    x_min = np.min([np.min(x_obs), np.min(x_miss), np.min(x_est_obs), np.min(x_est_miss)])
    x_max = np.max([np.max(x_obs), np.max(x_miss), np.max(x_est_obs), np.max(x_est_miss)])

    ax = axes[0]
    ax.hist([x_obs, x_miss], color=["blue", "red"], bins=50, edgecolor="black", linewidth=1.2, stacked=True)
    ax.set_title("Data")
    ax.set_xlabel("x")
    ax.set_ylabel("(stacked) count")
    ax.set_xlim(x_min, x_max)
    ax.grid(True)
    ax.set_axisbelow(True)
    ax.legend(labels=["$x_{obs}$", "$x_{miss}$"], fontsize=12)

    ax = axes[1]
    ax.hist([x_est_obs, x_est_miss], color=["blue", "red"], bins=50, edgecolor="black", linewidth=1.2, stacked=True)
    ax.set_title("Model")
    ax.set_xlabel("x")
    ax.set_ylabel("(stacked) count")
    ax.set_xlim(x_min, x_max)
    ax.grid(True)
    ax.set_axisbelow(True)
    ax.legend(labels=["$x_{obs}$", "$x_{miss}$"], fontsize=12)

# %% [markdown]
# ## Data generation

# %% [markdown]
# Let's start by generating the synthetic data and visualizing it.

# %%
def logistic(x, k=1, x0=0, L=1):
    return L / (1 + np.exp(-k * (x - x0)))

def sigmoid(x):
    return 1 / (1 + np.exp(-x))


def simulate_data(n_cells=1000, n_proteins=5000):
    # all cells are from the same group (cell-type)
    # the cell type has some protein distribution / signature
    cell_type_signature = np.random.uniform(5, 12, n_proteins)

    # each cell is a bit different
    cell_variation = np.random.normal(0, 1, n_cells)

    intensity = cell_type_signature.reshape(1, -1) + cell_variation.reshape(-1, 1)

    # the measurement is noisy
    x = np.random.normal(intensity, 0.1)

    # MNAR mechanism: self-masking (x -> m)
    # entries with low intensity are less likely to be sampled
    #detection_prob = logistic(x, k=2, x0=7) # set x0=6, if you want less missing values
    detection_prob = sigmoid(2*x - 14)

    # sample using a bernoulli distribution
    mask = np.random.binomial(1, detection_prob)
    mask = mask.astype(bool)

    return x, detection_prob, mask

# %% [markdown]
# Let's simulate some data:

# %%
x_data, detection_prob, mask = simulate_data()

# %%
x_nan = x_data.copy()
x_nan[~mask] = np.nan

x_0 = x_data.copy()
x_0[~mask] = 0

# %%
print("Missing entries: {:.2f}%".format(np.isnan(x_nan).sum() / x_nan.size * 100))
# Out:
# Missing entries: 30.26%

# %% [markdown]
# Let's plot the data. "White" are the missing values.

# %%
fig, ax = plt.subplots(figsize=(8, 5))
sns.heatmap(x_nan, cmap="viridis", xticklabels=False, yticklabels=False, ax=ax)
ax.set_xlabel("Proteins")
ax.set_ylabel("Cells")
ax.set_title("Expression matrix with missing values")
# Out:
# Text(0.5, 1.0, 'Expression matrix with missing values')

# %% [markdown]
# Let's look at the missigness pattern entry-wise and protein-wise:

# %%
fig, axes = plt.subplots(ncols=2, figsize=(12, 5))

# plot entry intensity vs detection probability
ax = axes[0]

p_obs = detection_prob[mask]
x_obs = x_data[mask]

p_miss = detection_prob[~mask]
x_miss = x_data[~mask]

n = 5_000

ax.scatter(x_miss[:n], p_miss[:n], color="red", alpha=.1, s=4)
ax.scatter(x_obs[:n], p_obs[:n], color="blue", alpha=.1, s=4)
ax.set_title("entry intensity vs detection probability")
ax.set_xlabel("entry intensity")
ax.set_ylabel("detection probability")
ax.grid(True)
ax.set_axisbelow(True)

# plot the average protein intensity vs the detection proportion
ax = axes[1]
x_obs_protein = np.nanmean(x_nan, axis=0)
p_protein = 1 - np.nanmean(np.isnan(x_nan), axis=0)

ax.scatter(x_obs_protein, p_protein, color="blue", alpha=1, s=6)
ax.set_title("avg protein intensity vs detection proportion")
ax.set_xlabel("protein intensity")
ax.set_ylabel("detection proportion")
ax.grid(True)
ax.set_axisbelow(True)

# %%
fig, ax = plt.subplots(1, 1, figsize=(5, 5))

ax.hist([x_obs, x_miss], color=["blue", "red"], bins=50, edgecolor="black", linewidth=1.2, stacked=True)
ax.set_title("Data")
ax.set_xlabel("x")
ax.set_ylabel("(stacked) count")
ax.set_xlim(np.min(x_data), np.max(x_data))
ax.grid(True)
ax.set_axisbelow(True)
ax.legend(labels=["$x_{obs}$", "$x_{miss}$"], fontsize=12)

# %% [markdown]
# ## Model Comparison

# %% [markdown]
# Set the parameters for the models.

# %%
name = '/tmp/best'

# model specification
n_hidden = 128
n_samples = 20
n_latent = 16
out_dist='gauss'

# training
max_iter = 10_000
batch_size = 64

# imputation
L = 1000

# %% [markdown]
# Let's run.

# %%
N, D = x_data.shape

Xtrain = x_data.copy()
Xval_org = x_data.copy()

Xnan = x_nan.copy()
Xz = x_0.copy()
S = mask.copy()

Xval = x_nan.copy()
Xvalz = x_0.copy()

# %%
tf.compat.v1.disable_eager_execution()

# %% [markdown]
# ### MIWAE

# %%
miwae = MIWAE(Xnan, Xval, n_latent=n_latent, n_samples=n_samples, n_hidden=n_hidden, name=name, out_dist=out_dist)

# ---- do the training
trainer.train(miwae, batch_size=batch_size, max_iter=max_iter, name=name + 'miwae')

# ---- find imputation RMSE
RMSE_miwae, x_miwae = utils.imputationRMSE(miwae, Xtrain, Xz, Xnan, S, L)

np.save('x_miwae.npy', x_miwae)
# Out:
# Creating graph...
# 2023-11-21 18:07:58.282176: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:382] MLIR V1 optimization pass is not enabled
# Saving session...
# Saving session...
# 0/10000 updates, 0.27 s, 352208.75 train_loss, 340520.94 val_loss
# Saving session...
# 100/10000 updates, 9.30 s, 11385.17 train_loss, 10479.33 val_loss
# Saving session...
# 200/10000 updates, 9.01 s, 8392.57 train_loss, 8298.45 val_loss
# Saving session...
# 300/10000 updates, 9.00 s, 7047.57 train_loss, 7098.56 val_loss
# Saving session...
# 400/10000 updates, 10.70 s, 5445.07 train_loss, 5548.94 val_loss
# Saving session...
# 500/10000 updates, 11.33 s, 3235.50 train_loss, 3204.26 val_loss
# Saving session...
# 600/10000 updates, 11.36 s, 973.80 train_loss, 1325.14 val_loss
# Saving session...
# 700/10000 updates, 11.28 s, 908.47 train_loss, 218.36 val_loss
# Saving session...
# 800/10000 updates, 11.54 s, -579.97 train_loss, 52.04 val_loss
# 900/10000 updates, 11.56 s, -177.86 train_loss, 192.29 val_loss
# Saving session...
# 1000/10000 updates, 11.23 s, -204.64 train_loss, -593.89 val_loss
# Saving session...
# 1100/10000 updates, 11.22 s, -207.55 train_loss, -613.40 val_loss
# Saving session...
# 1200/10000 updates, 11.76 s, -829.19 train_loss, -772.15 val_loss
# 1300/10000 updates, 13.73 s, -623.48 train_loss, -603.84 val_loss
# 1400/10000 updates, 14.40 s, -568.67 train_loss, -577.11 val_loss
# 1500/10000 updates, 13.36 s, -86.77 train_loss, -478.76 val_loss
# 1600/10000 updates, 21.49 s, -585.35 train_loss, -728.86 val_loss
# Saving session...
# 1700/10000 updates, 19.85 s, -697.23 train_loss, -861.71 val_loss
# 1800/10000 updates, 23.26 s, -903.32 train_loss, -841.14 val_loss
# Saving session...
# 1900/10000 updates, 21.83 s, -745.21 train_loss, -954.45 val_loss
# 2000/10000 updates, 24.11 s, -1594.79 train_loss, -821.77 val_loss
# 2100/10000 updates, 15.04 s, -1152.56 train_loss, -565.50 val_loss
# 2200/10000 updates, 11.86 s, -939.76 train_loss, -853.06 val_loss
# Saving session...
# 2300/10000 updates, 11.31 s, -1315.62 train_loss, -1019.91 val_loss
# 2400/10000 updates, 11.47 s, -424.03 train_loss, -856.53 val_loss
# 2500/10000 updates, 11.46 s, -936.72 train_loss, -922.31 val_loss
# 2600/10000 updates, 11.89 s, -1350.99 train_loss, -842.54 val_loss
# 2700/10000 updates, 12.49 s, -929.34 train_loss, -245.44 val_loss
# 2800/10000 updates, 12.42 s, -1124.84 train_loss, -677.44 val_loss
# 2900/10000 updates, 11.25 s, -947.57 train_loss, -779.44 val_loss
# 3000/10000 updates, 11.17 s, -1285.96 train_loss, -563.79 val_loss
# 3100/10000 updates, 11.17 s, -1356.12 train_loss, -941.19 val_loss
# 3200/10000 updates, 12.76 s, -513.41 train_loss, -757.96 val_loss
# 3300/10000 updates, 13.71 s, -1009.48 train_loss, -812.69 val_loss
# 3400/10000 updates, 13.03 s, -1404.23 train_loss, -948.01 val_loss
# 3500/10000 updates, 13.99 s, -884.14 train_loss, -889.27 val_loss
# 3600/10000 updates, 11.86 s, -1013.78 train_loss, -953.04 val_loss
# 3700/10000 updates, 12.98 s, -761.11 train_loss, -238.26 val_loss
# Saving session...
# 3800/10000 updates, 12.83 s, -1527.57 train_loss, -1038.58 val_loss
# 3900/10000 updates, 11.72 s, -422.93 train_loss, -467.08 val_loss
# 4000/10000 updates, 12.60 s, -835.56 train_loss, -594.75 val_loss
# 4100/10000 updates, 12.35 s, -739.94 train_loss, -793.10 val_loss
# 4200/10000 updates, 11.84 s, -1149.36 train_loss, -929.78 val_loss
# 4300/10000 updates, 11.82 s, -877.78 train_loss, -907.37 val_loss
# 4400/10000 updates, 11.59 s, -874.60 train_loss, -650.47 val_loss
# 4500/10000 updates, 12.19 s, -466.45 train_loss, -856.39 val_loss
# 4600/10000 updates, 13.53 s, -534.81 train_loss, -873.52 val_loss
# 4700/10000 updates, 14.87 s, -575.75 train_loss, -979.19 val_loss
# 4800/10000 updates, 13.69 s, -1298.38 train_loss, -896.42 val_loss
# 4900/10000 updates, 13.10 s, -761.08 train_loss, -768.78 val_loss
# 5000/10000 updates, 12.88 s, -907.51 train_loss, -917.30 val_loss
# 5100/10000 updates, 12.41 s, -743.67 train_loss, -708.52 val_loss
# 5200/10000 updates, 11.46 s, -689.88 train_loss, -415.68 val_loss
# 5300/10000 updates, 11.38 s, -676.13 train_loss, -534.51 val_loss
# 5400/10000 updates, 11.36 s, -1080.95 train_loss, -802.08 val_loss
# 5500/10000 updates, 11.96 s, -680.68 train_loss, -946.39 val_loss
# 5600/10000 updates, 12.26 s, -462.40 train_loss, -760.56 val_loss
# 5700/10000 updates, 12.60 s, -961.14 train_loss, -843.33 val_loss
# 5800/10000 updates, 12.16 s, -1148.59 train_loss, -1003.73 val_loss
# 5900/10000 updates, 12.03 s, -631.10 train_loss, -647.85 val_loss
# 6000/10000 updates, 12.27 s, -1426.25 train_loss, -767.40 val_loss
# 6100/10000 updates, 11.97 s, -1195.10 train_loss, -910.06 val_loss
# 6200/10000 updates, 11.85 s, -813.86 train_loss, -714.91 val_loss
# 6300/10000 updates, 11.90 s, -968.33 train_loss, -713.45 val_loss
# 6400/10000 updates, 11.58 s, -891.73 train_loss, -867.58 val_loss
# 6500/10000 updates, 11.39 s, -1163.57 train_loss, -825.67 val_loss
# 6600/10000 updates, 11.24 s, -847.79 train_loss, -870.79 val_loss
# 6700/10000 updates, 11.31 s, -1631.34 train_loss, -805.76 val_loss
# Saving session...
# 6800/10000 updates, 11.23 s, -1187.21 train_loss, -1131.74 val_loss
# 6900/10000 updates, 11.33 s, -738.10 train_loss, -780.16 val_loss
# 7000/10000 updates, 11.21 s, -771.27 train_loss, -734.95 val_loss
# 7100/10000 updates, 11.27 s, -434.84 train_loss, -823.07 val_loss
# 7200/10000 updates, 11.58 s, -43.48 train_loss, -835.58 val_loss
# 7300/10000 updates, 11.43 s, -605.25 train_loss, -819.41 val_loss
# 7400/10000 updates, 11.45 s, -706.74 train_loss, -952.29 val_loss
# 7500/10000 updates, 11.47 s, -1099.05 train_loss, -856.28 val_loss
# 7600/10000 updates, 11.17 s, -1147.50 train_loss, -862.48 val_loss
# 7700/10000 updates, 12.82 s, -1575.08 train_loss, -808.18 val_loss
# 7800/10000 updates, 12.08 s, -1046.04 train_loss, -836.78 val_loss
# 7900/10000 updates, 12.11 s, -1515.14 train_loss, -1026.44 val_loss
# 8000/10000 updates, 12.14 s, -882.01 train_loss, -782.90 val_loss
# 8100/10000 updates, 11.76 s, -675.21 train_loss, -937.50 val_loss
# 8200/10000 updates, 11.80 s, -1075.57 train_loss, -862.90 val_loss
# 8300/10000 updates, 11.99 s, -1118.58 train_loss, -1008.99 val_loss
# 8400/10000 updates, 12.17 s, -1128.79 train_loss, -859.55 val_loss
# 8500/10000 updates, 12.61 s, -1062.29 train_loss, -847.15 val_loss
# 8600/10000 updates, 12.31 s, -921.66 train_loss, -681.60 val_loss
# 8700/10000 updates, 12.53 s, -1419.28 train_loss, -808.36 val_loss
# 8800/10000 updates, 12.05 s, -762.32 train_loss, -1029.28 val_loss
# 8900/10000 updates, 12.04 s, -1107.57 train_loss, -921.07 val_loss
# 9000/10000 updates, 11.94 s, -1749.42 train_loss, -835.37 val_loss
# 9100/10000 updates, 11.79 s, -1158.72 train_loss, -898.85 val_loss
# 9200/10000 updates, 11.72 s, -632.49 train_loss, -828.19 val_loss
# 9300/10000 updates, 13.09 s, -1176.71 train_loss, -553.70 val_loss
# 9400/10000 updates, 12.49 s, -394.88 train_loss, -725.45 val_loss
# 9500/10000 updates, 12.34 s, -990.66 train_loss, -928.24 val_loss
# 9600/10000 updates, 11.77 s, -527.11 train_loss, -737.55 val_loss
# 9700/10000 updates, 11.64 s, -855.01 train_loss, -835.20 val_loss
# 9800/10000 updates, 12.32 s, -1339.16 train_loss, -796.85 val_loss
# 9900/10000 updates, 12.72 s, -1042.04 train_loss, -996.04 val_loss
# 0 / 1000
# 100 / 1000
# 200 / 1000
# 300 / 1000
# 400 / 1000
# 500 / 1000
# 600 / 1000
# 700 / 1000
# 800 / 1000
# 900 / 1000

# %%
print("RMSE: {:.3f}".format(RMSE_miwae))
# Out:
# RMSE: 0.489

# %%
x_miwae = np.load('x_miwae.npy')

# %%
x_obs = x_data[mask]
x_miss = x_data[~mask]

x_est = x_miwae

x_est_obs = x_est[mask]
x_est_miss = x_est[~mask]

# %%
scatter_compare_individual_entries_panel(x_obs, x_miss, x_est_obs, x_est_miss)

# %%
hist_compare_individual_entries(x_obs, x_miss, x_est_obs, x_est_miss)

# %% [markdown]
# ### not-MIWAE (self-masking)

# %%
notmiwae = notMIWAE(Xnan, Xval, n_latent=n_latent, n_samples=n_samples, n_hidden=n_hidden, name=name, out_dist=out_dist, mechanism_weight=0.1, missing_process='selfmasking')

# ---- do the training
trainer.train(notmiwae, batch_size=batch_size, max_iter=max_iter, name=name + 'notmiwae')

# ---- find imputation RMSE
RMSE_notmiwae, x_notmiwae = utils.not_imputationRMSE(notmiwae, Xtrain, Xz, Xnan, S, L)

np.save('x_notmiwae.npy', x_notmiwae)
# Out:
# Creating graph...
# Saving session...
# Saving session...
# 0/10000 updates, 0.37 s, 352187.00 train_loss, 333472.13 val_loss
# Saving session...
# 100/10000 updates, 21.60 s, 10258.71 train_loss, 10601.66 val_loss
# Saving session...
# 200/10000 updates, 21.18 s, 8641.21 train_loss, 8534.19 val_loss
# Saving session...
# 300/10000 updates, 20.84 s, 7139.53 train_loss, 7233.18 val_loss
# Saving session...
# 400/10000 updates, 20.73 s, 5623.52 train_loss, 5567.23 val_loss
# Saving session...
# 500/10000 updates, 20.69 s, 3094.57 train_loss, 3007.60 val_loss
# Saving session...
# 600/10000 updates, 20.76 s, 1018.56 train_loss, 1228.78 val_loss
# Saving session...
# 700/10000 updates, 20.98 s, 165.61 train_loss, 527.19 val_loss
# Saving session...
# 800/10000 updates, 20.80 s, 445.33 train_loss, -286.87 val_loss
# Saving session...
# 900/10000 updates, 20.88 s, -423.49 train_loss, -423.00 val_loss
# 1000/10000 updates, 20.78 s, -464.58 train_loss, -342.77 val_loss
# Saving session...
# 1100/10000 updates, 21.74 s, -878.98 train_loss, -600.49 val_loss
# Saving session...
# 1200/10000 updates, 19.69 s, -364.00 train_loss, -745.53 val_loss
# 1300/10000 updates, 19.48 s, -456.21 train_loss, -420.88 val_loss
# 1400/10000 updates, 19.47 s, 471.74 train_loss, -689.68 val_loss
# 1500/10000 updates, 22.97 s, -431.47 train_loss, -411.01 val_loss
# 1600/10000 updates, 22.62 s, -45.00 train_loss, -576.95 val_loss
# 1700/10000 updates, 23.46 s, -712.97 train_loss, -693.64 val_loss
# 1800/10000 updates, 22.88 s, -346.86 train_loss, -615.57 val_loss
# 1900/10000 updates, 23.13 s, -1060.58 train_loss, -532.14 val_loss
# 2000/10000 updates, 22.34 s, -661.90 train_loss, -624.53 val_loss
# 2100/10000 updates, 22.51 s, -894.03 train_loss, -577.20 val_loss
# 2200/10000 updates, 21.55 s, 823.90 train_loss, -713.59 val_loss
# 2300/10000 updates, 21.95 s, -846.54 train_loss, -504.46 val_loss
# 2400/10000 updates, 21.57 s, -832.32 train_loss, -629.36 val_loss
# 2500/10000 updates, 20.97 s, -228.07 train_loss, -277.97 val_loss
# 2600/10000 updates, 19.88 s, -377.99 train_loss, -318.98 val_loss
# 2700/10000 updates, 20.23 s, -730.26 train_loss, -569.66 val_loss
# 2800/10000 updates, 20.68 s, -1218.12 train_loss, -660.06 val_loss
# 2900/10000 updates, 21.82 s, -1337.58 train_loss, -666.89 val_loss
# 3000/10000 updates, 20.62 s, -894.92 train_loss, -682.88 val_loss
# 3100/10000 updates, 19.82 s, -701.85 train_loss, -542.01 val_loss
# 3200/10000 updates, 19.41 s, -732.55 train_loss, -726.46 val_loss
# Saving session...
# 3300/10000 updates, 19.37 s, -619.06 train_loss, -750.20 val_loss
# Saving session...
# 3400/10000 updates, 20.35 s, -869.62 train_loss, -750.30 val_loss
# 3500/10000 updates, 22.74 s, -715.29 train_loss, -496.76 val_loss
# 3600/10000 updates, 24.32 s, -1026.72 train_loss, -696.79 val_loss
# 3700/10000 updates, 23.26 s, -746.15 train_loss, -589.84 val_loss
# Saving session...
# 3800/10000 updates, 20.39 s, -700.09 train_loss, -768.71 val_loss
# 3900/10000 updates, 22.00 s, -706.92 train_loss, -548.14 val_loss
# 4000/10000 updates, 21.90 s, -550.02 train_loss, -690.89 val_loss
# 4100/10000 updates, 24.00 s, -671.55 train_loss, -700.20 val_loss
# Saving session...
# 4200/10000 updates, 23.06 s, -842.53 train_loss, -887.99 val_loss
# 4300/10000 updates, 23.64 s, -1031.99 train_loss, -638.88 val_loss
# 4400/10000 updates, 22.04 s, -675.85 train_loss, -741.15 val_loss
# 4500/10000 updates, 23.74 s, -554.87 train_loss, -678.39 val_loss
# 4600/10000 updates, 23.54 s, -809.73 train_loss, -688.16 val_loss
# 4700/10000 updates, 22.04 s, -964.75 train_loss, -688.71 val_loss
# 4800/10000 updates, 20.64 s, -370.47 train_loss, -475.55 val_loss
# 4900/10000 updates, 22.26 s, -481.89 train_loss, -636.53 val_loss
# 5000/10000 updates, 20.50 s, -861.53 train_loss, -769.30 val_loss
# 5100/10000 updates, 20.65 s, -585.23 train_loss, -515.79 val_loss
# 5200/10000 updates, 20.50 s, -996.60 train_loss, -690.50 val_loss
# 5300/10000 updates, 20.45 s, -417.42 train_loss, -431.25 val_loss
# 5400/10000 updates, 20.50 s, -721.28 train_loss, -624.47 val_loss
# 5500/10000 updates, 20.45 s, -312.49 train_loss, -675.05 val_loss
# 5600/10000 updates, 20.48 s, -1215.91 train_loss, -701.19 val_loss
# 5700/10000 updates, 20.70 s, -725.33 train_loss, -639.02 val_loss
# 5800/10000 updates, 20.47 s, -610.36 train_loss, -794.16 val_loss
# 5900/10000 updates, 20.49 s, -337.88 train_loss, -765.17 val_loss
# Saving session...
# 6000/10000 updates, 20.55 s, -1083.40 train_loss, -888.45 val_loss
# 6100/10000 updates, 20.65 s, 349.33 train_loss, -672.56 val_loss
# 6200/10000 updates, 20.36 s, -354.34 train_loss, -760.96 val_loss
# 6300/10000 updates, 20.30 s, -584.40 train_loss, -812.11 val_loss
# 6400/10000 updates, 20.61 s, -610.56 train_loss, -475.56 val_loss
# 6500/10000 updates, 20.31 s, -668.43 train_loss, -411.65 val_loss
# 6600/10000 updates, 20.38 s, -78.18 train_loss, -658.88 val_loss
# 6700/10000 updates, 20.75 s, -1333.57 train_loss, -303.17 val_loss
# 6800/10000 updates, 20.38 s, -397.44 train_loss, -699.80 val_loss
# 6900/10000 updates, 20.36 s, -497.07 train_loss, -542.37 val_loss
# 7000/10000 updates, 20.42 s, -557.12 train_loss, -639.30 val_loss
# Saving session...
# 7100/10000 updates, 20.43 s, -1144.29 train_loss, -908.80 val_loss
# 7200/10000 updates, 20.43 s, -757.78 train_loss, -707.56 val_loss
# 7300/10000 updates, 20.45 s, 1530.67 train_loss, -369.99 val_loss
# 7400/10000 updates, 20.35 s, -591.03 train_loss, -712.49 val_loss
# 7500/10000 updates, 20.35 s, -830.89 train_loss, -601.21 val_loss
# 7600/10000 updates, 20.37 s, -694.94 train_loss, -666.84 val_loss
# 7700/10000 updates, 20.33 s, -1174.62 train_loss, -590.45 val_loss
# 7800/10000 updates, 20.39 s, -1006.58 train_loss, -580.60 val_loss
# 7900/10000 updates, 20.39 s, -933.03 train_loss, -806.89 val_loss
# 8000/10000 updates, 20.35 s, -843.56 train_loss, -679.55 val_loss
# 8100/10000 updates, 20.37 s, 996.76 train_loss, -728.55 val_loss
# 8200/10000 updates, 20.38 s, -859.67 train_loss, -834.26 val_loss
# 8300/10000 updates, 20.39 s, -885.48 train_loss, -672.88 val_loss
# 8400/10000 updates, 20.34 s, -83.32 train_loss, -805.07 val_loss
# 8500/10000 updates, 20.39 s, -843.65 train_loss, -644.82 val_loss
# 8600/10000 updates, 20.38 s, -1048.25 train_loss, -785.54 val_loss
# 8700/10000 updates, 20.37 s, -939.12 train_loss, -778.06 val_loss
# 8800/10000 updates, 20.43 s, -775.87 train_loss, -386.38 val_loss
# 8900/10000 updates, 20.39 s, -219.80 train_loss, -638.48 val_loss
# 9000/10000 updates, 20.39 s, -1051.48 train_loss, -745.08 val_loss
# 9100/10000 updates, 20.41 s, -899.27 train_loss, -769.73 val_loss
# 9200/10000 updates, 20.37 s, -1095.62 train_loss, -817.55 val_loss
# 9300/10000 updates, 20.35 s, -157.04 train_loss, -356.37 val_loss
# 9400/10000 updates, 20.36 s, -1008.31 train_loss, -742.61 val_loss
# 9500/10000 updates, 20.42 s, -1243.66 train_loss, -840.97 val_loss
# 9600/10000 updates, 20.29 s, -733.57 train_loss, -497.22 val_loss
# 9700/10000 updates, 20.33 s, -822.61 train_loss, -778.54 val_loss
# 9800/10000 updates, 20.43 s, -924.31 train_loss, -809.45 val_loss
# 9900/10000 updates, 20.69 s, -701.23 train_loss, -717.90 val_loss
# 0 / 1000
# 100 / 1000
# 200 / 1000
# 300 / 1000
# 400 / 1000
# 500 / 1000
# 600 / 1000
# 700 / 1000
# 800 / 1000
# 900 / 1000

# %%
print("RMSE: {:.3f}".format(RMSE_notmiwae))
# Out:
# RMSE: 0.181

# %%
x_notmiwae = np.load('x_notmiwae.npy')

# %%
x_obs = x_data[mask]
x_miss = x_data[~mask]

x_est = x_notmiwae

x_est_obs = x_est[mask]
x_est_miss = x_est[~mask]

# %%
scatter_compare_individual_entries_panel(x_obs, x_miss, x_est_obs, x_est_miss)

# %%
hist_compare_individual_entries(x_obs, x_miss, x_est_obs, x_est_miss)

# %%
W, b = notmiwae.sess.run([notmiwae.W, notmiwae.b])

# %%
fig, ax = plt.subplots(ncols=1, figsize=(6, 5))

p_obs = detection_prob[mask]
x_obs = x_data[mask]

p_miss = detection_prob[~mask]
x_miss = x_data[~mask]

n = 5_000

ax.scatter(x_miss[:n], p_miss[:n], color="red", alpha=.1, s=2)
ax.scatter(x_obs[:n], p_obs[:n], color="blue", alpha=.1, s=2)
ax.set_title("entry intensity vs detection probability")
ax.set_xlabel("entry intensity")
ax.set_ylabel("detection probability")
ax.grid(True)
ax.set_axisbelow(True)

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

for n in range(W.shape[-1]):
    xs = np.linspace(0, 18, 100)
    logit = W[0, 0, n] * xs + b[0, 0, n]
    ys = sigmoid(logit)
    ax.plot(xs, ys, color="black", alpha=.3, linewidth=4)

# %% [markdown]
# ### not-MIWAE (self-masking known)

# %%
notmiwae = notMIWAE(Xnan, Xval, n_latent=n_latent, n_samples=n_samples, n_hidden=n_hidden, name=name, out_dist=out_dist, mechanism_weight=0.1, missing_process='selfmasking_known')

# ---- do the training
trainer.train(notmiwae, batch_size=batch_size, max_iter=max_iter, name=name + 'notmiwae')

# ---- find imputation RMSE
RMSE_notmiwae, x_notmiwae = utils.not_imputationRMSE(notmiwae, Xtrain, Xz, Xnan, S, L)

np.save('x_notmiwae.npy', x_notmiwae)
# Out:
# Creating graph...
# Saving session...
# Saving session...
# 0/10000 updates, 0.36 s, 352447.59 train_loss, 338723.86 val_loss
# Saving session...
# 100/10000 updates, 20.33 s, 11100.50 train_loss, 10632.46 val_loss
# Saving session...
# 200/10000 updates, 23.00 s, 8306.78 train_loss, 8503.53 val_loss
# Saving session...
# 300/10000 updates, 21.41 s, 7040.15 train_loss, 7088.70 val_loss
# Saving session...
# 400/10000 updates, 22.39 s, 5164.06 train_loss, 5301.08 val_loss
# Saving session...
# 500/10000 updates, 21.87 s, 2782.12 train_loss, 2797.23 val_loss
# Saving session...
# 600/10000 updates, 22.30 s, 918.42 train_loss, 1379.41 val_loss
# Saving session...
# 700/10000 updates, 20.60 s, 1352.07 train_loss, 281.42 val_loss
# Saving session...
# 800/10000 updates, 23.22 s, -69.29 train_loss, -430.66 val_loss
# 900/10000 updates, 21.94 s, 49.15 train_loss, -306.52 val_loss
# Saving session...
# 1000/10000 updates, 22.24 s, -662.91 train_loss, -473.81 val_loss
# 1100/10000 updates, 20.94 s, -924.03 train_loss, -396.19 val_loss
# 1200/10000 updates, 21.61 s, -770.35 train_loss, -331.60 val_loss
# Saving session...
# 1300/10000 updates, 22.72 s, -210.67 train_loss, -875.59 val_loss
# 1400/10000 updates, 22.41 s, 1110.70 train_loss, -397.46 val_loss
# 1500/10000 updates, 21.49 s, -702.47 train_loss, -523.74 val_loss
# 1600/10000 updates, 21.43 s, -871.49 train_loss, -621.75 val_loss
# 1700/10000 updates, 20.83 s, -150.40 train_loss, -263.03 val_loss
# 1800/10000 updates, 20.35 s, -899.38 train_loss, -676.49 val_loss
# 1900/10000 updates, 20.36 s, -364.99 train_loss, -340.08 val_loss
# 2000/10000 updates, 20.34 s, -561.16 train_loss, -684.21 val_loss
# 2100/10000 updates, 20.39 s, -454.19 train_loss, -716.88 val_loss
# 2200/10000 updates, 20.33 s, -853.09 train_loss, -737.15 val_loss
# 2300/10000 updates, 20.39 s, -961.36 train_loss, -493.95 val_loss
# 2400/10000 updates, 20.28 s, -393.45 train_loss, -748.67 val_loss
# 2500/10000 updates, 20.29 s, -652.56 train_loss, -601.28 val_loss
# 2600/10000 updates, 20.43 s, -790.53 train_loss, -799.27 val_loss
# 2700/10000 updates, 20.28 s, -445.71 train_loss, -572.96 val_loss
# 2800/10000 updates, 20.28 s, -1055.70 train_loss, -796.26 val_loss
# 2900/10000 updates, 20.32 s, -731.87 train_loss, -839.32 val_loss
# 3000/10000 updates, 20.29 s, -366.10 train_loss, -858.45 val_loss
# 3100/10000 updates, 20.29 s, -498.39 train_loss, -714.62 val_loss
# 3200/10000 updates, 20.29 s, -639.86 train_loss, -807.44 val_loss
# 3300/10000 updates, 20.21 s, -766.14 train_loss, -754.75 val_loss
# 3400/10000 updates, 20.25 s, -592.62 train_loss, -869.36 val_loss
# 3500/10000 updates, 20.23 s, -1284.74 train_loss, -756.53 val_loss
# 3600/10000 updates, 20.43 s, -492.23 train_loss, -846.00 val_loss
# 3700/10000 updates, 20.25 s, -156.36 train_loss, -333.34 val_loss
# 3800/10000 updates, 20.24 s, -819.67 train_loss, -610.43 val_loss
# 3900/10000 updates, 20.26 s, -708.88 train_loss, -801.27 val_loss
# 4000/10000 updates, 20.22 s, 47.19 train_loss, -610.98 val_loss
# 4100/10000 updates, 20.28 s, -282.23 train_loss, -842.19 val_loss
# 4200/10000 updates, 20.25 s, -841.14 train_loss, -746.93 val_loss
# 4300/10000 updates, 20.19 s, -807.94 train_loss, -607.13 val_loss
# 4400/10000 updates, 21.18 s, -1329.76 train_loss, -691.88 val_loss
# 4500/10000 updates, 22.60 s, -1037.64 train_loss, -857.52 val_loss
# 4600/10000 updates, 23.18 s, -1456.66 train_loss, -264.66 val_loss
# 4700/10000 updates, 19.57 s, -735.16 train_loss, -683.83 val_loss
# 4800/10000 updates, 21.78 s, -610.70 train_loss, -649.76 val_loss
# 4900/10000 updates, 22.71 s, -587.21 train_loss, -782.53 val_loss
# 5000/10000 updates, 20.85 s, -1062.83 train_loss, -699.18 val_loss
# 5100/10000 updates, 19.78 s, -933.16 train_loss, -768.78 val_loss
# 5200/10000 updates, 20.06 s, -1164.05 train_loss, -701.95 val_loss
# 5300/10000 updates, 19.82 s, -693.56 train_loss, -699.64 val_loss
# 5400/10000 updates, 19.45 s, -1138.45 train_loss, -852.42 val_loss
# 5500/10000 updates, 19.36 s, -139.08 train_loss, -703.87 val_loss
# 5600/10000 updates, 22.49 s, -743.97 train_loss, -766.59 val_loss
# 5700/10000 updates, 20.06 s, -625.74 train_loss, -574.21 val_loss
# 5800/10000 updates, 19.02 s, 58.40 train_loss, -577.08 val_loss
# 5900/10000 updates, 18.95 s, -333.79 train_loss, -457.00 val_loss
# 6000/10000 updates, 19.03 s, -708.58 train_loss, -793.05 val_loss
# 6100/10000 updates, 19.02 s, -684.06 train_loss, -746.48 val_loss
# 6200/10000 updates, 18.99 s, -90.07 train_loss, -449.45 val_loss
# 6300/10000 updates, 18.95 s, -542.02 train_loss, -809.96 val_loss
# 6400/10000 updates, 18.92 s, -334.05 train_loss, -610.13 val_loss
# 6500/10000 updates, 18.98 s, -1474.75 train_loss, -507.63 val_loss
# 6600/10000 updates, 18.95 s, -290.08 train_loss, -831.44 val_loss
# 6700/10000 updates, 18.97 s, -555.51 train_loss, -520.09 val_loss
# 6800/10000 updates, 18.87 s, -918.42 train_loss, -548.71 val_loss
# 6900/10000 updates, 18.92 s, -569.06 train_loss, -765.88 val_loss
# 7000/10000 updates, 18.90 s, -575.88 train_loss, -789.56 val_loss
# 7100/10000 updates, 18.93 s, -721.03 train_loss, -702.93 val_loss
# 7200/10000 updates, 18.94 s, -1366.17 train_loss, -838.65 val_loss
# 7300/10000 updates, 18.88 s, -618.05 train_loss, -758.88 val_loss
# 7400/10000 updates, 18.91 s, -651.98 train_loss, -763.51 val_loss
# 7500/10000 updates, 18.92 s, -630.85 train_loss, -578.82 val_loss
# Saving session...
# 7600/10000 updates, 18.94 s, -868.05 train_loss, -909.98 val_loss
# 7700/10000 updates, 19.00 s, -754.31 train_loss, -586.35 val_loss
# 7800/10000 updates, 18.90 s, -1170.59 train_loss, -646.67 val_loss
# 7900/10000 updates, 18.88 s, -549.17 train_loss, -558.50 val_loss
# 8000/10000 updates, 18.96 s, -397.31 train_loss, -787.23 val_loss
# 8100/10000 updates, 18.91 s, -823.32 train_loss, -829.97 val_loss
# 8200/10000 updates, 18.91 s, -164.85 train_loss, -589.65 val_loss
# 8300/10000 updates, 18.89 s, -1152.29 train_loss, -744.74 val_loss
# 8400/10000 updates, 18.89 s, -756.36 train_loss, -755.99 val_loss
# 8500/10000 updates, 18.90 s, -161.18 train_loss, -744.53 val_loss
# 8600/10000 updates, 18.91 s, -700.07 train_loss, -736.92 val_loss
# 8700/10000 updates, 18.85 s, -685.59 train_loss, -897.01 val_loss
# 8800/10000 updates, 18.93 s, -431.06 train_loss, -764.79 val_loss
# 8900/10000 updates, 18.86 s, -657.62 train_loss, -806.44 val_loss
# 9000/10000 updates, 18.89 s, -779.95 train_loss, -765.68 val_loss
# 9100/10000 updates, 18.90 s, -917.33 train_loss, -807.52 val_loss
# 9200/10000 updates, 18.93 s, -892.46 train_loss, -517.58 val_loss
# 9300/10000 updates, 20.82 s, -335.82 train_loss, -715.29 val_loss
# 9400/10000 updates, 22.83 s, 30.77 train_loss, -540.36 val_loss
# Saving session...
# 9500/10000 updates, 21.93 s, -903.51 train_loss, -944.26 val_loss
# 9600/10000 updates, 22.35 s, -160.00 train_loss, -690.37 val_loss
# 9700/10000 updates, 19.20 s, -579.43 train_loss, -490.51 val_loss
# 9800/10000 updates, 20.65 s, -910.92 train_loss, -827.38 val_loss
# 9900/10000 updates, 22.78 s, -982.15 train_loss, -773.38 val_loss
# 0 / 1000
# 100 / 1000
# 200 / 1000
# 300 / 1000
# 400 / 1000
# 500 / 1000
# 600 / 1000
# 700 / 1000
# 800 / 1000
# 900 / 1000

# %%
print("RMSE: {:.3f}".format(RMSE_notmiwae))
# Out:
# RMSE: 0.289

# %%
x_notmiwae = np.load('x_notmiwae.npy')

# %%
x_obs = x_data[mask]
x_miss = x_data[~mask]

x_est = x_notmiwae

x_est_obs = x_est[mask]
x_est_miss = x_est[~mask]

# %%
scatter_compare_individual_entries_panel(x_obs, x_miss, x_est_obs, x_est_miss)

# %%
hist_compare_individual_entries(x_obs, x_miss, x_est_obs, x_est_miss)
