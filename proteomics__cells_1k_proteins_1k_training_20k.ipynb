# %% [markdown]
# # Single-cell Proteomics Synthetic Data Generation

# %% [markdown]
# The goal of this notebook is to simulate a crude single-cell proteomics datasets with a MNAR mechanism, and show that not-MIWAE performs better than MIWAE.

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

from MIWAE import MIWAE
from notMIWAE import notMIWAE
import trainer
import utils

np.random.seed(42)
# Out:
# 2023-11-20 23:19:46.167412: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-11-20 23:19:46.219723: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-20 23:19:46.510751: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-20 23:19:46.510808: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-20 23:19:46.511557: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-20 23:19:46.625883: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-20 23:19:46.627216: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-20 23:19:48.543764: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# Plotting functions for later.

# %%
def scatter_compare_individual_entries_panel(x_obs, x_miss, x_est_obs, x_est_miss):
    fig, axes = plt.subplots(ncols=2, figsize=(12, 5))
    
    ax = axes[0]
    ax.scatter(x_obs, x_est_obs, s=1, alpha=0.1)
    lims = [np.min([ax.get_xlim(), ax.get_ylim()]), np.max([ax.get_xlim(), ax.get_ylim()])]
    ax.plot(lims, lims, "--", c="k")

    mse = np.mean((x_obs - x_est_obs)**2)
    ax.text(0.05, 0.95, f"MSE: {mse:.2f}", transform=ax.transAxes, fontsize=12, verticalalignment="top", bbox=dict(facecolor="white", alpha=0.8))

    ax.set_xlabel("Observed")
    ax.set_ylabel("Imputed")
    ax.set_title("Observed")
    ax.grid(True)
    ax.set_axisbelow(True)

    ax = axes[1]
    ax.scatter(x_miss, x_est_miss, s=1, alpha=0.1)
    lims = [np.min([ax.get_xlim(), ax.get_ylim()]), np.max([ax.get_xlim(), ax.get_ylim()])]
    ax.plot(lims, lims, "--", c="k")

    mse = np.mean((x_miss - x_est_miss)**2)
    ax.text(0.05, 0.95, f"MSE: {mse:.2f}", transform=ax.transAxes, fontsize=12, verticalalignment="top", bbox=dict(facecolor="white", alpha=0.8))

    ax.set_xlabel("Observed")
    ax.set_ylabel("Imputed")
    ax.set_title("Missing")
    ax.grid(True)

# %%
def hist_compare_individual_entries(x_obs, x_miss, x_est_obs, x_est_miss):
    fig, axes = plt.subplots(ncols=2, figsize=(12, 5))

    x_min = np.min([np.min(x_obs), np.min(x_miss), np.min(x_est_obs), np.min(x_est_miss)])
    x_max = np.max([np.max(x_obs), np.max(x_miss), np.max(x_est_obs), np.max(x_est_miss)])

    ax = axes[0]
    ax.hist([x_obs, x_miss], color=["blue", "red"], bins=50, edgecolor="black", linewidth=1.2, stacked=True)
    ax.set_title("Data")
    ax.set_xlabel("x")
    ax.set_ylabel("(stacked) count")
    ax.set_xlim(x_min, x_max)
    ax.grid(True)
    ax.set_axisbelow(True)
    ax.legend(labels=["$x_{obs}$", "$x_{miss}$"], fontsize=12)

    ax = axes[1]
    ax.hist([x_est_obs, x_est_miss], color=["blue", "red"], bins=50, edgecolor="black", linewidth=1.2, stacked=True)
    ax.set_title("Model")
    ax.set_xlabel("x")
    ax.set_ylabel("(stacked) count")
    ax.set_xlim(x_min, x_max)
    ax.grid(True)
    ax.set_axisbelow(True)
    ax.legend(labels=["$x_{obs}$", "$x_{miss}$"], fontsize=12)

# %% [markdown]
# ## Data generation

# %% [markdown]
# Let's start by generating the synthetic data and visualizing it.

# %%
def logistic(x, k=1, x0=0, L=1):
    return L / (1 + np.exp(-k * (x - x0)))

def sigmoid(x):
    return 1 / (1 + np.exp(-x))


def simulate_data(n_cells=1000, n_proteins=1000):
    # all cells are from the same group (cell-type)
    # the cell type has some protein distribution / signature
    cell_type_signature = np.random.uniform(5, 12, n_proteins)

    # each cell is a bit different
    cell_variation = np.random.normal(0, 1, n_cells)

    intensity = cell_type_signature.reshape(1, -1) + cell_variation.reshape(-1, 1)

    # the measurement is noisy
    x = np.random.normal(intensity, 0.1)

    # MNAR mechanism: self-masking (x -> m)
    # entries with low intensity are less likely to be sampled
    #detection_prob = logistic(x, k=2, x0=7) # set x0=6, if you want less missing values
    detection_prob = sigmoid(2*x - 14)

    # sample using a bernoulli distribution
    mask = np.random.binomial(1, detection_prob)
    mask = mask.astype(bool)

    return x, detection_prob, mask

# %% [markdown]
# Let's simulate some data:

# %%
x_data, detection_prob, mask = simulate_data()

# %%
x_nan = x_data.copy()
x_nan[~mask] = np.nan

x_0 = x_data.copy()
x_0[~mask] = 0

# %%
print("Missing entries: {:.2f}%".format(np.isnan(x_nan).sum() / x_nan.size * 100))
# Out:
# Missing entries: 29.23%

# %% [markdown]
# Let's plot the data. "White" are the missing values.

# %%
fig, ax = plt.subplots(figsize=(8, 5))
sns.heatmap(x_nan, cmap="viridis", xticklabels=False, yticklabels=False, ax=ax)
ax.set_xlabel("Proteins")
ax.set_ylabel("Cells")
ax.set_title("Expression matrix with missing values")
# Out:
# Text(0.5, 1.0, 'Expression matrix with missing values')

# %% [markdown]
# Let's look at the missigness pattern entry-wise and protein-wise:

# %%
fig, axes = plt.subplots(ncols=2, figsize=(12, 5))

# plot entry intensity vs detection probability
ax = axes[0]

p_obs = detection_prob[mask]
x_obs = x_data[mask]

p_miss = detection_prob[~mask]
x_miss = x_data[~mask]

n = 5_000

ax.scatter(x_miss[:n], p_miss[:n], color="red", alpha=.1, s=4)
ax.scatter(x_obs[:n], p_obs[:n], color="blue", alpha=.1, s=4)
ax.set_title("entry intensity vs detection probability")
ax.set_xlabel("entry intensity")
ax.set_ylabel("detection probability")
ax.grid(True)
ax.set_axisbelow(True)

# plot the average protein intensity vs the detection proportion
ax = axes[1]
x_obs_protein = np.nanmean(x_nan, axis=0)
p_protein = 1 - np.nanmean(np.isnan(x_nan), axis=0)

ax.scatter(x_obs_protein, p_protein, color="blue", alpha=1, s=6)
ax.set_title("avg protein intensity vs detection proportion")
ax.set_xlabel("protein intensity")
ax.set_ylabel("detection proportion")
ax.grid(True)
ax.set_axisbelow(True)

# %%
fig, ax = plt.subplots(1, 1, figsize=(5, 5))

ax.hist([x_obs, x_miss], color=["blue", "red"], bins=50, edgecolor="black", linewidth=1.2, stacked=True)
ax.set_title("Data")
ax.set_xlabel("x")
ax.set_ylabel("(stacked) count")
ax.set_xlim(np.min(x_data), np.max(x_data))
ax.grid(True)
ax.set_axisbelow(True)
ax.legend(labels=["$x_{obs}$", "$x_{miss}$"], fontsize=12)

# %% [markdown]
# ## Model Comparison

# %% [markdown]
# Set the parameters for the models.

# %%
name = '/tmp/best'

# model specification
n_hidden = 128
n_samples = 20
n_latent = 16
out_dist='gauss'

# training
max_iter = 20_000
batch_size = 64

# imputation
L = 1000

# %% [markdown]
# Let's run.

# %%
N, D = x_data.shape

Xtrain = x_data.copy()
Xval_org = x_data.copy()

Xnan = x_nan.copy()
Xz = x_0.copy()
S = mask.copy()

Xval = x_nan.copy()
Xvalz = x_0.copy()

# %%
tf.compat.v1.disable_eager_execution()

# %% [markdown]
# ### MIWAE

# %%
miwae = MIWAE(Xnan, Xval, n_latent=n_latent, n_samples=n_samples, n_hidden=n_hidden, name=name, out_dist=out_dist)

# ---- do the training
trainer.train(miwae, batch_size=batch_size, max_iter=max_iter, name=name + 'miwae')

# ---- find imputation RMSE
RMSE_miwae, x_miwae = utils.imputationRMSE(miwae, Xtrain, Xz, Xnan, S, L)

np.save('x_miwae.npy', x_miwae)
# Out:
# Creating graph...
# 2023-11-20 23:19:54.100991: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:382] MLIR V1 optimization pass is not enabled
# Saving session...
# Saving session...
# 0/20000 updates, 0.21 s, 71612.61 train_loss, 70297.11 val_loss
# Saving session...
# 100/20000 updates, 3.07 s, 2228.41 train_loss, 2221.49 val_loss
# Saving session...
# 200/20000 updates, 2.74 s, 1652.22 train_loss, 1718.15 val_loss
# Saving session...
# 300/20000 updates, 2.85 s, 1421.24 train_loss, 1445.12 val_loss
# Saving session...
# 400/20000 updates, 2.74 s, 1133.07 train_loss, 1140.73 val_loss
# Saving session...
# 500/20000 updates, 2.70 s, 722.99 train_loss, 718.51 val_loss
# Saving session...
# 600/20000 updates, 2.81 s, 393.34 train_loss, 347.57 val_loss
# Saving session...
# 700/20000 updates, 2.80 s, 90.97 train_loss, 117.00 val_loss
# Saving session...
# 800/20000 updates, 2.43 s, -50.94 train_loss, -15.12 val_loss
# Saving session...
# 900/20000 updates, 2.75 s, -36.04 train_loss, -48.83 val_loss
# 1000/20000 updates, 4.29 s, 55.38 train_loss, -33.77 val_loss
# Saving session...
# 1100/20000 updates, 3.45 s, -160.00 train_loss, -73.90 val_loss
# Saving session...
# 1200/20000 updates, 3.77 s, -135.10 train_loss, -94.86 val_loss
# 1300/20000 updates, 3.94 s, -129.84 train_loss, -10.04 val_loss
# 1400/20000 updates, 3.59 s, 280.98 train_loss, -35.90 val_loss
# Saving session...
# 1500/20000 updates, 3.53 s, -56.55 train_loss, -157.56 val_loss
# 1600/20000 updates, 3.44 s, -163.54 train_loss, -104.08 val_loss
# 1700/20000 updates, 3.86 s, -124.99 train_loss, -81.18 val_loss
# 1800/20000 updates, 4.41 s, -160.83 train_loss, -148.90 val_loss
# 1900/20000 updates, 4.14 s, -152.14 train_loss, -146.29 val_loss
# Saving session...
# 2000/20000 updates, 3.85 s, -172.78 train_loss, -177.68 val_loss
# 2100/20000 updates, 3.30 s, -180.92 train_loss, -113.91 val_loss
# 2200/20000 updates, 4.61 s, -222.41 train_loss, -38.36 val_loss
# 2300/20000 updates, 3.86 s, -175.31 train_loss, -103.79 val_loss
# Saving session...
# 2400/20000 updates, 4.78 s, -140.35 train_loss, -188.18 val_loss
# 2500/20000 updates, 4.74 s, -121.10 train_loss, -121.32 val_loss
# 2600/20000 updates, 5.10 s, -248.78 train_loss, -142.82 val_loss
# 2700/20000 updates, 4.99 s, -151.86 train_loss, -136.95 val_loss
# 2800/20000 updates, 3.54 s, -153.12 train_loss, -182.07 val_loss
# 2900/20000 updates, 4.71 s, -214.59 train_loss, -78.87 val_loss
# 3000/20000 updates, 3.54 s, -59.13 train_loss, -91.00 val_loss
# 3100/20000 updates, 4.72 s, -199.17 train_loss, -116.38 val_loss
# 3200/20000 updates, 4.72 s, -129.83 train_loss, -152.40 val_loss
# 3300/20000 updates, 4.89 s, -148.44 train_loss, -132.92 val_loss
# 3400/20000 updates, 4.68 s, -106.33 train_loss, -121.76 val_loss
# Saving session...
# 3500/20000 updates, 5.01 s, -172.81 train_loss, -190.92 val_loss
# 3600/20000 updates, 4.96 s, -165.95 train_loss, -104.12 val_loss
# 3700/20000 updates, 4.92 s, -171.87 train_loss, -169.47 val_loss
# 3800/20000 updates, 4.82 s, -158.55 train_loss, -140.08 val_loss
# 3900/20000 updates, 5.05 s, -158.86 train_loss, -147.80 val_loss
# 4000/20000 updates, 5.09 s, -222.47 train_loss, -155.60 val_loss
# 4100/20000 updates, 5.06 s, -234.46 train_loss, -165.18 val_loss
# 4200/20000 updates, 4.66 s, -266.20 train_loss, -149.00 val_loss
# 4300/20000 updates, 4.23 s, -77.47 train_loss, -169.57 val_loss
# 4400/20000 updates, 3.75 s, -189.77 train_loss, -159.42 val_loss
# 4500/20000 updates, 3.53 s, -217.66 train_loss, -190.04 val_loss
# 4600/20000 updates, 4.03 s, -46.52 train_loss, -59.06 val_loss
# 4700/20000 updates, 4.23 s, 98.51 train_loss, -173.07 val_loss
# 4800/20000 updates, 3.72 s, -171.47 train_loss, -140.18 val_loss
# 4900/20000 updates, 3.82 s, -184.92 train_loss, -135.02 val_loss
# 5000/20000 updates, 3.55 s, -135.80 train_loss, -161.21 val_loss
# 5100/20000 updates, 4.01 s, -108.33 train_loss, -179.96 val_loss
# 5200/20000 updates, 3.66 s, -244.13 train_loss, -178.95 val_loss
# 5300/20000 updates, 3.77 s, 77.30 train_loss, -124.56 val_loss
# 5400/20000 updates, 4.87 s, -133.59 train_loss, -131.37 val_loss
# 5500/20000 updates, 4.63 s, -153.98 train_loss, -114.41 val_loss
# 5600/20000 updates, 4.77 s, -122.36 train_loss, -162.52 val_loss
# 5700/20000 updates, 4.80 s, 110.63 train_loss, -123.89 val_loss
# 5800/20000 updates, 4.86 s, -55.31 train_loss, -178.12 val_loss
# 5900/20000 updates, 3.75 s, -172.65 train_loss, -158.34 val_loss
# 6000/20000 updates, 3.60 s, -128.05 train_loss, -166.41 val_loss
# 6100/20000 updates, 3.70 s, -258.42 train_loss, -138.79 val_loss
# 6200/20000 updates, 3.99 s, -131.68 train_loss, -156.28 val_loss
# 6300/20000 updates, 4.04 s, -208.54 train_loss, -107.68 val_loss
# 6400/20000 updates, 3.60 s, -233.48 train_loss, -128.23 val_loss
# 6500/20000 updates, 3.72 s, -84.76 train_loss, -98.11 val_loss
# 6600/20000 updates, 3.42 s, -227.59 train_loss, -182.63 val_loss
# 6700/20000 updates, 4.31 s, -218.05 train_loss, -166.45 val_loss
# 6800/20000 updates, 4.94 s, -153.13 train_loss, -125.46 val_loss
# 6900/20000 updates, 4.86 s, -105.87 train_loss, -114.69 val_loss
# 7000/20000 updates, 5.06 s, 268.80 train_loss, -107.67 val_loss
# 7100/20000 updates, 4.68 s, -64.97 train_loss, -146.79 val_loss
# 7200/20000 updates, 5.01 s, -75.32 train_loss, -164.23 val_loss
# 7300/20000 updates, 5.09 s, -218.67 train_loss, -134.36 val_loss
# 7400/20000 updates, 4.92 s, -163.29 train_loss, -90.53 val_loss
# 7500/20000 updates, 4.84 s, -221.14 train_loss, -118.15 val_loss
# 7600/20000 updates, 5.03 s, -163.98 train_loss, -170.38 val_loss
# 7700/20000 updates, 4.86 s, -177.84 train_loss, -53.56 val_loss
# 7800/20000 updates, 4.78 s, -188.83 train_loss, -140.14 val_loss
# 7900/20000 updates, 4.93 s, -28.56 train_loss, -152.15 val_loss
# 8000/20000 updates, 4.95 s, -136.97 train_loss, -171.36 val_loss
# 8100/20000 updates, 4.94 s, -113.52 train_loss, -142.30 val_loss
# 8200/20000 updates, 4.87 s, -147.98 train_loss, -145.79 val_loss
# 8300/20000 updates, 4.63 s, -150.32 train_loss, -148.96 val_loss
# 8400/20000 updates, 5.00 s, -166.43 train_loss, -184.53 val_loss
# 8500/20000 updates, 5.00 s, -280.37 train_loss, -178.09 val_loss
# 8600/20000 updates, 5.03 s, -93.65 train_loss, -141.03 val_loss
# 8700/20000 updates, 4.72 s, -95.25 train_loss, -165.15 val_loss
# 8800/20000 updates, 4.97 s, -165.00 train_loss, -165.46 val_loss
# 8900/20000 updates, 4.72 s, -218.92 train_loss, -179.46 val_loss
# 9000/20000 updates, 4.75 s, -22.49 train_loss, -127.05 val_loss
# 9100/20000 updates, 4.43 s, -125.23 train_loss, -144.61 val_loss
# 9200/20000 updates, 4.78 s, -130.60 train_loss, -86.42 val_loss
# 9300/20000 updates, 3.87 s, -136.43 train_loss, -142.68 val_loss
# 9400/20000 updates, 3.97 s, -211.24 train_loss, -187.29 val_loss
# Saving session...
# 9500/20000 updates, 4.05 s, -175.52 train_loss, -213.31 val_loss
# 9600/20000 updates, 3.97 s, -190.87 train_loss, -167.19 val_loss
# 9700/20000 updates, 3.92 s, -171.86 train_loss, -179.62 val_loss
# 9800/20000 updates, 3.90 s, -154.36 train_loss, -197.21 val_loss
# 9900/20000 updates, 4.10 s, -177.35 train_loss, -132.90 val_loss
# 10000/20000 updates, 3.89 s, -171.07 train_loss, -162.75 val_loss
# 10100/20000 updates, 4.14 s, -91.84 train_loss, -167.09 val_loss
# 10200/20000 updates, 3.88 s, -142.84 train_loss, -132.76 val_loss
# 10300/20000 updates, 4.01 s, -178.18 train_loss, -172.72 val_loss
# 10400/20000 updates, 3.96 s, -26.66 train_loss, -134.21 val_loss
# 10500/20000 updates, 3.84 s, -115.66 train_loss, -98.24 val_loss
# 10600/20000 updates, 3.94 s, -49.49 train_loss, -128.97 val_loss
# 10700/20000 updates, 3.82 s, -262.44 train_loss, -175.98 val_loss
# 10800/20000 updates, 3.92 s, -204.77 train_loss, -156.45 val_loss
# 10900/20000 updates, 4.20 s, -81.70 train_loss, -159.54 val_loss
# 11000/20000 updates, 4.16 s, -230.87 train_loss, -184.67 val_loss
# 11100/20000 updates, 3.93 s, -97.34 train_loss, -190.20 val_loss
# 11200/20000 updates, 3.90 s, -105.94 train_loss, -170.42 val_loss
# 11300/20000 updates, 3.95 s, -117.23 train_loss, -129.51 val_loss
# 11400/20000 updates, 3.89 s, 299.47 train_loss, -160.18 val_loss
# 11500/20000 updates, 3.93 s, -186.60 train_loss, -187.49 val_loss
# 11600/20000 updates, 3.97 s, -233.35 train_loss, -209.96 val_loss
# 11700/20000 updates, 4.04 s, -132.34 train_loss, -166.15 val_loss
# 11800/20000 updates, 3.87 s, -147.52 train_loss, -167.55 val_loss
# 11900/20000 updates, 4.08 s, -180.78 train_loss, -100.20 val_loss
# 12000/20000 updates, 3.79 s, -138.11 train_loss, -203.96 val_loss
# 12100/20000 updates, 3.23 s, -269.02 train_loss, -155.78 val_loss
# 12200/20000 updates, 4.15 s, -171.39 train_loss, -162.02 val_loss
# 12300/20000 updates, 3.95 s, -66.23 train_loss, -138.78 val_loss
# 12400/20000 updates, 3.96 s, -207.41 train_loss, -145.64 val_loss
# 12500/20000 updates, 3.89 s, -128.09 train_loss, -127.44 val_loss
# 12600/20000 updates, 3.93 s, -94.65 train_loss, -143.87 val_loss
# 12700/20000 updates, 4.05 s, -251.81 train_loss, -190.37 val_loss
# 12800/20000 updates, 3.96 s, -139.85 train_loss, -184.05 val_loss
# 12900/20000 updates, 3.95 s, -142.23 train_loss, -114.71 val_loss
# 13000/20000 updates, 3.94 s, -113.05 train_loss, -184.84 val_loss
# 13100/20000 updates, 4.01 s, -200.54 train_loss, -204.82 val_loss
# 13200/20000 updates, 3.99 s, -197.87 train_loss, -152.90 val_loss
# 13300/20000 updates, 3.94 s, -245.37 train_loss, -169.31 val_loss
# 13400/20000 updates, 4.08 s, -206.37 train_loss, -182.24 val_loss
# 13500/20000 updates, 3.87 s, -66.48 train_loss, -189.79 val_loss
# 13600/20000 updates, 3.94 s, -208.14 train_loss, -149.33 val_loss
# 13700/20000 updates, 4.06 s, -6.84 train_loss, -177.56 val_loss
# 13800/20000 updates, 3.96 s, -151.57 train_loss, -196.62 val_loss
# 13900/20000 updates, 3.92 s, -163.31 train_loss, -135.01 val_loss
# 14000/20000 updates, 3.88 s, -162.98 train_loss, -166.37 val_loss
# 14100/20000 updates, 3.93 s, -66.16 train_loss, -155.68 val_loss
# 14200/20000 updates, 4.02 s, -190.35 train_loss, -174.32 val_loss
# 14300/20000 updates, 4.01 s, -45.13 train_loss, -137.04 val_loss
# 14400/20000 updates, 3.92 s, -208.07 train_loss, -161.17 val_loss
# 14500/20000 updates, 3.99 s, -163.17 train_loss, -141.74 val_loss
# 14600/20000 updates, 3.89 s, -244.54 train_loss, -183.70 val_loss
# 14700/20000 updates, 3.96 s, -202.20 train_loss, -119.71 val_loss
# 14800/20000 updates, 3.88 s, -136.42 train_loss, -189.76 val_loss
# 14900/20000 updates, 4.04 s, -123.08 train_loss, -192.54 val_loss
# 15000/20000 updates, 3.97 s, -128.11 train_loss, -210.27 val_loss
# 15100/20000 updates, 3.95 s, 46.62 train_loss, -155.41 val_loss
# 15200/20000 updates, 3.90 s, -171.83 train_loss, -171.95 val_loss
# 15300/20000 updates, 4.03 s, -141.44 train_loss, -191.64 val_loss
# 15400/20000 updates, 3.98 s, -73.19 train_loss, -159.03 val_loss
# 15500/20000 updates, 3.91 s, -240.20 train_loss, -179.63 val_loss
# 15600/20000 updates, 4.00 s, -120.63 train_loss, -129.80 val_loss
# 15700/20000 updates, 3.92 s, -213.99 train_loss, -174.62 val_loss
# 15800/20000 updates, 4.03 s, -84.89 train_loss, -192.55 val_loss
# 15900/20000 updates, 4.07 s, -119.23 train_loss, -180.76 val_loss
# 16000/20000 updates, 3.83 s, -171.34 train_loss, -151.67 val_loss
# 16100/20000 updates, 3.88 s, -213.81 train_loss, -198.22 val_loss
# 16200/20000 updates, 3.90 s, -153.85 train_loss, -175.18 val_loss
# 16300/20000 updates, 3.96 s, -293.49 train_loss, -154.18 val_loss
# 16400/20000 updates, 3.88 s, -183.83 train_loss, -185.85 val_loss
# 16500/20000 updates, 3.91 s, -106.45 train_loss, -86.12 val_loss
# 16600/20000 updates, 4.09 s, -239.04 train_loss, -183.82 val_loss
# 16700/20000 updates, 3.97 s, -146.14 train_loss, -143.95 val_loss
# 16800/20000 updates, 3.91 s, -99.09 train_loss, -169.02 val_loss
# 16900/20000 updates, 3.99 s, -184.68 train_loss, -182.17 val_loss
# 17000/20000 updates, 4.03 s, -244.58 train_loss, -171.90 val_loss
# 17100/20000 updates, 4.03 s, -193.36 train_loss, -140.56 val_loss
# Saving session...
# 17200/20000 updates, 3.98 s, -205.43 train_loss, -217.12 val_loss
# 17300/20000 updates, 3.95 s, -72.15 train_loss, -91.21 val_loss
# 17400/20000 updates, 3.96 s, -201.38 train_loss, -130.32 val_loss
# 17500/20000 updates, 3.93 s, -285.66 train_loss, -159.45 val_loss
# 17600/20000 updates, 4.07 s, -245.40 train_loss, -186.10 val_loss
# 17700/20000 updates, 4.01 s, -85.01 train_loss, -138.06 val_loss
# 17800/20000 updates, 3.98 s, -54.61 train_loss, -167.20 val_loss
# 17900/20000 updates, 4.00 s, -274.21 train_loss, -189.10 val_loss
# 18000/20000 updates, 3.96 s, -244.53 train_loss, -151.48 val_loss
# 18100/20000 updates, 3.90 s, -174.92 train_loss, -160.11 val_loss
# 18200/20000 updates, 4.01 s, -213.93 train_loss, -155.88 val_loss
# 18300/20000 updates, 3.95 s, -90.24 train_loss, -170.57 val_loss
# 18400/20000 updates, 3.91 s, -201.33 train_loss, -201.49 val_loss
# 18500/20000 updates, 4.04 s, -288.65 train_loss, -175.96 val_loss
# 18600/20000 updates, 3.99 s, -157.03 train_loss, -150.52 val_loss
# 18700/20000 updates, 3.90 s, -140.79 train_loss, -184.20 val_loss
# 18800/20000 updates, 4.12 s, -223.87 train_loss, -187.06 val_loss
# 18900/20000 updates, 4.04 s, -97.24 train_loss, -135.88 val_loss
# 19000/20000 updates, 3.91 s, -179.32 train_loss, -173.28 val_loss
# 19100/20000 updates, 4.08 s, -130.07 train_loss, -190.17 val_loss
# 19200/20000 updates, 3.97 s, -229.26 train_loss, -198.37 val_loss
# 19300/20000 updates, 3.92 s, -123.95 train_loss, -147.51 val_loss
# 19400/20000 updates, 4.04 s, -135.86 train_loss, -178.43 val_loss
# 19500/20000 updates, 3.94 s, -160.60 train_loss, -156.85 val_loss
# 19600/20000 updates, 3.92 s, -168.63 train_loss, -168.04 val_loss
# 19700/20000 updates, 3.94 s, -174.67 train_loss, -153.77 val_loss
# 19800/20000 updates, 4.09 s, -233.71 train_loss, -171.21 val_loss
# 19900/20000 updates, 3.99 s, -202.96 train_loss, -173.19 val_loss
# 0 / 1000
# 100 / 1000
# 200 / 1000
# 300 / 1000
# 400 / 1000
# 500 / 1000
# 600 / 1000
# 700 / 1000
# 800 / 1000
# 900 / 1000

# %%
print("RMSE: {:.3f}".format(RMSE_miwae))
# Out:
# RMSE: 0.387

# %%
x_miwae = np.load('x_miwae.npy')

# %%
x_obs = x_data[mask]
x_miss = x_data[~mask]

x_est = x_miwae

x_est_obs = x_est[mask]
x_est_miss = x_est[~mask]

# %%
scatter_compare_individual_entries_panel(x_obs, x_miss, x_est_obs, x_est_miss)

# %%
hist_compare_individual_entries(x_obs, x_miss, x_est_obs, x_est_miss)

# %% [markdown]
# ### not-MIWAE (self-masking)

# %%
notmiwae = notMIWAE(Xnan, Xval, n_latent=n_latent, n_samples=n_samples, n_hidden=n_hidden, name=name, out_dist=out_dist, mechanism_weight=0.1, missing_process='selfmasking')

# ---- do the training
trainer.train(notmiwae, batch_size=batch_size, max_iter=max_iter, name=name + 'notmiwae')

# ---- find imputation RMSE
RMSE_notmiwae, x_notmiwae = utils.not_imputationRMSE(notmiwae, Xtrain, Xz, Xnan, S, L)

np.save('x_notmiwae.npy', x_notmiwae)
# Out:
# Creating graph...
# Saving session...
# Saving session...
# 0/20000 updates, 0.32 s, 71853.06 train_loss, 68330.55 val_loss
# Saving session...
# 100/20000 updates, 6.43 s, 3187.53 train_loss, 3112.68 val_loss
# Saving session...
# 200/20000 updates, 6.32 s, 2582.22 train_loss, 2561.13 val_loss
# Saving session...
# 300/20000 updates, 6.36 s, 2196.36 train_loss, 2208.81 val_loss
# Saving session...
# 400/20000 updates, 6.27 s, 1798.92 train_loss, 1822.37 val_loss
# Saving session...
# 500/20000 updates, 6.23 s, 1221.71 train_loss, 1265.61 val_loss
# Saving session...
# 600/20000 updates, 6.24 s, 869.67 train_loss, 800.24 val_loss
# Saving session...
# 700/20000 updates, 6.26 s, 446.78 train_loss, 547.22 val_loss
# Saving session...
# 800/20000 updates, 6.07 s, 323.13 train_loss, 378.07 val_loss
# Saving session...
# 900/20000 updates, 6.13 s, 244.69 train_loss, 254.40 val_loss
# Saving session...
# 1000/20000 updates, 6.72 s, 95.37 train_loss, 131.76 val_loss
# 1100/20000 updates, 4.92 s, 83.74 train_loss, 135.97 val_loss
# Saving session...
# 1200/20000 updates, 5.48 s, -33.76 train_loss, 49.20 val_loss
# Saving session...
# 1300/20000 updates, 5.49 s, 12.65 train_loss, -39.27 val_loss
# Saving session...
# 1400/20000 updates, 5.48 s, -140.61 train_loss, -42.03 val_loss
# Saving session...
# 1500/20000 updates, 4.97 s, -68.87 train_loss, -82.08 val_loss
# Saving session...
# 1600/20000 updates, 5.29 s, 185.51 train_loss, -127.37 val_loss
# 1700/20000 updates, 5.37 s, -184.08 train_loss, -81.75 val_loss
# 1800/20000 updates, 5.35 s, -140.56 train_loss, -81.61 val_loss
# Saving session...
# 1900/20000 updates, 5.02 s, -144.89 train_loss, -129.96 val_loss
# 2000/20000 updates, 5.00 s, 179.96 train_loss, 119.75 val_loss
# 2100/20000 updates, 5.08 s, -83.42 train_loss, -80.79 val_loss
# 2200/20000 updates, 5.88 s, -37.38 train_loss, -100.60 val_loss
# 2300/20000 updates, 5.29 s, -99.20 train_loss, -121.81 val_loss
# 2400/20000 updates, 5.29 s, -164.55 train_loss, -65.51 val_loss
# 2500/20000 updates, 6.14 s, -165.27 train_loss, -77.64 val_loss
# 2600/20000 updates, 5.03 s, -166.48 train_loss, -120.50 val_loss
# 2700/20000 updates, 5.63 s, -129.12 train_loss, -115.29 val_loss
# 2800/20000 updates, 7.11 s, 246.80 train_loss, -56.96 val_loss
# 2900/20000 updates, 6.82 s, -138.90 train_loss, -98.72 val_loss
# 3000/20000 updates, 5.91 s, -101.53 train_loss, -98.29 val_loss
# 3100/20000 updates, 6.01 s, -65.64 train_loss, -88.78 val_loss
# 3200/20000 updates, 6.18 s, -112.63 train_loss, -57.36 val_loss
# 3300/20000 updates, 4.71 s, -20.98 train_loss, -115.45 val_loss
# 3400/20000 updates, 5.57 s, -225.39 train_loss, -117.11 val_loss
# 3500/20000 updates, 5.74 s, -30.42 train_loss, -56.73 val_loss
# 3600/20000 updates, 5.18 s, -84.61 train_loss, -73.29 val_loss
# 3700/20000 updates, 4.97 s, -242.65 train_loss, -66.49 val_loss
# 3800/20000 updates, 5.09 s, 12.57 train_loss, -54.35 val_loss
# 3900/20000 updates, 6.34 s, -189.98 train_loss, -97.04 val_loss
# 4000/20000 updates, 5.19 s, -138.11 train_loss, -108.03 val_loss
# 4100/20000 updates, 5.22 s, -256.63 train_loss, -95.70 val_loss
# 4200/20000 updates, 5.93 s, -33.70 train_loss, 99.47 val_loss
# 4300/20000 updates, 5.97 s, -130.09 train_loss, -81.55 val_loss
# 4400/20000 updates, 6.08 s, -120.66 train_loss, -100.58 val_loss
# 4500/20000 updates, 6.07 s, -221.43 train_loss, -109.37 val_loss
# 4600/20000 updates, 6.07 s, -207.87 train_loss, -118.35 val_loss
# 4700/20000 updates, 5.88 s, -146.08 train_loss, -64.66 val_loss
# 4800/20000 updates, 5.88 s, -100.67 train_loss, -99.39 val_loss
# 4900/20000 updates, 6.24 s, -76.42 train_loss, -70.84 val_loss
# Saving session...
# 5000/20000 updates, 6.10 s, -158.26 train_loss, -139.56 val_loss
# 5100/20000 updates, 6.11 s, -274.95 train_loss, -116.36 val_loss
# Saving session...
# 5200/20000 updates, 6.07 s, -182.59 train_loss, -160.36 val_loss
# 5300/20000 updates, 6.01 s, -140.09 train_loss, -136.30 val_loss
# 5400/20000 updates, 6.02 s, 22.45 train_loss, -38.16 val_loss
# 5500/20000 updates, 5.98 s, -218.93 train_loss, -121.57 val_loss
# 5600/20000 updates, 6.04 s, -158.71 train_loss, -144.73 val_loss
# 5700/20000 updates, 5.88 s, -91.94 train_loss, -131.30 val_loss
# 5800/20000 updates, 5.92 s, -186.85 train_loss, -140.56 val_loss
# Saving session...
# 5900/20000 updates, 5.93 s, -172.92 train_loss, -173.72 val_loss
# 6000/20000 updates, 5.98 s, -153.74 train_loss, -133.59 val_loss
# 6100/20000 updates, 5.87 s, -131.08 train_loss, -127.17 val_loss
# 6200/20000 updates, 5.81 s, -97.53 train_loss, -112.09 val_loss
# 6300/20000 updates, 5.92 s, -107.12 train_loss, -139.10 val_loss
# 6400/20000 updates, 5.84 s, -102.60 train_loss, -155.78 val_loss
# 6500/20000 updates, 5.82 s, -176.02 train_loss, -87.10 val_loss
# 6600/20000 updates, 5.83 s, -140.96 train_loss, -145.92 val_loss
# 6700/20000 updates, 5.77 s, -24.99 train_loss, -80.36 val_loss
# 6800/20000 updates, 5.86 s, -101.20 train_loss, -125.17 val_loss
# 6900/20000 updates, 5.96 s, -117.84 train_loss, -126.83 val_loss
# 7000/20000 updates, 5.53 s, 123.00 train_loss, -136.43 val_loss
# 7100/20000 updates, 5.30 s, -74.00 train_loss, -102.41 val_loss
# 7200/20000 updates, 5.26 s, -112.09 train_loss, -124.05 val_loss
# 7300/20000 updates, 5.05 s, -180.95 train_loss, -134.19 val_loss
# 7400/20000 updates, 5.23 s, -143.34 train_loss, -156.19 val_loss
# 7500/20000 updates, 5.46 s, -97.58 train_loss, -57.89 val_loss
# 7600/20000 updates, 5.71 s, -146.13 train_loss, -149.68 val_loss
# 7700/20000 updates, 4.90 s, -163.61 train_loss, -94.43 val_loss
# 7800/20000 updates, 5.11 s, -164.18 train_loss, -139.87 val_loss
# 7900/20000 updates, 5.32 s, -5.71 train_loss, -104.71 val_loss
# 8000/20000 updates, 5.10 s, 4.14 train_loss, -87.58 val_loss
# 8100/20000 updates, 5.05 s, -121.82 train_loss, -26.50 val_loss
# 8200/20000 updates, 4.75 s, -31.21 train_loss, -150.13 val_loss
# 8300/20000 updates, 4.92 s, -153.84 train_loss, -103.12 val_loss
# 8400/20000 updates, 4.95 s, -105.08 train_loss, -94.97 val_loss
# 8500/20000 updates, 4.97 s, -167.48 train_loss, -163.16 val_loss
# 8600/20000 updates, 4.80 s, -100.77 train_loss, -107.48 val_loss
# 8700/20000 updates, 5.08 s, -198.37 train_loss, -122.13 val_loss
# 8800/20000 updates, 4.91 s, -116.49 train_loss, -151.21 val_loss
# 8900/20000 updates, 5.41 s, -159.80 train_loss, -134.31 val_loss
# 9000/20000 updates, 5.15 s, -166.02 train_loss, -114.74 val_loss
# 9100/20000 updates, 4.90 s, -140.72 train_loss, -80.68 val_loss
# 9200/20000 updates, 5.24 s, -172.19 train_loss, -139.15 val_loss
# 9300/20000 updates, 5.31 s, -17.95 train_loss, -89.35 val_loss
# 9400/20000 updates, 5.08 s, -194.69 train_loss, -157.46 val_loss
# 9500/20000 updates, 5.42 s, -201.85 train_loss, -172.17 val_loss
# 9600/20000 updates, 5.57 s, -23.76 train_loss, -93.33 val_loss
# 9700/20000 updates, 5.25 s, -153.70 train_loss, -159.54 val_loss
# 9800/20000 updates, 5.20 s, -169.26 train_loss, -116.49 val_loss
# 9900/20000 updates, 5.44 s, -113.26 train_loss, -107.20 val_loss
# 10000/20000 updates, 5.55 s, -197.97 train_loss, -141.64 val_loss
# 10100/20000 updates, 5.75 s, -228.53 train_loss, -147.47 val_loss
# 10200/20000 updates, 5.55 s, -38.28 train_loss, -146.52 val_loss
# 10300/20000 updates, 5.46 s, -197.53 train_loss, -166.73 val_loss
# 10400/20000 updates, 5.44 s, -99.23 train_loss, -150.61 val_loss
# 10500/20000 updates, 6.26 s, -142.00 train_loss, -101.87 val_loss
# 10600/20000 updates, 5.67 s, -184.53 train_loss, -134.22 val_loss
# 10700/20000 updates, 6.35 s, -118.43 train_loss, -141.42 val_loss
# 10800/20000 updates, 5.95 s, -256.55 train_loss, -158.32 val_loss
# 10900/20000 updates, 5.94 s, -238.33 train_loss, -128.20 val_loss
# 11000/20000 updates, 6.21 s, -125.59 train_loss, -172.08 val_loss
# 11100/20000 updates, 6.30 s, -123.45 train_loss, -117.32 val_loss
# 11200/20000 updates, 6.43 s, -89.46 train_loss, -81.84 val_loss
# 11300/20000 updates, 6.48 s, -143.95 train_loss, -138.68 val_loss
# 11400/20000 updates, 5.86 s, -166.24 train_loss, -169.38 val_loss
# 11500/20000 updates, 5.73 s, -107.99 train_loss, -165.11 val_loss
# 11600/20000 updates, 6.20 s, -79.87 train_loss, -137.57 val_loss
# 11700/20000 updates, 6.25 s, -211.77 train_loss, -172.63 val_loss
# 11800/20000 updates, 6.39 s, -232.64 train_loss, -116.12 val_loss
# Saving session...
# 11900/20000 updates, 6.37 s, -232.96 train_loss, -186.27 val_loss
# 12000/20000 updates, 5.95 s, -165.19 train_loss, -97.89 val_loss
# 12100/20000 updates, 5.16 s, -137.74 train_loss, -169.80 val_loss
# 12200/20000 updates, 5.36 s, -97.60 train_loss, -72.49 val_loss
# 12300/20000 updates, 5.21 s, -192.64 train_loss, -92.54 val_loss
# 12400/20000 updates, 5.23 s, -154.27 train_loss, -137.17 val_loss
# 12500/20000 updates, 5.90 s, -134.58 train_loss, -174.04 val_loss
# 12600/20000 updates, 6.72 s, -233.79 train_loss, -162.69 val_loss
# 12700/20000 updates, 6.25 s, -131.19 train_loss, -124.61 val_loss
# 12800/20000 updates, 6.26 s, -183.88 train_loss, -130.39 val_loss
# 12900/20000 updates, 6.29 s, -75.99 train_loss, -139.91 val_loss
# 13000/20000 updates, 6.24 s, -108.43 train_loss, -166.21 val_loss
# 13100/20000 updates, 6.34 s, -200.55 train_loss, -135.02 val_loss
# 13200/20000 updates, 6.32 s, -142.60 train_loss, -123.65 val_loss
# 13300/20000 updates, 6.22 s, -82.74 train_loss, -109.84 val_loss
# 13400/20000 updates, 6.35 s, -165.78 train_loss, -150.30 val_loss
# 13500/20000 updates, 6.40 s, 44.57 train_loss, -117.37 val_loss
# 13600/20000 updates, 6.36 s, -59.32 train_loss, -161.70 val_loss
# 13700/20000 updates, 6.14 s, -185.06 train_loss, -126.87 val_loss
# 13800/20000 updates, 6.17 s, -141.57 train_loss, -149.05 val_loss
# 13900/20000 updates, 6.13 s, -80.10 train_loss, -132.28 val_loss
# 14000/20000 updates, 6.42 s, -231.66 train_loss, -163.35 val_loss
# 14100/20000 updates, 6.33 s, -163.09 train_loss, -162.49 val_loss
# 14200/20000 updates, 6.28 s, -141.37 train_loss, -131.55 val_loss
# 14300/20000 updates, 6.31 s, -175.50 train_loss, -175.43 val_loss
# 14400/20000 updates, 6.22 s, -124.28 train_loss, -126.47 val_loss
# 14500/20000 updates, 6.25 s, 39.66 train_loss, -163.83 val_loss
# 14600/20000 updates, 6.22 s, -167.97 train_loss, 33.48 val_loss
# 14700/20000 updates, 6.13 s, -167.42 train_loss, -136.52 val_loss
# 14800/20000 updates, 6.25 s, -137.60 train_loss, -99.03 val_loss
# 14900/20000 updates, 6.38 s, -200.83 train_loss, -133.31 val_loss
# 15000/20000 updates, 6.51 s, -165.87 train_loss, -140.82 val_loss
# 15100/20000 updates, 5.68 s, -113.73 train_loss, -140.30 val_loss
# 15200/20000 updates, 4.97 s, -208.86 train_loss, -134.14 val_loss
# 15300/20000 updates, 5.34 s, 431.50 train_loss, -167.34 val_loss
# 15400/20000 updates, 5.21 s, -191.42 train_loss, -145.59 val_loss
# 15500/20000 updates, 6.39 s, -172.76 train_loss, -66.58 val_loss
# 15600/20000 updates, 6.42 s, -175.82 train_loss, -97.77 val_loss
# 15700/20000 updates, 6.24 s, -161.54 train_loss, -147.68 val_loss
# 15800/20000 updates, 6.21 s, -132.48 train_loss, -140.00 val_loss
# 15900/20000 updates, 6.25 s, -103.76 train_loss, -146.98 val_loss
# 16000/20000 updates, 6.36 s, -150.70 train_loss, -157.53 val_loss
# 16100/20000 updates, 6.23 s, -115.74 train_loss, -114.76 val_loss
# 16200/20000 updates, 6.22 s, -92.73 train_loss, -110.71 val_loss
# 16300/20000 updates, 6.37 s, 100.03 train_loss, -139.46 val_loss
# 16400/20000 updates, 6.23 s, -75.64 train_loss, -152.68 val_loss
# 16500/20000 updates, 6.35 s, -167.20 train_loss, -84.94 val_loss
# 16600/20000 updates, 6.37 s, -184.91 train_loss, -146.71 val_loss
# 16700/20000 updates, 6.06 s, -214.04 train_loss, -148.20 val_loss
# 16800/20000 updates, 6.24 s, -127.16 train_loss, -113.05 val_loss
# 16900/20000 updates, 6.17 s, -133.86 train_loss, -151.56 val_loss
# 17000/20000 updates, 6.26 s, -116.66 train_loss, -137.70 val_loss
# 17100/20000 updates, 6.27 s, -22.26 train_loss, -144.62 val_loss
# 17200/20000 updates, 6.02 s, -104.34 train_loss, -117.86 val_loss
# 17300/20000 updates, 5.94 s, -147.23 train_loss, -109.21 val_loss
# 17400/20000 updates, 6.16 s, -144.01 train_loss, -131.50 val_loss
# 17500/20000 updates, 6.20 s, -221.52 train_loss, -179.57 val_loss
# 17600/20000 updates, 6.25 s, -48.21 train_loss, -101.56 val_loss
# 17700/20000 updates, 6.16 s, 43.44 train_loss, -47.89 val_loss
# 17800/20000 updates, 6.29 s, -58.66 train_loss, -91.52 val_loss
# 17900/20000 updates, 6.21 s, -81.56 train_loss, -101.70 val_loss
# 18000/20000 updates, 6.10 s, -215.99 train_loss, -174.00 val_loss
# 18100/20000 updates, 6.35 s, -88.47 train_loss, -118.51 val_loss
# 18200/20000 updates, 6.25 s, -183.22 train_loss, -129.01 val_loss
# 18300/20000 updates, 6.24 s, -174.39 train_loss, -120.39 val_loss
# 18400/20000 updates, 6.14 s, -109.65 train_loss, -121.44 val_loss
# 18500/20000 updates, 6.07 s, -28.61 train_loss, -134.10 val_loss
# 18600/20000 updates, 6.04 s, -184.50 train_loss, -158.78 val_loss
# 18700/20000 updates, 6.13 s, -108.83 train_loss, -135.82 val_loss
# 18800/20000 updates, 6.27 s, -145.87 train_loss, -152.17 val_loss
# 18900/20000 updates, 6.24 s, -68.79 train_loss, -122.83 val_loss
# 19000/20000 updates, 6.20 s, -145.65 train_loss, -94.26 val_loss
# 19100/20000 updates, 6.26 s, -180.97 train_loss, -106.52 val_loss
# 19200/20000 updates, 6.25 s, -163.56 train_loss, -79.68 val_loss
# 19300/20000 updates, 5.35 s, -28.96 train_loss, -109.96 val_loss
# 19400/20000 updates, 5.41 s, -61.84 train_loss, -146.38 val_loss
# 19500/20000 updates, 6.21 s, -184.57 train_loss, -84.33 val_loss
# 19600/20000 updates, 6.24 s, -134.63 train_loss, -150.11 val_loss
# 19700/20000 updates, 6.26 s, -207.06 train_loss, -108.18 val_loss
# 19800/20000 updates, 6.27 s, -9.98 train_loss, -156.49 val_loss
# 19900/20000 updates, 6.25 s, -76.21 train_loss, -144.46 val_loss
# 0 / 1000
# 100 / 1000
# 200 / 1000
# 300 / 1000
# 400 / 1000
# 500 / 1000
# 600 / 1000
# 700 / 1000
# 800 / 1000
# 900 / 1000

# %%
print("RMSE: {:.3f}".format(RMSE_notmiwae))
# Out:
# RMSE: 0.245

# %%
x_notmiwae = np.load('x_notmiwae.npy')

# %%
x_obs = x_data[mask]
x_miss = x_data[~mask]

x_est = x_notmiwae

x_est_obs = x_est[mask]
x_est_miss = x_est[~mask]

# %%
scatter_compare_individual_entries_panel(x_obs, x_miss, x_est_obs, x_est_miss)

# %%
hist_compare_individual_entries(x_obs, x_miss, x_est_obs, x_est_miss)

# %%
W, b = notmiwae.sess.run([notmiwae.W, notmiwae.b])

# %%
fig, ax = plt.subplots(ncols=1, figsize=(6, 5))

p_obs = detection_prob[mask]
x_obs = x_data[mask]

p_miss = detection_prob[~mask]
x_miss = x_data[~mask]

n = 5_000

ax.scatter(x_miss[:n], p_miss[:n], color="red", alpha=.1, s=2)
ax.scatter(x_obs[:n], p_obs[:n], color="blue", alpha=.1, s=2)
ax.set_title("entry intensity vs detection probability")
ax.set_xlabel("entry intensity")
ax.set_ylabel("detection probability")
ax.grid(True)
ax.set_axisbelow(True)

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

for n in range(W.shape[-1]):
    xs = np.linspace(0, 18, 100)
    logit = W[0, 0, n] * xs + b[0, 0, n]
    ys = sigmoid(logit)
    ax.plot(xs, ys, color="black", alpha=.3, linewidth=4)

# %% [markdown]
# ### not-MIWAE (self-masking known)

# %%
notmiwae = notMIWAE(Xnan, Xval, n_latent=n_latent, n_samples=n_samples, n_hidden=n_hidden, name=name, out_dist=out_dist, mechanism_weight=0.1, missing_process='selfmasking_known')

# ---- do the training
trainer.train(notmiwae, batch_size=batch_size, max_iter=max_iter, name=name + 'notmiwae')

# ---- find imputation RMSE
RMSE_notmiwae, x_notmiwae = utils.not_imputationRMSE(notmiwae, Xtrain, Xz, Xnan, S, L)

np.save('x_notmiwae.npy', x_notmiwae)
# Out:
# Creating graph...
# Saving session...
# Saving session...
# 0/20000 updates, 0.29 s, 71542.34 train_loss, 70965.92 val_loss
# Saving session...
# 100/20000 updates, 6.29 s, 2093.29 train_loss, 2193.36 val_loss
# Saving session...
# 200/20000 updates, 6.07 s, 1747.08 train_loss, 1736.03 val_loss
# Saving session...
# 300/20000 updates, 6.12 s, 1431.29 train_loss, 1428.76 val_loss
# Saving session...
# 400/20000 updates, 6.07 s, 1055.03 train_loss, 1067.60 val_loss
# Saving session...
# 500/20000 updates, 6.39 s, 564.25 train_loss, 557.59 val_loss
# Saving session...
# 600/20000 updates, 5.78 s, 186.07 train_loss, 216.08 val_loss
# Saving session...
# 700/20000 updates, 5.61 s, 58.87 train_loss, 69.70 val_loss
# Saving session...
# 800/20000 updates, 5.85 s, 2.16 train_loss, 13.46 val_loss
# Saving session...
# 900/20000 updates, 6.08 s, -169.05 train_loss, -105.75 val_loss
# 1000/20000 updates, 6.08 s, -140.11 train_loss, -88.71 val_loss
# Saving session...
# 1100/20000 updates, 5.92 s, -32.81 train_loss, -106.08 val_loss
# 1200/20000 updates, 6.07 s, 30.99 train_loss, 15.40 val_loss
# 1300/20000 updates, 5.03 s, -131.89 train_loss, -45.33 val_loss
# 1400/20000 updates, 5.14 s, 130.67 train_loss, -59.60 val_loss
# 1500/20000 updates, 4.70 s, -65.86 train_loss, -56.03 val_loss
# 1600/20000 updates, 5.08 s, -118.66 train_loss, -92.09 val_loss
# 1700/20000 updates, 4.59 s, -125.03 train_loss, -50.32 val_loss
# 1800/20000 updates, 5.18 s, -57.88 train_loss, -99.27 val_loss
# Saving session...
# 1900/20000 updates, 5.21 s, 170.48 train_loss, -136.61 val_loss
# 2000/20000 updates, 5.21 s, -122.79 train_loss, -59.08 val_loss
# 2100/20000 updates, 6.11 s, -81.56 train_loss, -126.07 val_loss
# 2200/20000 updates, 6.10 s, -15.60 train_loss, -128.81 val_loss
# 2300/20000 updates, 6.17 s, -133.94 train_loss, -60.40 val_loss
# 2400/20000 updates, 6.14 s, -84.13 train_loss, -116.16 val_loss
# 2500/20000 updates, 6.24 s, -229.11 train_loss, -126.20 val_loss
# 2600/20000 updates, 6.08 s, -64.49 train_loss, -85.59 val_loss
# 2700/20000 updates, 6.02 s, -98.28 train_loss, -85.01 val_loss
# Saving session...
# 2800/20000 updates, 6.15 s, -158.64 train_loss, -161.91 val_loss
# 2900/20000 updates, 6.19 s, -84.49 train_loss, -86.86 val_loss
# 3000/20000 updates, 6.18 s, -178.77 train_loss, -113.48 val_loss
# 3100/20000 updates, 6.15 s, -94.89 train_loss, -92.83 val_loss
# 3200/20000 updates, 6.25 s, -180.60 train_loss, -139.00 val_loss
# 3300/20000 updates, 6.13 s, -45.99 train_loss, -86.47 val_loss
# 3400/20000 updates, 6.14 s, 138.09 train_loss, -119.46 val_loss
# Saving session...
# 3500/20000 updates, 6.22 s, -90.17 train_loss, -171.88 val_loss
# 3600/20000 updates, 6.20 s, -220.06 train_loss, -140.71 val_loss
# 3700/20000 updates, 6.29 s, -92.08 train_loss, -98.89 val_loss
# 3800/20000 updates, 6.23 s, -112.00 train_loss, -169.51 val_loss
# 3900/20000 updates, 6.10 s, -132.37 train_loss, -101.01 val_loss
# 4000/20000 updates, 6.25 s, -225.88 train_loss, -145.81 val_loss
# 4100/20000 updates, 6.18 s, -108.85 train_loss, -147.15 val_loss
# 4200/20000 updates, 6.17 s, -232.07 train_loss, -145.09 val_loss
# 4300/20000 updates, 6.22 s, -204.42 train_loss, -104.63 val_loss
# 4400/20000 updates, 6.17 s, -244.21 train_loss, -99.95 val_loss
# 4500/20000 updates, 6.18 s, -149.69 train_loss, -113.94 val_loss
# 4600/20000 updates, 6.13 s, 23.16 train_loss, -57.85 val_loss
# 4700/20000 updates, 6.12 s, -203.87 train_loss, -128.71 val_loss
# 4800/20000 updates, 6.27 s, -267.41 train_loss, -167.08 val_loss
# 4900/20000 updates, 6.15 s, -104.24 train_loss, -111.56 val_loss
# 5000/20000 updates, 6.15 s, -65.95 train_loss, -150.11 val_loss
# 5100/20000 updates, 6.18 s, -121.87 train_loss, -133.14 val_loss
# 5200/20000 updates, 6.27 s, 20.45 train_loss, -169.90 val_loss
# 5300/20000 updates, 6.02 s, 86.33 train_loss, -75.36 val_loss
# 5400/20000 updates, 6.38 s, -298.22 train_loss, -155.40 val_loss
# 5500/20000 updates, 6.15 s, -120.26 train_loss, -134.04 val_loss
# 5600/20000 updates, 6.18 s, -187.23 train_loss, -138.95 val_loss
# 5700/20000 updates, 6.01 s, -217.57 train_loss, -129.35 val_loss
# 5800/20000 updates, 6.18 s, -125.91 train_loss, -117.46 val_loss
# 5900/20000 updates, 6.16 s, -170.35 train_loss, -39.53 val_loss
# 6000/20000 updates, 6.14 s, -208.64 train_loss, -105.52 val_loss
# 6100/20000 updates, 6.10 s, -125.26 train_loss, -138.41 val_loss
# 6200/20000 updates, 6.22 s, -163.85 train_loss, -106.43 val_loss
# 6300/20000 updates, 6.27 s, -186.20 train_loss, -92.60 val_loss
# 6400/20000 updates, 6.26 s, -217.92 train_loss, -92.97 val_loss
# 6500/20000 updates, 6.04 s, -144.19 train_loss, -139.34 val_loss
# 6600/20000 updates, 5.61 s, -147.92 train_loss, -119.84 val_loss
# 6700/20000 updates, 4.94 s, -272.94 train_loss, -147.96 val_loss
# Saving session...
# 6800/20000 updates, 4.99 s, -63.55 train_loss, -180.43 val_loss
# 6900/20000 updates, 5.23 s, -235.33 train_loss, -150.19 val_loss
# 7000/20000 updates, 5.26 s, -218.79 train_loss, -128.29 val_loss
# 7100/20000 updates, 5.22 s, -93.76 train_loss, -163.63 val_loss
# 7200/20000 updates, 6.11 s, -96.11 train_loss, -67.81 val_loss
# 7300/20000 updates, 6.12 s, -186.57 train_loss, -120.81 val_loss
# 7400/20000 updates, 5.93 s, -216.53 train_loss, -147.59 val_loss
# 7500/20000 updates, 5.99 s, -191.48 train_loss, -92.12 val_loss
# 7600/20000 updates, 6.05 s, -223.22 train_loss, -124.92 val_loss
# 7700/20000 updates, 5.96 s, -79.14 train_loss, -112.33 val_loss
# 7800/20000 updates, 6.18 s, 128.14 train_loss, 74.55 val_loss
# 7900/20000 updates, 5.98 s, -183.55 train_loss, -119.90 val_loss
# 8000/20000 updates, 6.10 s, -182.38 train_loss, -95.21 val_loss
# 8100/20000 updates, 5.98 s, 53.46 train_loss, -15.50 val_loss
# 8200/20000 updates, 6.07 s, -182.12 train_loss, -168.60 val_loss
# 8300/20000 updates, 5.94 s, -132.56 train_loss, -77.78 val_loss
# 8400/20000 updates, 6.15 s, -99.19 train_loss, -61.77 val_loss
# 8500/20000 updates, 6.00 s, -101.56 train_loss, -40.33 val_loss
# 8600/20000 updates, 6.15 s, -141.10 train_loss, -118.60 val_loss
# 8700/20000 updates, 6.05 s, -220.33 train_loss, -158.92 val_loss
# 8800/20000 updates, 6.08 s, -158.21 train_loss, -164.10 val_loss
# 8900/20000 updates, 6.12 s, -184.34 train_loss, -155.26 val_loss
# 9000/20000 updates, 6.01 s, -209.48 train_loss, -122.87 val_loss
# 9100/20000 updates, 5.95 s, -223.54 train_loss, -124.63 val_loss
# Saving session...
# 9200/20000 updates, 6.12 s, -150.48 train_loss, -189.41 val_loss
# 9300/20000 updates, 6.09 s, -6.38 train_loss, -111.55 val_loss
# 9400/20000 updates, 6.07 s, -72.94 train_loss, -107.16 val_loss
# Saving session...
# 9500/20000 updates, 6.37 s, -163.96 train_loss, -190.82 val_loss
# 9600/20000 updates, 5.22 s, -149.82 train_loss, -80.86 val_loss
# 9700/20000 updates, 5.71 s, -177.05 train_loss, -137.08 val_loss
# 9800/20000 updates, 5.81 s, -178.11 train_loss, -170.14 val_loss
# 9900/20000 updates, 5.13 s, -203.44 train_loss, -163.16 val_loss
# 10000/20000 updates, 4.61 s, -150.39 train_loss, -110.86 val_loss
# 10100/20000 updates, 5.78 s, -171.47 train_loss, -163.97 val_loss
# 10200/20000 updates, 5.04 s, -44.49 train_loss, -76.71 val_loss
# 10300/20000 updates, 4.89 s, -124.39 train_loss, -84.63 val_loss
# 10400/20000 updates, 4.51 s, 31.75 train_loss, -116.65 val_loss
# 10500/20000 updates, 5.15 s, -183.87 train_loss, -146.45 val_loss
# 10600/20000 updates, 4.86 s, -196.61 train_loss, -143.09 val_loss
# 10700/20000 updates, 5.05 s, -94.12 train_loss, -98.41 val_loss
# 10800/20000 updates, 5.06 s, -163.30 train_loss, -122.64 val_loss
# 10900/20000 updates, 5.00 s, -165.42 train_loss, -147.19 val_loss
# 11000/20000 updates, 4.63 s, -162.00 train_loss, -126.02 val_loss
# 11100/20000 updates, 5.14 s, -174.71 train_loss, -86.29 val_loss
# 11200/20000 updates, 5.27 s, -94.94 train_loss, -165.99 val_loss
# 11300/20000 updates, 5.43 s, -148.98 train_loss, -157.62 val_loss
# 11400/20000 updates, 5.83 s, -171.21 train_loss, -150.72 val_loss
# 11500/20000 updates, 5.51 s, -99.78 train_loss, -180.07 val_loss
# 11600/20000 updates, 5.44 s, -92.66 train_loss, -118.59 val_loss
# 11700/20000 updates, 4.92 s, -135.01 train_loss, -131.07 val_loss
# 11800/20000 updates, 4.99 s, -146.86 train_loss, -120.08 val_loss
# 11900/20000 updates, 6.25 s, -255.95 train_loss, -149.31 val_loss
# 12000/20000 updates, 5.01 s, -160.53 train_loss, -167.59 val_loss
# 12100/20000 updates, 5.87 s, -165.99 train_loss, -144.60 val_loss
# 12200/20000 updates, 5.43 s, -167.19 train_loss, -173.52 val_loss
# 12300/20000 updates, 5.61 s, -189.39 train_loss, -127.80 val_loss
# 12400/20000 updates, 5.35 s, -132.34 train_loss, -95.39 val_loss
# 12500/20000 updates, 4.94 s, -85.18 train_loss, -94.95 val_loss
# 12600/20000 updates, 4.74 s, -170.78 train_loss, -127.20 val_loss
# 12700/20000 updates, 4.89 s, 51.14 train_loss, 71.84 val_loss
# 12800/20000 updates, 5.01 s, -122.06 train_loss, -61.06 val_loss
# 12900/20000 updates, 5.17 s, -198.56 train_loss, -146.18 val_loss
# 13000/20000 updates, 5.03 s, -172.64 train_loss, -168.38 val_loss
# 13100/20000 updates, 5.34 s, -93.95 train_loss, -157.46 val_loss
# 13200/20000 updates, 5.54 s, -44.57 train_loss, -140.80 val_loss
# 13300/20000 updates, 5.24 s, -261.49 train_loss, -101.20 val_loss
# 13400/20000 updates, 5.13 s, -223.75 train_loss, -141.81 val_loss
# Saving session...
# 13500/20000 updates, 5.52 s, -187.27 train_loss, -197.53 val_loss
# 13600/20000 updates, 5.22 s, -152.47 train_loss, -83.35 val_loss
# 13700/20000 updates, 5.11 s, -126.26 train_loss, -177.70 val_loss
# 13800/20000 updates, 5.33 s, -107.03 train_loss, -123.59 val_loss
# 13900/20000 updates, 5.49 s, -169.11 train_loss, -155.31 val_loss
# 14000/20000 updates, 5.70 s, -95.00 train_loss, -131.51 val_loss
# 14100/20000 updates, 5.68 s, -210.27 train_loss, -137.53 val_loss
# 14200/20000 updates, 5.76 s, -192.41 train_loss, -163.37 val_loss
# 14300/20000 updates, 5.71 s, -20.01 train_loss, -145.18 val_loss
# 14400/20000 updates, 5.52 s, -34.76 train_loss, -86.20 val_loss
# 14500/20000 updates, 6.13 s, -239.23 train_loss, -141.11 val_loss
# 14600/20000 updates, 6.28 s, -140.58 train_loss, -145.09 val_loss
# 14700/20000 updates, 6.31 s, -286.46 train_loss, -137.13 val_loss
# 14800/20000 updates, 6.24 s, -160.54 train_loss, -168.17 val_loss
# 14900/20000 updates, 6.09 s, -149.69 train_loss, -177.64 val_loss
# 15000/20000 updates, 6.19 s, -123.34 train_loss, -143.80 val_loss
# 15100/20000 updates, 6.15 s, -177.92 train_loss, -133.82 val_loss
# 15200/20000 updates, 6.16 s, -141.22 train_loss, -175.13 val_loss
# 15300/20000 updates, 6.28 s, -0.45 train_loss, -119.30 val_loss
# 15400/20000 updates, 6.14 s, -155.67 train_loss, -133.60 val_loss
# 15500/20000 updates, 6.11 s, -184.43 train_loss, -117.23 val_loss
# 15600/20000 updates, 6.27 s, -89.48 train_loss, -151.49 val_loss
# 15700/20000 updates, 6.15 s, -198.86 train_loss, -130.77 val_loss
# 15800/20000 updates, 6.23 s, -188.02 train_loss, -147.51 val_loss
# 15900/20000 updates, 6.19 s, -184.11 train_loss, -107.34 val_loss
# 16000/20000 updates, 6.05 s, -95.30 train_loss, -94.05 val_loss
# 16100/20000 updates, 6.09 s, -195.87 train_loss, -161.87 val_loss
# 16200/20000 updates, 6.30 s, -209.41 train_loss, -164.32 val_loss
# 16300/20000 updates, 6.29 s, 114.52 train_loss, -165.24 val_loss
# 16400/20000 updates, 6.18 s, -160.08 train_loss, -160.06 val_loss
# 16500/20000 updates, 6.24 s, -173.42 train_loss, -154.68 val_loss
# 16600/20000 updates, 6.12 s, -109.94 train_loss, -99.11 val_loss
# 16700/20000 updates, 5.91 s, -95.94 train_loss, -154.75 val_loss
# 16800/20000 updates, 5.30 s, -183.53 train_loss, -138.21 val_loss
# 16900/20000 updates, 5.95 s, -92.24 train_loss, -79.05 val_loss
# 17000/20000 updates, 5.83 s, -196.89 train_loss, -151.98 val_loss
# 17100/20000 updates, 5.65 s, -13.56 train_loss, -155.50 val_loss
# 17200/20000 updates, 4.83 s, -90.06 train_loss, -67.61 val_loss
# 17300/20000 updates, 4.79 s, -218.61 train_loss, -169.12 val_loss
# 17400/20000 updates, 4.88 s, -149.92 train_loss, -141.12 val_loss
# 17500/20000 updates, 4.83 s, -94.78 train_loss, -128.52 val_loss
# 17600/20000 updates, 5.17 s, -80.60 train_loss, -157.10 val_loss
# 17700/20000 updates, 4.96 s, -137.00 train_loss, -156.47 val_loss
# 17800/20000 updates, 4.85 s, -105.38 train_loss, -128.44 val_loss
# 17900/20000 updates, 5.28 s, -171.21 train_loss, -147.75 val_loss
# 18000/20000 updates, 5.34 s, -109.23 train_loss, -108.36 val_loss
# 18100/20000 updates, 5.83 s, -150.64 train_loss, -112.20 val_loss
# 18200/20000 updates, 6.00 s, -184.55 train_loss, -166.61 val_loss
# 18300/20000 updates, 6.00 s, -193.14 train_loss, -112.97 val_loss
# 18400/20000 updates, 6.09 s, -111.01 train_loss, -103.29 val_loss
# 18500/20000 updates, 6.16 s, -198.58 train_loss, -104.62 val_loss
# 18600/20000 updates, 6.06 s, -212.62 train_loss, -149.80 val_loss
# 18700/20000 updates, 6.08 s, -69.78 train_loss, -168.49 val_loss
# 18800/20000 updates, 6.15 s, -188.71 train_loss, -95.76 val_loss
# 18900/20000 updates, 6.02 s, -128.96 train_loss, -127.57 val_loss
# 19000/20000 updates, 6.06 s, -107.52 train_loss, -163.08 val_loss
# 19100/20000 updates, 6.04 s, -236.35 train_loss, -159.31 val_loss
# 19200/20000 updates, 6.00 s, -87.95 train_loss, -126.78 val_loss
# 19300/20000 updates, 5.97 s, -18.01 train_loss, 14.15 val_loss
# 19400/20000 updates, 6.05 s, -174.71 train_loss, -145.05 val_loss
# 19500/20000 updates, 6.09 s, -26.53 train_loss, -154.29 val_loss
# 19600/20000 updates, 5.93 s, -175.24 train_loss, -141.76 val_loss
# 19700/20000 updates, 6.04 s, -133.37 train_loss, -163.87 val_loss
# 19800/20000 updates, 6.00 s, -223.21 train_loss, -167.11 val_loss
# 19900/20000 updates, 6.02 s, -53.68 train_loss, -118.63 val_loss
# 0 / 1000
# 100 / 1000
# 200 / 1000
# 300 / 1000
# 400 / 1000
# 500 / 1000
# 600 / 1000
# 700 / 1000
# 800 / 1000
# 900 / 1000

# %%
print("RMSE: {:.3f}".format(RMSE_notmiwae))
# Out:
# RMSE: 0.190

# %%
x_notmiwae = np.load('x_notmiwae.npy')

# %%
x_obs = x_data[mask]
x_miss = x_data[~mask]

x_est = x_notmiwae

x_est_obs = x_est[mask]
x_est_miss = x_est[~mask]

# %%
scatter_compare_individual_entries_panel(x_obs, x_miss, x_est_obs, x_est_miss)

# %%
hist_compare_individual_entries(x_obs, x_miss, x_est_obs, x_est_miss)
