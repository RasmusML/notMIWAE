# %% [markdown]
# # Single-cell Proteomics Synthetic Data Generation

# %% [markdown]
# The goal of this notebook is to simulate a crude single-cell proteomics datasets with a MNAR mechanism, and show that not-MIWAE performs better than MIWAE.

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

from MIWAE import MIWAE
from notMIWAE import notMIWAE
import trainer
import utils

np.random.seed(42)
# Out:
# 2023-11-21 20:36:58.327498: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-11-21 20:36:58.388085: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-21 20:36:58.755617: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-21 20:36:58.755662: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-21 20:36:58.756572: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-21 20:36:58.932519: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-21 20:36:58.935147: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-21 20:37:01.413930: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# Plotting functions for later.

# %%
def scatter_compare_individual_entries_panel(x_obs, x_miss, x_est_obs, x_est_miss):
    fig, axes = plt.subplots(ncols=2, figsize=(12, 5))
    
    ax = axes[0]
    ax.scatter(x_obs, x_est_obs, s=1, alpha=0.1)
    lims = [np.min([ax.get_xlim(), ax.get_ylim()]), np.max([ax.get_xlim(), ax.get_ylim()])]
    ax.plot(lims, lims, "--", c="k")

    mse = np.mean((x_obs - x_est_obs)**2)
    ax.text(0.05, 0.95, f"MSE: {mse:.2f}", transform=ax.transAxes, fontsize=12, verticalalignment="top", bbox=dict(facecolor="white", alpha=0.8))

    ax.set_xlabel("Observed")
    ax.set_ylabel("Imputed")
    ax.set_title("Observed")
    ax.grid(True)
    ax.set_axisbelow(True)

    ax = axes[1]
    ax.scatter(x_miss, x_est_miss, s=1, alpha=0.1)
    lims = [np.min([ax.get_xlim(), ax.get_ylim()]), np.max([ax.get_xlim(), ax.get_ylim()])]
    ax.plot(lims, lims, "--", c="k")

    mse = np.mean((x_miss - x_est_miss)**2)
    ax.text(0.05, 0.95, f"MSE: {mse:.2f}", transform=ax.transAxes, fontsize=12, verticalalignment="top", bbox=dict(facecolor="white", alpha=0.8))

    ax.set_xlabel("Observed")
    ax.set_ylabel("Imputed")
    ax.set_title("Missing")
    ax.grid(True)

# %%
def hist_compare_individual_entries(x_obs, x_miss, x_est_obs, x_est_miss):
    fig, axes = plt.subplots(ncols=2, figsize=(12, 5))

    x_min = np.min([np.min(x_obs), np.min(x_miss), np.min(x_est_obs), np.min(x_est_miss)])
    x_max = np.max([np.max(x_obs), np.max(x_miss), np.max(x_est_obs), np.max(x_est_miss)])

    ax = axes[0]
    ax.hist([x_obs, x_miss], color=["blue", "red"], bins=50, edgecolor="black", linewidth=1.2, stacked=True)
    ax.set_title("Data")
    ax.set_xlabel("x")
    ax.set_ylabel("(stacked) count")
    ax.set_xlim(x_min, x_max)
    ax.grid(True)
    ax.set_axisbelow(True)
    ax.legend(labels=["$x_{obs}$", "$x_{miss}$"], fontsize=12)

    ax = axes[1]
    ax.hist([x_est_obs, x_est_miss], color=["blue", "red"], bins=50, edgecolor="black", linewidth=1.2, stacked=True)
    ax.set_title("Model")
    ax.set_xlabel("x")
    ax.set_ylabel("(stacked) count")
    ax.set_xlim(x_min, x_max)
    ax.grid(True)
    ax.set_axisbelow(True)
    ax.legend(labels=["$x_{obs}$", "$x_{miss}$"], fontsize=12)

# %% [markdown]
# ## Data generation

# %% [markdown]
# Let's start by generating the synthetic data and visualizing it.

# %%
def logistic(x, k=1, x0=0, L=1):
    return L / (1 + np.exp(-k * (x - x0)))

def sigmoid(x):
    return 1 / (1 + np.exp(-x))


def simulate_data(n_cells=1000, n_proteins=5000):
    # all cells are from the same group (cell-type)
    # the cell type has some protein distribution / signature
    cell_type_signature = np.random.uniform(5, 12, n_proteins)

    # each cell is a bit different
    cell_variation = np.random.normal(0, 1, n_cells)

    intensity = cell_type_signature.reshape(1, -1) + cell_variation.reshape(-1, 1)

    # the measurement is noisy
    x = np.random.normal(intensity, 0.1)

    # MNAR mechanism: self-masking (x -> m)
    # entries with low intensity are less likely to be sampled
    #detection_prob = logistic(x, k=2, x0=7) # set x0=6, if you want less missing values
    detection_prob = sigmoid(2*x - 14)

    # sample using a bernoulli distribution
    mask = np.random.binomial(1, detection_prob)
    mask = mask.astype(bool)

    return x, detection_prob, mask

# %% [markdown]
# Let's simulate some data:

# %%
x_data, detection_prob, mask = simulate_data()

# %%
x_nan = x_data.copy()
x_nan[~mask] = np.nan

x_0 = x_data.copy()
x_0[~mask] = 0

# %%
print("Missing entries: {:.2f}%".format(np.isnan(x_nan).sum() / x_nan.size * 100))
# Out:
# Missing entries: 30.26%

# %% [markdown]
# Let's plot the data. "White" are the missing values.

# %%
fig, ax = plt.subplots(figsize=(8, 5))
sns.heatmap(x_nan, cmap="viridis", xticklabels=False, yticklabels=False, ax=ax)
ax.set_xlabel("Proteins")
ax.set_ylabel("Cells")
ax.set_title("Expression matrix with missing values")
# Out:
# Text(0.5, 1.0, 'Expression matrix with missing values')

# %% [markdown]
# Let's look at the missigness pattern entry-wise and protein-wise:

# %%
fig, axes = plt.subplots(ncols=2, figsize=(12, 5))

# plot entry intensity vs detection probability
ax = axes[0]

p_obs = detection_prob[mask]
x_obs = x_data[mask]

p_miss = detection_prob[~mask]
x_miss = x_data[~mask]

n = 5_000

ax.scatter(x_miss[:n], p_miss[:n], color="red", alpha=.1, s=4)
ax.scatter(x_obs[:n], p_obs[:n], color="blue", alpha=.1, s=4)
ax.set_title("entry intensity vs detection probability")
ax.set_xlabel("entry intensity")
ax.set_ylabel("detection probability")
ax.grid(True)
ax.set_axisbelow(True)

# plot the average protein intensity vs the detection proportion
ax = axes[1]
x_obs_protein = np.nanmean(x_nan, axis=0)
p_protein = 1 - np.nanmean(np.isnan(x_nan), axis=0)

ax.scatter(x_obs_protein, p_protein, color="blue", alpha=1, s=6)
ax.set_title("avg protein intensity vs detection proportion")
ax.set_xlabel("protein intensity")
ax.set_ylabel("detection proportion")
ax.grid(True)
ax.set_axisbelow(True)

# %%
fig, ax = plt.subplots(1, 1, figsize=(5, 5))

ax.hist([x_obs, x_miss], color=["blue", "red"], bins=50, edgecolor="black", linewidth=1.2, stacked=True)
ax.set_title("Data")
ax.set_xlabel("x")
ax.set_ylabel("(stacked) count")
ax.set_xlim(np.min(x_data), np.max(x_data))
ax.grid(True)
ax.set_axisbelow(True)
ax.legend(labels=["$x_{obs}$", "$x_{miss}$"], fontsize=12)

# %% [markdown]
# ## Model Comparison

# %% [markdown]
# Set the parameters for the models.

# %%
name = '/tmp/best'

# model specification
n_hidden = 128
n_samples = 20
n_latent = 16
out_dist='gauss'

# training
max_iter = 10_000
batch_size = 64

# imputation
L = 1000

# %% [markdown]
# Let's run.

# %%
N, D = x_data.shape

Xtrain = x_data.copy()
Xval_org = x_data.copy()

Xnan = x_nan.copy()
Xz = x_0.copy()
S = mask.copy()

Xval = x_nan.copy()
Xvalz = x_0.copy()

# %%
tf.compat.v1.disable_eager_execution()

# %% [markdown]
# ### MIWAE

# %%
miwae = MIWAE(Xnan, Xval, n_latent=n_latent, n_samples=n_samples, n_hidden=n_hidden, name=name, out_dist=out_dist)

# ---- do the training
trainer.train(miwae, batch_size=batch_size, max_iter=max_iter, name=name + 'miwae')

# ---- find imputation RMSE
RMSE_miwae, x_miwae = utils.imputationRMSE(miwae, Xtrain, Xz, Xnan, S, L)

np.save('x_miwae.npy', x_miwae)
# Out:
# Creating graph...
# 2023-11-21 20:37:13.688398: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:382] MLIR V1 optimization pass is not enabled
# Saving session...
# Saving session...
# 0/10000 updates, 0.47 s, 351783.25 train_loss, 345197.53 val_loss
# Saving session...
# 100/10000 updates, 16.13 s, 11636.65 train_loss, 10696.65 val_loss
# Saving session...
# 200/10000 updates, 13.92 s, 8450.12 train_loss, 8351.88 val_loss
# Saving session...
# 300/10000 updates, 13.33 s, 7003.68 train_loss, 7063.51 val_loss
# Saving session...
# 400/10000 updates, 12.93 s, 5388.76 train_loss, 5493.37 val_loss
# Saving session...
# 500/10000 updates, 12.80 s, 2944.92 train_loss, 3047.20 val_loss
# Saving session...
# 600/10000 updates, 12.93 s, 1551.92 train_loss, 1422.40 val_loss
# Saving session...
# 700/10000 updates, 12.84 s, -28.80 train_loss, 573.85 val_loss
# Saving session...
# 800/10000 updates, 13.13 s, -541.81 train_loss, -416.50 val_loss
# 900/10000 updates, 12.79 s, 326.42 train_loss, 678.26 val_loss
# Saving session...
# 1000/10000 updates, 11.54 s, -984.67 train_loss, -534.84 val_loss
# Saving session...
# 1100/10000 updates, 12.70 s, -1001.55 train_loss, -609.21 val_loss
# 1200/10000 updates, 11.79 s, -1177.79 train_loss, -512.74 val_loss
# 1300/10000 updates, 11.28 s, -1112.57 train_loss, -602.66 val_loss
# Saving session...
# 1400/10000 updates, 11.67 s, -1124.32 train_loss, -728.35 val_loss
# 1500/10000 updates, 11.41 s, -859.83 train_loss, -635.26 val_loss
# 1600/10000 updates, 11.61 s, -401.77 train_loss, -557.00 val_loss
# 1700/10000 updates, 11.63 s, 633.12 train_loss, -657.10 val_loss
# 1800/10000 updates, 11.37 s, -670.84 train_loss, -660.24 val_loss
# 1900/10000 updates, 11.42 s, -962.34 train_loss, -491.19 val_loss
# 2000/10000 updates, 11.66 s, 50.91 train_loss, -648.12 val_loss
# Saving session...
# 2100/10000 updates, 13.90 s, -1006.34 train_loss, -767.28 val_loss
# 2200/10000 updates, 14.22 s, -641.76 train_loss, -674.40 val_loss
# Saving session...
# 2300/10000 updates, 13.97 s, -1397.85 train_loss, -910.28 val_loss
# 2400/10000 updates, 13.88 s, 31.61 train_loss, 148.09 val_loss
# 2500/10000 updates, 13.84 s, -1010.83 train_loss, -780.79 val_loss
# Saving session...
# 2600/10000 updates, 13.64 s, -1358.07 train_loss, -1017.78 val_loss
# 2700/10000 updates, 14.60 s, -992.03 train_loss, -535.61 val_loss
# 2800/10000 updates, 15.15 s, -932.69 train_loss, -603.95 val_loss
# 2900/10000 updates, 15.13 s, -648.83 train_loss, -865.31 val_loss
# 3000/10000 updates, 14.95 s, -1135.13 train_loss, -920.30 val_loss
# 3100/10000 updates, 14.99 s, -922.49 train_loss, -806.10 val_loss
# 3200/10000 updates, 15.02 s, -189.90 train_loss, -842.20 val_loss
# 3300/10000 updates, 15.05 s, -642.83 train_loss, -936.88 val_loss
# 3400/10000 updates, 14.74 s, -972.81 train_loss, -910.28 val_loss
# 3500/10000 updates, 14.57 s, 1952.76 train_loss, -211.83 val_loss
# 3600/10000 updates, 14.76 s, -1213.12 train_loss, -888.76 val_loss
# 3700/10000 updates, 14.95 s, -509.13 train_loss, -420.79 val_loss
# 3800/10000 updates, 14.93 s, -1305.64 train_loss, -889.35 val_loss
# 3900/10000 updates, 15.00 s, -849.30 train_loss, -729.50 val_loss
# 4000/10000 updates, 14.94 s, -660.34 train_loss, -716.86 val_loss
# 4100/10000 updates, 14.95 s, -862.22 train_loss, -987.15 val_loss
# 4200/10000 updates, 14.95 s, -1233.97 train_loss, -895.58 val_loss
# 4300/10000 updates, 15.05 s, -904.78 train_loss, -713.43 val_loss
# 4400/10000 updates, 14.98 s, -1093.38 train_loss, -810.68 val_loss
# 4500/10000 updates, 14.84 s, -582.45 train_loss, -944.46 val_loss
# 4600/10000 updates, 14.90 s, -814.66 train_loss, -833.57 val_loss
# 4700/10000 updates, 14.91 s, -430.11 train_loss, -795.54 val_loss
# 4800/10000 updates, 15.00 s, -1163.59 train_loss, -905.37 val_loss
# 4900/10000 updates, 14.94 s, -1463.68 train_loss, -842.91 val_loss
# 5000/10000 updates, 15.06 s, -686.78 train_loss, -842.87 val_loss
# 5100/10000 updates, 14.45 s, -1063.76 train_loss, -890.60 val_loss
# 5200/10000 updates, 14.49 s, -484.34 train_loss, -858.73 val_loss
# 5300/10000 updates, 14.96 s, -1677.71 train_loss, -802.24 val_loss
# 5400/10000 updates, 14.79 s, -854.94 train_loss, -642.52 val_loss
# 5500/10000 updates, 14.98 s, -516.10 train_loss, -838.23 val_loss
# 5600/10000 updates, 14.96 s, -623.91 train_loss, -816.89 val_loss
# 5700/10000 updates, 14.93 s, -560.64 train_loss, -836.55 val_loss
# 5800/10000 updates, 14.88 s, -889.32 train_loss, -729.27 val_loss
# 5900/10000 updates, 15.04 s, 326.97 train_loss, -508.48 val_loss
# 6000/10000 updates, 14.99 s, -1306.60 train_loss, -715.66 val_loss
# 6100/10000 updates, 14.84 s, -555.83 train_loss, -823.71 val_loss
# 6200/10000 updates, 14.98 s, -1456.78 train_loss, -677.83 val_loss
# 6300/10000 updates, 15.02 s, -835.50 train_loss, -976.93 val_loss
# 6400/10000 updates, 14.79 s, -612.90 train_loss, -835.67 val_loss
# 6500/10000 updates, 14.83 s, -69.19 train_loss, -164.08 val_loss
# 6600/10000 updates, 14.61 s, -1137.27 train_loss, -838.58 val_loss
# 6700/10000 updates, 14.95 s, -1010.04 train_loss, -944.70 val_loss
# 6800/10000 updates, 15.05 s, -517.03 train_loss, -812.53 val_loss
# 6900/10000 updates, 14.82 s, -363.43 train_loss, -584.83 val_loss
# 7000/10000 updates, 14.81 s, -1075.52 train_loss, -861.83 val_loss
# 7100/10000 updates, 14.94 s, -1035.37 train_loss, -520.95 val_loss
# 7200/10000 updates, 14.94 s, -839.53 train_loss, -910.46 val_loss
# 7300/10000 updates, 15.02 s, -996.85 train_loss, -914.12 val_loss
# 7400/10000 updates, 14.97 s, -830.43 train_loss, -932.33 val_loss
# 7500/10000 updates, 14.67 s, -1454.63 train_loss, -743.49 val_loss
# 7600/10000 updates, 14.40 s, -550.39 train_loss, -671.73 val_loss
# 7700/10000 updates, 13.47 s, -1092.29 train_loss, -767.06 val_loss
# 7800/10000 updates, 11.66 s, -602.24 train_loss, -729.53 val_loss
# 7900/10000 updates, 12.57 s, -872.84 train_loss, -640.03 val_loss
# 8000/10000 updates, 11.42 s, -1237.58 train_loss, -772.40 val_loss
# 8100/10000 updates, 11.50 s, -762.45 train_loss, -851.43 val_loss
# 8200/10000 updates, 11.36 s, -687.36 train_loss, -899.12 val_loss
# 8300/10000 updates, 11.42 s, -1277.05 train_loss, -916.02 val_loss
# 8400/10000 updates, 11.37 s, -342.95 train_loss, -393.57 val_loss
# 8500/10000 updates, 11.53 s, -1374.71 train_loss, -900.86 val_loss
# 8600/10000 updates, 12.47 s, -776.21 train_loss, -802.74 val_loss
# 8700/10000 updates, 11.81 s, -1515.11 train_loss, -918.85 val_loss
# 8800/10000 updates, 12.35 s, -930.41 train_loss, -889.92 val_loss
# 8900/10000 updates, 13.67 s, -1334.68 train_loss, -851.50 val_loss
# 9000/10000 updates, 13.48 s, -1239.40 train_loss, -732.50 val_loss
# 9100/10000 updates, 13.38 s, -1109.41 train_loss, -882.82 val_loss
# 9200/10000 updates, 13.22 s, -487.55 train_loss, -825.22 val_loss
# 9300/10000 updates, 13.41 s, -889.99 train_loss, -829.47 val_loss
# 9400/10000 updates, 12.56 s, -890.81 train_loss, -699.28 val_loss
# 9500/10000 updates, 12.98 s, -248.09 train_loss, -728.59 val_loss
# 9600/10000 updates, 13.21 s, -824.94 train_loss, -946.81 val_loss
# 9700/10000 updates, 13.66 s, -836.15 train_loss, -880.48 val_loss
# 9800/10000 updates, 14.04 s, -736.49 train_loss, -869.33 val_loss
# 9900/10000 updates, 14.04 s, -1207.14 train_loss, -971.60 val_loss
# 0 / 1000
# 100 / 1000
# 200 / 1000
# 300 / 1000
# 400 / 1000
# 500 / 1000
# 600 / 1000
# 700 / 1000
# 800 / 1000
# 900 / 1000

# %%
print("RMSE: {:.3f}".format(RMSE_miwae))
# Out:
# RMSE: 0.170

# %%
x_miwae = np.load('x_miwae.npy')

# %%
x_obs = x_data[mask]
x_miss = x_data[~mask]

x_est = x_miwae

x_est_obs = x_est[mask]
x_est_miss = x_est[~mask]

# %%
scatter_compare_individual_entries_panel(x_obs, x_miss, x_est_obs, x_est_miss)

# %%
hist_compare_individual_entries(x_obs, x_miss, x_est_obs, x_est_miss)

# %% [markdown]
# ### not-MIWAE (self-masking)

# %%
notmiwae = notMIWAE(Xnan, Xval, n_latent=n_latent, n_samples=n_samples, n_hidden=n_hidden, name=name, out_dist=out_dist, mechanism_weight=0.1, missing_process='selfmasking')

# ---- do the training
trainer.train(notmiwae, batch_size=batch_size, max_iter=max_iter, name=name + 'notmiwae')

# ---- find imputation RMSE
RMSE_notmiwae, x_notmiwae = utils.not_imputationRMSE(notmiwae, Xtrain, Xz, Xnan, S, L)

np.save('x_notmiwae.npy', x_notmiwae)
# Out:
# Creating graph...
# Saving session...
# Saving session...
# 0/10000 updates, 0.41 s, 355496.94 train_loss, 340210.93 val_loss
# Saving session...
# 100/10000 updates, 23.97 s, 12452.38 train_loss, 12873.72 val_loss
# Saving session...
# 200/10000 updates, 24.09 s, 10390.18 train_loss, 10242.70 val_loss
# Saving session...
# 300/10000 updates, 24.01 s, 8434.74 train_loss, 8551.45 val_loss
# Saving session...
# 400/10000 updates, 23.97 s, 6545.01 train_loss, 6428.45 val_loss
# Saving session...
# 500/10000 updates, 23.94 s, 3769.51 train_loss, 3630.21 val_loss
# Saving session...
# 600/10000 updates, 23.87 s, 1453.36 train_loss, 1669.99 val_loss
# Saving session...
# 700/10000 updates, 23.91 s, -36.19 train_loss, 455.28 val_loss
# Saving session...
# 800/10000 updates, 23.86 s, -100.12 train_loss, 101.89 val_loss
# Saving session...
# 900/10000 updates, 23.79 s, -603.07 train_loss, 32.99 val_loss
# Saving session...
# 1000/10000 updates, 23.93 s, -312.28 train_loss, -242.82 val_loss
# Saving session...
# 1100/10000 updates, 23.83 s, -179.57 train_loss, -287.23 val_loss
# Saving session...
# 1200/10000 updates, 23.84 s, -953.60 train_loss, -385.39 val_loss
# 1300/10000 updates, 23.83 s, -470.34 train_loss, -143.39 val_loss
# Saving session...
# 1400/10000 updates, 23.71 s, 116.30 train_loss, -413.32 val_loss
# 1500/10000 updates, 23.92 s, -254.18 train_loss, -268.52 val_loss
# 1600/10000 updates, 23.71 s, -8.95 train_loss, -313.72 val_loss
# 1700/10000 updates, 23.75 s, -269.84 train_loss, -268.46 val_loss
# Saving session...
# 1800/10000 updates, 23.79 s, -211.01 train_loss, -501.74 val_loss
# 1900/10000 updates, 23.80 s, -808.12 train_loss, -436.05 val_loss
# Saving session...
# 2000/10000 updates, 23.74 s, -716.84 train_loss, -529.79 val_loss
# 2100/10000 updates, 23.97 s, -690.98 train_loss, -430.72 val_loss
# 2200/10000 updates, 23.74 s, -306.73 train_loss, -410.79 val_loss
# 2300/10000 updates, 23.83 s, -428.02 train_loss, -289.32 val_loss
# 2400/10000 updates, 24.22 s, -467.01 train_loss, -488.19 val_loss
# 2500/10000 updates, 20.04 s, -501.78 train_loss, -488.75 val_loss
# Saving session...
# 2600/10000 updates, 19.07 s, -899.46 train_loss, -574.22 val_loss
# 2700/10000 updates, 19.33 s, -390.54 train_loss, -481.70 val_loss
# 2800/10000 updates, 20.12 s, -653.42 train_loss, -532.90 val_loss
# 2900/10000 updates, 23.95 s, -989.48 train_loss, -549.84 val_loss
# Saving session...
# 3000/10000 updates, 22.35 s, -549.98 train_loss, -639.27 val_loss
# 3100/10000 updates, 19.18 s, -602.58 train_loss, -489.62 val_loss
# 3200/10000 updates, 19.18 s, -891.96 train_loss, -454.11 val_loss
# 3300/10000 updates, 20.16 s, -375.17 train_loss, -594.67 val_loss
# 3400/10000 updates, 22.55 s, -868.43 train_loss, -580.17 val_loss
# 3500/10000 updates, 22.31 s, -316.47 train_loss, -230.95 val_loss
# Saving session...
# 3600/10000 updates, 22.19 s, -767.79 train_loss, -701.43 val_loss
# 3700/10000 updates, 21.58 s, -843.21 train_loss, -465.62 val_loss
# 3800/10000 updates, 20.99 s, -472.33 train_loss, -378.58 val_loss
# 3900/10000 updates, 22.19 s, -1028.27 train_loss, -607.33 val_loss
# 4000/10000 updates, 22.23 s, -1033.39 train_loss, -585.40 val_loss
# 4100/10000 updates, 22.38 s, -521.89 train_loss, -516.06 val_loss
# 4200/10000 updates, 22.30 s, -657.80 train_loss, 16.03 val_loss
# 4300/10000 updates, 22.25 s, -609.45 train_loss, -384.07 val_loss
# 4400/10000 updates, 22.33 s, -689.24 train_loss, -599.47 val_loss
# 4500/10000 updates, 22.21 s, -184.35 train_loss, -597.35 val_loss
# 4600/10000 updates, 22.38 s, -622.42 train_loss, -673.96 val_loss
# 4700/10000 updates, 22.43 s, -575.83 train_loss, -681.18 val_loss
# Saving session...
# 4800/10000 updates, 22.33 s, -1123.44 train_loss, -785.90 val_loss
# 4900/10000 updates, 22.46 s, -1188.28 train_loss, -681.09 val_loss
# 5000/10000 updates, 22.43 s, -324.88 train_loss, -109.53 val_loss
# 5100/10000 updates, 22.47 s, -570.80 train_loss, -512.65 val_loss
# 5200/10000 updates, 22.52 s, -469.18 train_loss, -705.48 val_loss
# 5300/10000 updates, 22.45 s, -717.81 train_loss, -669.18 val_loss
# 5400/10000 updates, 22.40 s, -725.76 train_loss, -437.14 val_loss
# 5500/10000 updates, 22.41 s, -434.04 train_loss, -688.18 val_loss
# 5600/10000 updates, 22.50 s, -214.01 train_loss, -245.35 val_loss
# 5700/10000 updates, 22.47 s, -966.94 train_loss, -617.89 val_loss
# 5800/10000 updates, 22.41 s, -579.38 train_loss, -422.96 val_loss
# 5900/10000 updates, 22.36 s, -140.04 train_loss, -377.96 val_loss
# 6000/10000 updates, 22.48 s, -1108.65 train_loss, -659.13 val_loss
# 6100/10000 updates, 22.43 s, -769.23 train_loss, -705.70 val_loss
# 6200/10000 updates, 22.37 s, -391.36 train_loss, -413.30 val_loss
# 6300/10000 updates, 22.33 s, -986.46 train_loss, -688.99 val_loss
# 6400/10000 updates, 22.35 s, -967.04 train_loss, -597.15 val_loss
# 6500/10000 updates, 22.43 s, -527.90 train_loss, -751.49 val_loss
# 6600/10000 updates, 22.42 s, -168.31 train_loss, -665.59 val_loss
# 6700/10000 updates, 22.47 s, -908.14 train_loss, -599.48 val_loss
# 6800/10000 updates, 22.44 s, -581.89 train_loss, -554.47 val_loss
# 6900/10000 updates, 22.42 s, -262.48 train_loss, -709.28 val_loss
# 7000/10000 updates, 22.38 s, -960.26 train_loss, -667.27 val_loss
# 7100/10000 updates, 22.48 s, -668.31 train_loss, -678.64 val_loss
# 7200/10000 updates, 22.36 s, -1156.95 train_loss, -750.64 val_loss
# 7300/10000 updates, 22.43 s, -321.86 train_loss, -580.43 val_loss
# 7400/10000 updates, 22.34 s, -529.74 train_loss, -185.13 val_loss
# 7500/10000 updates, 22.34 s, -621.55 train_loss, -714.74 val_loss
# 7600/10000 updates, 22.27 s, -917.38 train_loss, -480.19 val_loss
# 7700/10000 updates, 22.37 s, -684.19 train_loss, -533.74 val_loss
# 7800/10000 updates, 22.28 s, -346.31 train_loss, -671.94 val_loss
# Saving session...
# 7900/10000 updates, 22.25 s, -750.69 train_loss, -790.06 val_loss
# 8000/10000 updates, 22.37 s, -1057.19 train_loss, -569.16 val_loss
# Saving session...
# 8100/10000 updates, 22.35 s, -648.50 train_loss, -791.62 val_loss
# 8200/10000 updates, 22.70 s, -583.24 train_loss, -699.03 val_loss
# 8300/10000 updates, 22.17 s, -430.36 train_loss, -535.46 val_loss
# 8400/10000 updates, 22.28 s, -1031.93 train_loss, -648.35 val_loss
# 8500/10000 updates, 21.89 s, -402.91 train_loss, -541.79 val_loss
# 8600/10000 updates, 23.41 s, -972.90 train_loss, -717.97 val_loss
# 8700/10000 updates, 22.79 s, -704.99 train_loss, -446.73 val_loss
# 8800/10000 updates, 22.45 s, -751.11 train_loss, -719.40 val_loss
# 8900/10000 updates, 22.52 s, -732.84 train_loss, -446.40 val_loss
# 9000/10000 updates, 22.47 s, -442.55 train_loss, -750.37 val_loss
# 9100/10000 updates, 22.51 s, -398.27 train_loss, -574.06 val_loss
# 9200/10000 updates, 22.47 s, -901.93 train_loss, -652.22 val_loss
# Saving session...
# 9300/10000 updates, 22.39 s, -228.81 train_loss, -833.39 val_loss
# 9400/10000 updates, 22.54 s, -418.04 train_loss, -468.36 val_loss
# Saving session...
# 9500/10000 updates, 22.44 s, -1301.99 train_loss, -862.11 val_loss
# 9600/10000 updates, 22.59 s, -684.28 train_loss, -835.11 val_loss
# 9700/10000 updates, 22.50 s, -998.98 train_loss, -594.59 val_loss
# 9800/10000 updates, 22.47 s, -584.07 train_loss, -555.34 val_loss
# 9900/10000 updates, 22.42 s, -504.08 train_loss, -827.10 val_loss
# 0 / 1000
# 100 / 1000
# 200 / 1000
# 300 / 1000
# 400 / 1000
# 500 / 1000
# 600 / 1000
# 700 / 1000
# 800 / 1000
# 900 / 1000

# %%
print("RMSE: {:.3f}".format(RMSE_notmiwae))
# Out:
# RMSE: 0.161

# %%
x_notmiwae = np.load('x_notmiwae.npy')

# %%
x_obs = x_data[mask]
x_miss = x_data[~mask]

x_est = x_notmiwae

x_est_obs = x_est[mask]
x_est_miss = x_est[~mask]

# %%
scatter_compare_individual_entries_panel(x_obs, x_miss, x_est_obs, x_est_miss)

# %%
hist_compare_individual_entries(x_obs, x_miss, x_est_obs, x_est_miss)

# %%
W, b = notmiwae.sess.run([notmiwae.W, notmiwae.b])

# %%
fig, ax = plt.subplots(ncols=1, figsize=(6, 5))

p_obs = detection_prob[mask]
x_obs = x_data[mask]

p_miss = detection_prob[~mask]
x_miss = x_data[~mask]

n = 5_000

ax.scatter(x_miss[:n], p_miss[:n], color="red", alpha=.1, s=2)
ax.scatter(x_obs[:n], p_obs[:n], color="blue", alpha=.1, s=2)
ax.set_title("entry intensity vs detection probability")
ax.set_xlabel("entry intensity")
ax.set_ylabel("detection probability")
ax.grid(True)
ax.set_axisbelow(True)

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

for n in range(W.shape[-1]):
    xs = np.linspace(0, 18, 100)
    logit = W[0, 0, n] * xs + b[0, 0, n]
    ys = sigmoid(logit)
    ax.plot(xs, ys, color="black", alpha=.3, linewidth=4)

# %% [markdown]
# ### not-MIWAE (self-masking known)

# %%
notmiwae = notMIWAE(Xnan, Xval, n_latent=n_latent, n_samples=n_samples, n_hidden=n_hidden, name=name, out_dist=out_dist, mechanism_weight=0.1, missing_process='selfmasking_known')

# ---- do the training
trainer.train(notmiwae, batch_size=batch_size, max_iter=max_iter, name=name + 'notmiwae')

# ---- find imputation RMSE
RMSE_notmiwae, x_notmiwae = utils.not_imputationRMSE(notmiwae, Xtrain, Xz, Xnan, S, L)

np.save('x_notmiwae.npy', x_notmiwae)
# Out:
# Creating graph...
# Saving session...
# Saving session...
# 0/10000 updates, 0.37 s, 352608.69 train_loss, 348249.10 val_loss
# Saving session...
# 100/10000 updates, 22.28 s, 11376.48 train_loss, 10885.20 val_loss
# Saving session...
# 200/10000 updates, 22.44 s, 8415.04 train_loss, 8622.55 val_loss
# Saving session...
# 300/10000 updates, 22.11 s, 7175.06 train_loss, 7247.81 val_loss
# Saving session...
# 400/10000 updates, 22.16 s, 5569.12 train_loss, 5663.01 val_loss
# Saving session...
# 500/10000 updates, 22.01 s, 3642.09 train_loss, 3259.51 val_loss
# Saving session...
# 600/10000 updates, 22.05 s, 1423.96 train_loss, 1551.37 val_loss
# Saving session...
# 700/10000 updates, 22.10 s, 24.66 train_loss, 399.82 val_loss
# Saving session...
# 800/10000 updates, 22.38 s, -17.26 train_loss, -487.27 val_loss
# 900/10000 updates, 21.96 s, -799.11 train_loss, -205.74 val_loss
# Saving session...
# 1000/10000 updates, 21.92 s, -962.49 train_loss, -648.56 val_loss
# 1100/10000 updates, 21.89 s, -745.55 train_loss, -495.23 val_loss
# 1200/10000 updates, 21.82 s, -1119.44 train_loss, -613.68 val_loss
# 1300/10000 updates, 21.96 s, -470.58 train_loss, -582.31 val_loss
# 1400/10000 updates, 21.95 s, -961.80 train_loss, -544.28 val_loss
# 1500/10000 updates, 21.92 s, 312.24 train_loss, -376.10 val_loss
# Saving session...
# 1600/10000 updates, 21.97 s, -644.10 train_loss, -770.87 val_loss
# 1700/10000 updates, 20.00 s, 121.07 train_loss, 190.10 val_loss
# 1800/10000 updates, 21.61 s, -528.39 train_loss, -577.55 val_loss
# 1900/10000 updates, 20.80 s, -1213.97 train_loss, 121.09 val_loss
# 2000/10000 updates, 24.27 s, -266.02 train_loss, -696.22 val_loss
# 2100/10000 updates, 22.52 s, -723.59 train_loss, -555.22 val_loss
# 2200/10000 updates, 21.58 s, -1081.49 train_loss, -689.82 val_loss
# 2300/10000 updates, 21.61 s, -803.97 train_loss, -714.12 val_loss
# 2400/10000 updates, 21.55 s, -426.86 train_loss, -764.62 val_loss
# Saving session...
# 2500/10000 updates, 21.51 s, -540.93 train_loss, -882.17 val_loss
# 2600/10000 updates, 21.44 s, -999.10 train_loss, -826.57 val_loss
# 2700/10000 updates, 21.59 s, 1084.53 train_loss, -621.26 val_loss
# 2800/10000 updates, 21.64 s, -596.59 train_loss, -411.86 val_loss
# 2900/10000 updates, 20.91 s, -674.42 train_loss, -773.81 val_loss
# 3000/10000 updates, 20.12 s, -241.27 train_loss, -830.39 val_loss
# 3100/10000 updates, 19.71 s, -891.33 train_loss, -671.23 val_loss
# 3200/10000 updates, 20.15 s, -635.50 train_loss, -828.09 val_loss
# 3300/10000 updates, 18.97 s, -906.57 train_loss, -825.56 val_loss
# 3400/10000 updates, 19.76 s, -415.46 train_loss, -437.14 val_loss
# 3500/10000 updates, 22.61 s, -444.96 train_loss, -810.22 val_loss
# 3600/10000 updates, 21.56 s, -537.53 train_loss, -739.01 val_loss
# 3700/10000 updates, 20.21 s, -710.25 train_loss, -818.12 val_loss
# 3800/10000 updates, 21.78 s, -142.30 train_loss, -625.77 val_loss
# 3900/10000 updates, 22.08 s, -802.23 train_loss, -785.84 val_loss
# 4000/10000 updates, 21.70 s, -604.54 train_loss, -499.09 val_loss
# 4100/10000 updates, 21.58 s, -799.43 train_loss, -610.53 val_loss
# 4200/10000 updates, 21.67 s, -789.10 train_loss, -637.75 val_loss
# 4300/10000 updates, 23.95 s, -478.34 train_loss, -629.89 val_loss
# 4400/10000 updates, 22.22 s, -961.71 train_loss, -592.45 val_loss
# 4500/10000 updates, 20.70 s, -629.27 train_loss, -627.99 val_loss
# 4600/10000 updates, 21.59 s, -185.66 train_loss, -198.90 val_loss
# 4700/10000 updates, 20.92 s, -555.35 train_loss, -674.67 val_loss
# 4800/10000 updates, 21.44 s, -871.34 train_loss, -854.60 val_loss
# 4900/10000 updates, 21.96 s, -321.84 train_loss, -693.37 val_loss
# 5000/10000 updates, 21.63 s, -1017.37 train_loss, -770.80 val_loss
# 5100/10000 updates, 21.53 s, -172.41 train_loss, -873.83 val_loss
# 5200/10000 updates, 21.48 s, -1032.76 train_loss, -822.39 val_loss
# 5300/10000 updates, 21.57 s, -765.63 train_loss, -714.89 val_loss
# 5400/10000 updates, 21.54 s, -1029.34 train_loss, -311.11 val_loss
# 5500/10000 updates, 21.55 s, -611.02 train_loss, -626.93 val_loss
# 5600/10000 updates, 21.48 s, -895.83 train_loss, -628.80 val_loss
# 5700/10000 updates, 21.57 s, -592.12 train_loss, -735.63 val_loss
# 5800/10000 updates, 21.56 s, 80.22 train_loss, -507.71 val_loss
# 5900/10000 updates, 21.50 s, -370.62 train_loss, -482.98 val_loss
# 6000/10000 updates, 21.49 s, -746.46 train_loss, -463.94 val_loss
# 6100/10000 updates, 21.60 s, -262.73 train_loss, -548.63 val_loss
# 6200/10000 updates, 21.52 s, -1122.51 train_loss, -799.16 val_loss
# 6300/10000 updates, 21.58 s, -2.45 train_loss, -81.82 val_loss
# 6400/10000 updates, 21.52 s, -533.86 train_loss, -672.18 val_loss
# 6500/10000 updates, 21.96 s, -1042.47 train_loss, -489.70 val_loss
# 6600/10000 updates, 21.77 s, -719.52 train_loss, -853.93 val_loss
# 6700/10000 updates, 21.48 s, -1108.62 train_loss, -558.71 val_loss
# 6800/10000 updates, 21.52 s, -1134.68 train_loss, -403.70 val_loss
# 6900/10000 updates, 21.82 s, -854.42 train_loss, -519.54 val_loss
# 7000/10000 updates, 21.55 s, -414.57 train_loss, -218.90 val_loss
# 7100/10000 updates, 21.60 s, -967.40 train_loss, -510.68 val_loss
# 7200/10000 updates, 21.58 s, -1382.28 train_loss, -514.48 val_loss
# 7300/10000 updates, 21.58 s, -632.51 train_loss, -756.55 val_loss
# 7400/10000 updates, 22.01 s, -1098.93 train_loss, -784.84 val_loss
# 7500/10000 updates, 22.03 s, -740.88 train_loss, -678.93 val_loss
# 7600/10000 updates, 22.94 s, -546.06 train_loss, -819.06 val_loss
# Saving session...
# 7700/10000 updates, 22.98 s, -803.38 train_loss, -920.17 val_loss
# 7800/10000 updates, 23.49 s, -440.27 train_loss, -789.58 val_loss
# Saving session...
# 7900/10000 updates, 24.14 s, -1242.52 train_loss, -948.13 val_loss
# 8000/10000 updates, 23.51 s, -736.66 train_loss, -618.52 val_loss
# 8100/10000 updates, 23.43 s, -624.90 train_loss, -413.67 val_loss
# 8200/10000 updates, 23.39 s, -776.27 train_loss, -477.61 val_loss
# 8300/10000 updates, 23.48 s, -655.01 train_loss, -797.57 val_loss
# 8400/10000 updates, 23.69 s, -1220.38 train_loss, -782.77 val_loss
# 8500/10000 updates, 23.47 s, -810.59 train_loss, -842.97 val_loss
# 8600/10000 updates, 23.43 s, -145.49 train_loss, -523.29 val_loss
# 8700/10000 updates, 23.50 s, -1058.13 train_loss, -593.74 val_loss
# 8800/10000 updates, 23.49 s, -356.54 train_loss, -672.70 val_loss
# 8900/10000 updates, 23.65 s, -1116.58 train_loss, -778.40 val_loss
# 9000/10000 updates, 23.46 s, -208.32 train_loss, -380.68 val_loss
# 9100/10000 updates, 23.34 s, -433.99 train_loss, -698.16 val_loss
# 9200/10000 updates, 23.24 s, -585.04 train_loss, -603.28 val_loss
# 9300/10000 updates, 23.41 s, -465.47 train_loss, -493.19 val_loss
# 9400/10000 updates, 23.41 s, 82.11 train_loss, -593.75 val_loss
# 9500/10000 updates, 23.31 s, -875.19 train_loss, -629.52 val_loss
# 9600/10000 updates, 23.49 s, -764.06 train_loss, -713.06 val_loss
# 9700/10000 updates, 23.42 s, -703.49 train_loss, -768.03 val_loss
# 9800/10000 updates, 23.58 s, -552.45 train_loss, -602.78 val_loss
# 9900/10000 updates, 23.61 s, -1131.09 train_loss, -775.44 val_loss
# 0 / 1000
# 100 / 1000
# 200 / 1000
# 300 / 1000
# 400 / 1000
# 500 / 1000
# 600 / 1000
# 700 / 1000
# 800 / 1000
# 900 / 1000

# %%
print("RMSE: {:.3f}".format(RMSE_notmiwae))
# Out:
# RMSE: 0.248

# %%
x_notmiwae = np.load('x_notmiwae.npy')

# %%
x_obs = x_data[mask]
x_miss = x_data[~mask]

x_est = x_notmiwae

x_est_obs = x_est[mask]
x_est_miss = x_est[~mask]

# %%
scatter_compare_individual_entries_panel(x_obs, x_miss, x_est_obs, x_est_miss)

# %%
hist_compare_individual_entries(x_obs, x_miss, x_est_obs, x_est_miss)
