# %% [markdown]
# # Single-cell Proteomics Synthetic Data Generation

# %% [markdown]
# The goal of this notebook is to simulate a crude single-cell proteomics datasets with a MNAR mechanism, and show that not-MIWAE performs better than MIWAE.

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

from MIWAE import MIWAE
from notMIWAE import notMIWAE
import trainer
import utils

np.random.seed(42)
# Out:
# 2023-11-20 19:26:52.948427: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-11-20 19:26:52.950017: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-20 19:26:52.972070: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-20 19:26:52.972097: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-20 19:26:52.972116: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-20 19:26:52.976469: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-20 19:26:52.976843: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-20 19:26:53.548108: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# Plotting functions for later.

# %%
def scatter_compare_individual_entries_panel(x_obs, x_miss, x_est_obs, x_est_miss):
    fig, axes = plt.subplots(ncols=2, figsize=(12, 5))
    
    ax = axes[0]
    ax.scatter(x_obs, x_est_obs, s=1, alpha=0.1)
    lims = [np.min([ax.get_xlim(), ax.get_ylim()]), np.max([ax.get_xlim(), ax.get_ylim()])]
    ax.plot(lims, lims, "--", c="k")

    mse = np.mean((x_obs - x_est_obs)**2)
    ax.text(0.05, 0.95, f"MSE: {mse:.2f}", transform=ax.transAxes, fontsize=12, verticalalignment="top", bbox=dict(facecolor="white", alpha=0.8))

    ax.set_xlabel("Observed")
    ax.set_ylabel("Imputed")
    ax.set_title("Observed")
    ax.grid(True)
    ax.set_axisbelow(True)

    ax = axes[1]
    ax.scatter(x_miss, x_est_miss, s=1, alpha=0.1)
    lims = [np.min([ax.get_xlim(), ax.get_ylim()]), np.max([ax.get_xlim(), ax.get_ylim()])]
    ax.plot(lims, lims, "--", c="k")

    mse = np.mean((x_miss - x_est_miss)**2)
    ax.text(0.05, 0.95, f"MSE: {mse:.2f}", transform=ax.transAxes, fontsize=12, verticalalignment="top", bbox=dict(facecolor="white", alpha=0.8))

    ax.set_xlabel("Observed")
    ax.set_ylabel("Imputed")
    ax.set_title("Missing")
    ax.grid(True)

# %%
def hist_compare_individual_entries(x_obs, x_miss, x_est_obs, x_est_miss):
    fig, axes = plt.subplots(ncols=2, figsize=(12, 5))

    x_min = np.min([np.min(x_obs), np.min(x_miss), np.min(x_est_obs), np.min(x_est_miss)])
    x_max = np.max([np.max(x_obs), np.max(x_miss), np.max(x_est_obs), np.max(x_est_miss)])

    ax = axes[0]
    ax.hist([x_obs, x_miss], color=["blue", "red"], bins=50, edgecolor="black", linewidth=1.2, stacked=True)
    ax.set_title("Data")
    ax.set_xlabel("x")
    ax.set_ylabel("(stacked) count")
    ax.set_xlim(x_min, x_max)
    ax.grid(True)
    ax.set_axisbelow(True)
    ax.legend(labels=["$x_{obs}$", "$x_{miss}$"], fontsize=12)

    ax = axes[1]
    ax.hist([x_est_obs, x_est_miss], color=["blue", "red"], bins=50, edgecolor="black", linewidth=1.2, stacked=True)
    ax.set_title("Model")
    ax.set_xlabel("x")
    ax.set_ylabel("(stacked) count")
    ax.set_xlim(x_min, x_max)
    ax.grid(True)
    ax.set_axisbelow(True)
    ax.legend(labels=["$x_{obs}$", "$x_{miss}$"], fontsize=12)

# %% [markdown]
# ## Data generation

# %% [markdown]
# Let's start by generating the synthetic data and visualizing it.

# %%
def logistic(x, k=1, x0=0, L=1):
    return L / (1 + np.exp(-k * (x - x0)))

def sigmoid(x):
    return 1 / (1 + np.exp(-x))


def simulate_data(n_cells=1000, n_proteins=1000):
    # all cells are from the same group (cell-type)
    # the cell type has some protein distribution / signature
    cell_type_signature = np.random.uniform(5, 12, n_proteins)

    # each cell is a bit different
    cell_variation = np.random.normal(0, 1, n_cells)

    intensity = cell_type_signature.reshape(1, -1) + cell_variation.reshape(-1, 1)

    # the measurement is noisy
    x = np.random.normal(intensity, 0.1)

    # MNAR mechanism: self-masking (x -> m)
    # entries with low intensity are less likely to be sampled
    #detection_prob = logistic(x, k=2, x0=7) # set x0=6, if you want less missing values
    detection_prob = sigmoid(2*x - 14)

    # sample using a bernoulli distribution
    mask = np.random.binomial(1, detection_prob)
    mask = mask.astype(bool)

    return x, detection_prob, mask

# %% [markdown]
# Let's simulate some data:

# %%
x_data, detection_prob, mask = simulate_data()

# %%
x_nan = x_data.copy()
x_nan[~mask] = np.nan

x_0 = x_data.copy()
x_0[~mask] = 0

# %%
print("Missing entries: {:.2f}%".format(np.isnan(x_nan).sum() / x_nan.size * 100))
# Out:
# Missing entries: 29.23%

# %% [markdown]
# Let's plot the data. "White" are the missing values.

# %%
fig, ax = plt.subplots(figsize=(8, 5))
sns.heatmap(x_nan, cmap="viridis", xticklabels=False, yticklabels=False, ax=ax)
ax.set_xlabel("Proteins")
ax.set_ylabel("Cells")
ax.set_title("Expression matrix with missing values")
# Out:
# Text(0.5, 1.0, 'Expression matrix with missing values')

# %% [markdown]
# Let's look at the missigness pattern entry-wise and protein-wise:

# %%
fig, axes = plt.subplots(ncols=2, figsize=(12, 5))

# plot entry intensity vs detection probability
ax = axes[0]

p_obs = detection_prob[mask]
x_obs = x_data[mask]

p_miss = detection_prob[~mask]
x_miss = x_data[~mask]

n = 5_000

ax.scatter(x_miss[:n], p_miss[:n], color="red", alpha=.1, s=4)
ax.scatter(x_obs[:n], p_obs[:n], color="blue", alpha=.1, s=4)
ax.set_title("entry intensity vs detection probability")
ax.set_xlabel("entry intensity")
ax.set_ylabel("detection probability")
ax.grid(True)
ax.set_axisbelow(True)

# plot the average protein intensity vs the detection proportion
ax = axes[1]
x_obs_protein = np.nanmean(x_nan, axis=0)
p_protein = 1 - np.nanmean(np.isnan(x_nan), axis=0)

ax.scatter(x_obs_protein, p_protein, color="blue", alpha=1, s=6)
ax.set_title("avg protein intensity vs detection proportion")
ax.set_xlabel("protein intensity")
ax.set_ylabel("detection proportion")
ax.grid(True)
ax.set_axisbelow(True)

# %%
fig, ax = plt.subplots(1, 1, figsize=(5, 5))

ax.hist([x_obs, x_miss], color=["blue", "red"], bins=50, edgecolor="black", linewidth=1.2, stacked=True)
ax.set_title("Data")
ax.set_xlabel("x")
ax.set_ylabel("(stacked) count")
ax.set_xlim(np.min(x_data), np.max(x_data))
ax.grid(True)
ax.set_axisbelow(True)
ax.legend(labels=["$x_{obs}$", "$x_{miss}$"], fontsize=12)

# %% [markdown]
# ## Model Comparison

# %% [markdown]
# Set the parameters for the models.

# %%
name = '/tmp/best'

# model specification
n_hidden = 128
n_samples = 20
n_latent = 16
out_dist='gauss'

# training
max_iter = 10_000
batch_size = 64

# imputation
L = 1000

# %% [markdown]
# Let's run.

# %%
N, D = x_data.shape

Xtrain = x_data.copy()
Xval_org = x_data.copy()

Xnan = x_nan.copy()
Xz = x_0.copy()
S = mask.copy()

Xval = x_nan.copy()
Xvalz = x_0.copy()

# %%
tf.compat.v1.disable_eager_execution()

# %% [markdown]
# ### MIWAE

# %%
miwae = MIWAE(Xnan, Xval, n_latent=n_latent, n_samples=n_samples, n_hidden=n_hidden, name=name, out_dist=out_dist)

# ---- do the training
trainer.train(miwae, batch_size=batch_size, max_iter=max_iter, name=name + 'miwae')

# ---- find imputation RMSE
RMSE_miwae, x_miwae = utils.imputationRMSE(miwae, Xtrain, Xz, Xnan, S, L)

np.save('x_miwae.npy', x_miwae)
# Out:
# Creating graph...
# 2023-11-20 19:26:56.682046: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:382] MLIR V1 optimization pass is not enabled
# Saving session...
# Saving session...
# 0/10000 updates, 0.17 s, 71067.30 train_loss, 67339.39 val_loss
# Saving session...
# 100/10000 updates, 5.34 s, 2186.84 train_loss, 2180.75 val_loss
# Saving session...
# 200/10000 updates, 5.17 s, 1645.15 train_loss, 1709.00 val_loss
# Saving session...
# 300/10000 updates, 5.29 s, 1409.90 train_loss, 1432.42 val_loss
# Saving session...
# 400/10000 updates, 5.14 s, 1112.82 train_loss, 1129.69 val_loss
# Saving session...
# 500/10000 updates, 5.23 s, 679.73 train_loss, 665.44 val_loss
# Saving session...
# 600/10000 updates, 5.15 s, 356.88 train_loss, 335.63 val_loss
# Saving session...
# 700/10000 updates, 4.88 s, 92.86 train_loss, 154.47 val_loss
# Saving session...
# 800/10000 updates, 4.93 s, -62.31 train_loss, 22.21 val_loss
# Saving session...
# 900/10000 updates, 4.97 s, -3.13 train_loss, -57.54 val_loss
# Saving session...
# 1000/10000 updates, 5.27 s, -71.51 train_loss, -73.50 val_loss
# Saving session...
# 1100/10000 updates, 5.06 s, -203.14 train_loss, -105.78 val_loss
# Saving session...
# 1200/10000 updates, 5.06 s, -51.56 train_loss, -136.20 val_loss
# 1300/10000 updates, 5.10 s, -111.70 train_loss, -108.97 val_loss
# 1400/10000 updates, 5.22 s, -8.08 train_loss, -133.70 val_loss
# Saving session...
# 1500/10000 updates, 4.31 s, -231.34 train_loss, -157.30 val_loss
# Saving session...
# 1600/10000 updates, 5.04 s, -121.80 train_loss, -174.57 val_loss
# 1700/10000 updates, 3.58 s, -215.26 train_loss, -166.76 val_loss
# 1800/10000 updates, 3.45 s, -146.09 train_loss, -50.84 val_loss
# 1900/10000 updates, 5.06 s, -200.34 train_loss, -166.97 val_loss
# 2000/10000 updates, 5.27 s, -183.03 train_loss, -139.25 val_loss
# 2100/10000 updates, 4.86 s, -147.34 train_loss, -152.48 val_loss
# 2200/10000 updates, 4.24 s, -136.08 train_loss, -112.76 val_loss
# 2300/10000 updates, 4.03 s, -142.80 train_loss, -116.07 val_loss
# 2400/10000 updates, 4.16 s, -191.75 train_loss, -115.71 val_loss
# 2500/10000 updates, 4.28 s, -43.39 train_loss, -118.72 val_loss
# 2600/10000 updates, 5.15 s, -170.07 train_loss, -159.84 val_loss
# 2700/10000 updates, 4.43 s, -226.39 train_loss, -157.43 val_loss
# 2800/10000 updates, 5.25 s, -163.64 train_loss, -164.28 val_loss
# 2900/10000 updates, 4.69 s, -106.33 train_loss, -102.67 val_loss
# 3000/10000 updates, 3.21 s, -48.86 train_loss, -159.96 val_loss
# Saving session...
# 3100/10000 updates, 2.79 s, -162.15 train_loss, -200.58 val_loss
# 3200/10000 updates, 4.50 s, -37.52 train_loss, -158.80 val_loss
# 3300/10000 updates, 4.99 s, -92.37 train_loss, -160.21 val_loss
# 3400/10000 updates, 5.15 s, -93.95 train_loss, -77.07 val_loss
# 3500/10000 updates, 4.65 s, -213.73 train_loss, -154.32 val_loss
# 3600/10000 updates, 4.95 s, -117.08 train_loss, -167.73 val_loss
# Saving session...
# 3700/10000 updates, 4.77 s, -98.66 train_loss, -201.46 val_loss
# 3800/10000 updates, 5.15 s, -141.20 train_loss, -188.60 val_loss
# 3900/10000 updates, 4.88 s, -183.18 train_loss, -150.59 val_loss
# 4000/10000 updates, 4.69 s, -220.04 train_loss, -147.92 val_loss
# Saving session...
# 4100/10000 updates, 3.29 s, -205.57 train_loss, -204.00 val_loss
# 4200/10000 updates, 2.29 s, -170.94 train_loss, -118.81 val_loss
# 4300/10000 updates, 2.81 s, -10.52 train_loss, -150.03 val_loss
# 4400/10000 updates, 3.15 s, -150.05 train_loss, -142.63 val_loss
# 4500/10000 updates, 4.79 s, -156.49 train_loss, -147.64 val_loss
# 4600/10000 updates, 4.73 s, -201.83 train_loss, -165.45 val_loss
# 4700/10000 updates, 4.97 s, -89.23 train_loss, -169.08 val_loss
# 4800/10000 updates, 5.06 s, 28.36 train_loss, -175.75 val_loss
# 4900/10000 updates, 5.06 s, -218.22 train_loss, -154.17 val_loss
# 5000/10000 updates, 4.93 s, -113.61 train_loss, -134.75 val_loss
# 5100/10000 updates, 4.50 s, -221.29 train_loss, -186.90 val_loss
# 5200/10000 updates, 3.17 s, -196.20 train_loss, -198.50 val_loss
# 5300/10000 updates, 2.99 s, -127.72 train_loss, -161.91 val_loss
# 5400/10000 updates, 3.96 s, -134.27 train_loss, -127.26 val_loss
# 5500/10000 updates, 2.61 s, -175.46 train_loss, -134.07 val_loss
# 5600/10000 updates, 2.69 s, 275.60 train_loss, -127.01 val_loss
# 5700/10000 updates, 4.09 s, -118.53 train_loss, -159.85 val_loss
# 5800/10000 updates, 4.34 s, -201.81 train_loss, -181.57 val_loss
# 5900/10000 updates, 4.88 s, -96.30 train_loss, -154.93 val_loss
# 6000/10000 updates, 4.61 s, -192.17 train_loss, -164.43 val_loss
# 6100/10000 updates, 3.40 s, -2.32 train_loss, -186.97 val_loss
# 6200/10000 updates, 3.47 s, -156.77 train_loss, -162.57 val_loss
# 6300/10000 updates, 3.92 s, -194.95 train_loss, -118.69 val_loss
# 6400/10000 updates, 4.24 s, -169.98 train_loss, -112.05 val_loss
# 6500/10000 updates, 3.76 s, -240.92 train_loss, -75.36 val_loss
# 6600/10000 updates, 3.62 s, -258.79 train_loss, -137.17 val_loss
# 6700/10000 updates, 3.79 s, -118.32 train_loss, -81.72 val_loss
# 6800/10000 updates, 3.95 s, -133.27 train_loss, -188.69 val_loss
# 6900/10000 updates, 4.02 s, -155.75 train_loss, -149.59 val_loss
# 7000/10000 updates, 3.73 s, 704.86 train_loss, -149.85 val_loss
# 7100/10000 updates, 3.96 s, -189.83 train_loss, -20.11 val_loss
# 7200/10000 updates, 3.66 s, -183.42 train_loss, -150.87 val_loss
# 7300/10000 updates, 4.38 s, -176.31 train_loss, -175.19 val_loss
# 7400/10000 updates, 3.49 s, -238.60 train_loss, -187.92 val_loss
# 7500/10000 updates, 3.45 s, -189.96 train_loss, -157.52 val_loss
# 7600/10000 updates, 3.73 s, -228.72 train_loss, -188.46 val_loss
# 7700/10000 updates, 3.85 s, -17.07 train_loss, -39.22 val_loss
# 7800/10000 updates, 3.69 s, -61.18 train_loss, -144.83 val_loss
# Saving session...
# 7900/10000 updates, 3.99 s, -235.66 train_loss, -204.53 val_loss
# 8000/10000 updates, 4.24 s, -135.27 train_loss, -179.58 val_loss
# 8100/10000 updates, 3.71 s, -139.09 train_loss, -179.49 val_loss
# 8200/10000 updates, 4.75 s, -158.32 train_loss, -165.75 val_loss
# 8300/10000 updates, 4.98 s, -160.19 train_loss, -148.75 val_loss
# 8400/10000 updates, 4.99 s, -148.41 train_loss, -199.72 val_loss
# 8500/10000 updates, 4.91 s, -163.07 train_loss, -145.19 val_loss
# 8600/10000 updates, 4.69 s, -99.30 train_loss, -147.25 val_loss
# 8700/10000 updates, 4.96 s, -96.73 train_loss, -165.75 val_loss
# 8800/10000 updates, 4.60 s, -227.52 train_loss, -170.70 val_loss
# 8900/10000 updates, 4.86 s, -156.77 train_loss, -178.38 val_loss
# 9000/10000 updates, 4.96 s, -123.54 train_loss, -153.82 val_loss
# 9100/10000 updates, 4.73 s, -64.20 train_loss, -166.16 val_loss
# 9200/10000 updates, 5.00 s, -99.39 train_loss, -163.81 val_loss
# 9300/10000 updates, 4.81 s, -135.28 train_loss, -187.29 val_loss
# 9400/10000 updates, 4.66 s, -159.93 train_loss, -149.88 val_loss
# 9500/10000 updates, 4.69 s, -183.64 train_loss, -200.77 val_loss
# 9600/10000 updates, 4.96 s, -181.95 train_loss, -177.17 val_loss
# 9700/10000 updates, 4.95 s, -183.96 train_loss, -196.93 val_loss
# 9800/10000 updates, 4.99 s, -122.55 train_loss, -154.52 val_loss
# 9900/10000 updates, 5.01 s, -158.26 train_loss, -167.15 val_loss
# 0 / 1000
# 100 / 1000
# 200 / 1000
# 300 / 1000
# 400 / 1000
# 500 / 1000
# 600 / 1000
# 700 / 1000
# 800 / 1000
# 900 / 1000

# %%
print("RMSE: {:.3f}".format(RMSE_miwae))
# Out:
# RMSE: 0.229

# %%
x_miwae = np.load('x_miwae.npy')

# %%
x_obs = x_data[mask]
x_miss = x_data[~mask]

x_est = x_miwae

x_est_obs = x_est[mask]
x_est_miss = x_est[~mask]

# %%
scatter_compare_individual_entries_panel(x_obs, x_miss, x_est_obs, x_est_miss)

# %%
hist_compare_individual_entries(x_obs, x_miss, x_est_obs, x_est_miss)

# %% [markdown]
# ### not-MIWAE (self-masking)

# %%
notmiwae = notMIWAE(Xnan, Xval, n_latent=n_latent, n_samples=n_samples, n_hidden=n_hidden, name=name, out_dist=out_dist, mechanism_weight=0.1, missing_process='selfmasking')

# ---- do the training
trainer.train(notmiwae, batch_size=batch_size, max_iter=max_iter, name=name + 'notmiwae')

# ---- find imputation RMSE
RMSE_notmiwae, x_notmiwae = utils.not_imputationRMSE(notmiwae, Xtrain, Xz, Xnan, S, L)

np.save('x_notmiwae.npy', x_notmiwae)
# Out:
# Creating graph...
# Saving session...
# Saving session...
# 0/10000 updates, 0.23 s, 71595.55 train_loss, 69400.48 val_loss
# Saving session...
# 100/10000 updates, 6.71 s, 2372.43 train_loss, 2257.27 val_loss
# Saving session...
# 200/10000 updates, 6.19 s, 1816.34 train_loss, 1805.04 val_loss
# Saving session...
# 300/10000 updates, 4.47 s, 1514.62 train_loss, 1502.12 val_loss
# Saving session...
# 400/10000 updates, 6.03 s, 1121.08 train_loss, 1111.88 val_loss
# Saving session...
# 500/10000 updates, 6.40 s, 688.90 train_loss, 626.06 val_loss
# Saving session...
# 600/10000 updates, 6.20 s, 263.86 train_loss, 297.66 val_loss
# Saving session...
# 700/10000 updates, 6.50 s, 49.51 train_loss, 50.02 val_loss
# Saving session...
# 800/10000 updates, 6.70 s, -18.19 train_loss, 8.67 val_loss
# 900/10000 updates, 6.19 s, 46.94 train_loss, 95.60 val_loss
# Saving session...
# 1000/10000 updates, 6.53 s, -160.70 train_loss, -70.08 val_loss
# 1100/10000 updates, 6.60 s, -36.08 train_loss, -63.35 val_loss
# 1200/10000 updates, 6.68 s, -105.02 train_loss, -39.98 val_loss
# 1300/10000 updates, 6.53 s, -102.60 train_loss, -46.85 val_loss
# Saving session...
# 1400/10000 updates, 6.51 s, -136.25 train_loss, -85.86 val_loss
# Saving session...
# 1500/10000 updates, 5.63 s, -178.55 train_loss, -90.23 val_loss
# 1600/10000 updates, 6.54 s, 10.21 train_loss, 5.87 val_loss
# Saving session...
# 1700/10000 updates, 6.52 s, -191.26 train_loss, -99.87 val_loss
# Saving session...
# 1800/10000 updates, 6.80 s, -28.73 train_loss, -133.79 val_loss
# 1900/10000 updates, 6.47 s, 54.83 train_loss, -53.28 val_loss
# 2000/10000 updates, 5.88 s, -153.97 train_loss, -105.17 val_loss
# 2100/10000 updates, 6.63 s, -209.79 train_loss, -108.56 val_loss
# 2200/10000 updates, 6.43 s, -6.18 train_loss, -47.70 val_loss
# Saving session...
# 2300/10000 updates, 6.45 s, 202.62 train_loss, -144.06 val_loss
# 2400/10000 updates, 6.55 s, -20.04 train_loss, -110.01 val_loss
# Saving session...
# 2500/10000 updates, 6.36 s, 28.64 train_loss, -159.76 val_loss
# 2600/10000 updates, 6.40 s, -22.81 train_loss, -75.13 val_loss
# 2700/10000 updates, 4.15 s, 153.82 train_loss, -59.88 val_loss
# 2800/10000 updates, 5.10 s, -151.43 train_loss, -68.25 val_loss
# 2900/10000 updates, 5.15 s, -50.45 train_loss, -83.65 val_loss
# 3000/10000 updates, 5.12 s, -229.07 train_loss, -136.59 val_loss
# 3100/10000 updates, 4.84 s, -143.77 train_loss, -132.15 val_loss
# 3200/10000 updates, 4.78 s, -138.63 train_loss, -108.98 val_loss
# 3300/10000 updates, 4.67 s, 12.10 train_loss, -123.63 val_loss
# 3400/10000 updates, 5.21 s, 487.04 train_loss, -140.84 val_loss
# 3500/10000 updates, 5.12 s, -158.67 train_loss, -98.03 val_loss
# 3600/10000 updates, 4.53 s, -209.76 train_loss, -103.16 val_loss
# 3700/10000 updates, 4.77 s, -15.39 train_loss, -45.11 val_loss
# 3800/10000 updates, 4.67 s, 107.45 train_loss, -126.13 val_loss
# 3900/10000 updates, 4.79 s, -139.69 train_loss, -122.97 val_loss
# 4000/10000 updates, 4.92 s, -178.05 train_loss, -11.63 val_loss
# 4100/10000 updates, 4.86 s, -91.73 train_loss, -132.59 val_loss
# Saving session...
# 4200/10000 updates, 4.81 s, -140.22 train_loss, -168.31 val_loss
# 4300/10000 updates, 5.33 s, -155.48 train_loss, -70.38 val_loss
# 4400/10000 updates, 4.84 s, -239.48 train_loss, -121.91 val_loss
# 4500/10000 updates, 4.98 s, -56.11 train_loss, -108.86 val_loss
# 4600/10000 updates, 5.26 s, -130.93 train_loss, -73.02 val_loss
# 4700/10000 updates, 5.10 s, -198.56 train_loss, -156.41 val_loss
# 4800/10000 updates, 4.83 s, -84.44 train_loss, -126.25 val_loss
# 4900/10000 updates, 5.01 s, -137.63 train_loss, -133.77 val_loss
# 5000/10000 updates, 5.42 s, -139.12 train_loss, -121.50 val_loss
# 5100/10000 updates, 4.85 s, -161.98 train_loss, -116.53 val_loss
# 5200/10000 updates, 4.95 s, 212.08 train_loss, -131.81 val_loss
# 5300/10000 updates, 4.92 s, -187.70 train_loss, -137.61 val_loss
# 5400/10000 updates, 4.83 s, -176.93 train_loss, -130.47 val_loss
# 5500/10000 updates, 5.11 s, -173.40 train_loss, -121.43 val_loss
# 5600/10000 updates, 5.00 s, -145.64 train_loss, -137.94 val_loss
# 5700/10000 updates, 4.77 s, -164.54 train_loss, -110.04 val_loss
# 5800/10000 updates, 4.84 s, -86.47 train_loss, -80.10 val_loss
# 5900/10000 updates, 4.86 s, -175.25 train_loss, -147.80 val_loss
# 6000/10000 updates, 4.99 s, -54.53 train_loss, -93.32 val_loss
# 6100/10000 updates, 5.04 s, -127.57 train_loss, -107.83 val_loss
# 6200/10000 updates, 4.97 s, -115.40 train_loss, -100.48 val_loss
# 6300/10000 updates, 4.96 s, -90.06 train_loss, -74.33 val_loss
# 6400/10000 updates, 4.95 s, -152.33 train_loss, -105.91 val_loss
# 6500/10000 updates, 5.02 s, -146.78 train_loss, -138.02 val_loss
# 6600/10000 updates, 4.94 s, -150.09 train_loss, -91.23 val_loss
# 6700/10000 updates, 4.99 s, -198.01 train_loss, -152.10 val_loss
# 6800/10000 updates, 4.98 s, -176.29 train_loss, -143.94 val_loss
# 6900/10000 updates, 4.96 s, -81.16 train_loss, -140.91 val_loss
# 7000/10000 updates, 4.97 s, -125.47 train_loss, -85.97 val_loss
# 7100/10000 updates, 4.93 s, 180.99 train_loss, -124.14 val_loss
# Saving session...
# 7200/10000 updates, 5.11 s, -73.12 train_loss, -169.02 val_loss
# 7300/10000 updates, 5.17 s, -152.50 train_loss, -142.19 val_loss
# 7400/10000 updates, 5.05 s, -120.97 train_loss, -139.20 val_loss
# 7500/10000 updates, 5.04 s, -200.68 train_loss, -145.04 val_loss
# 7600/10000 updates, 5.04 s, -74.18 train_loss, -145.65 val_loss
# 7700/10000 updates, 5.10 s, -175.84 train_loss, -144.91 val_loss
# 7800/10000 updates, 5.09 s, -213.51 train_loss, -70.55 val_loss
# Saving session...
# 7900/10000 updates, 5.00 s, -245.26 train_loss, -179.95 val_loss
# 8000/10000 updates, 5.03 s, -176.07 train_loss, -138.86 val_loss
# 8100/10000 updates, 5.05 s, -161.88 train_loss, -156.88 val_loss
# 8200/10000 updates, 4.98 s, -136.38 train_loss, -145.12 val_loss
# 8300/10000 updates, 4.97 s, 29.56 train_loss, 17.72 val_loss
# 8400/10000 updates, 5.05 s, -45.18 train_loss, -153.07 val_loss
# 8500/10000 updates, 4.88 s, -86.82 train_loss, -131.41 val_loss
# 8600/10000 updates, 4.81 s, -175.78 train_loss, -151.99 val_loss
# 8700/10000 updates, 4.84 s, 48.15 train_loss, -130.40 val_loss
# 8800/10000 updates, 4.83 s, -92.73 train_loss, -115.09 val_loss
# 8900/10000 updates, 4.78 s, -140.42 train_loss, -151.43 val_loss
# 9000/10000 updates, 4.80 s, -226.47 train_loss, -148.53 val_loss
# 9100/10000 updates, 4.78 s, -119.42 train_loss, -127.54 val_loss
# 9200/10000 updates, 4.81 s, -41.08 train_loss, -142.23 val_loss
# 9300/10000 updates, 4.81 s, -124.91 train_loss, -142.05 val_loss
# 9400/10000 updates, 4.79 s, -129.62 train_loss, -130.16 val_loss
# 9500/10000 updates, 4.81 s, -149.58 train_loss, -168.28 val_loss
# 9600/10000 updates, 4.77 s, -223.39 train_loss, -153.86 val_loss
# 9700/10000 updates, 4.83 s, -0.10 train_loss, -86.34 val_loss
# 9800/10000 updates, 4.74 s, -129.96 train_loss, -119.40 val_loss
# 9900/10000 updates, 4.76 s, -134.57 train_loss, -174.18 val_loss
# 0 / 1000
# 100 / 1000
# 200 / 1000
# 300 / 1000
# 400 / 1000
# 500 / 1000
# 600 / 1000
# 700 / 1000
# 800 / 1000
# 900 / 1000

# %%
print("RMSE: {:.3f}".format(RMSE_notmiwae))
# Out:
# RMSE: 0.159

# %%
x_notmiwae = np.load('x_notmiwae.npy')

# %%
x_obs = x_data[mask]
x_miss = x_data[~mask]

x_est = x_notmiwae

x_est_obs = x_est[mask]
x_est_miss = x_est[~mask]

# %%
scatter_compare_individual_entries_panel(x_obs, x_miss, x_est_obs, x_est_miss)

# %%
hist_compare_individual_entries(x_obs, x_miss, x_est_obs, x_est_miss)

# %%
W, b = notmiwae.sess.run([notmiwae.W, notmiwae.b])

# %%
fig, ax = plt.subplots(ncols=1, figsize=(6, 5))

p_obs = detection_prob[mask]
x_obs = x_data[mask]

p_miss = detection_prob[~mask]
x_miss = x_data[~mask]

n = 5_000

ax.scatter(x_miss[:n], p_miss[:n], color="red", alpha=.1, s=2)
ax.scatter(x_obs[:n], p_obs[:n], color="blue", alpha=.1, s=2)
ax.set_title("entry intensity vs detection probability")
ax.set_xlabel("entry intensity")
ax.set_ylabel("detection probability")
ax.grid(True)
ax.set_axisbelow(True)

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

for n in range(W.shape[-1]):
    xs = np.linspace(0, 18, 100)
    logit = W[0, 0, n] * xs + b[0, 0, n]
    ys = sigmoid(logit)
    ax.plot(xs, ys, color="black", alpha=.3, linewidth=4)

# %% [markdown]
# ### not-MIWAE (self-masking known)

# %%
notmiwae = notMIWAE(Xnan, Xval, n_latent=n_latent, n_samples=n_samples, n_hidden=n_hidden, name=name, out_dist=out_dist, mechanism_weight=0.1, missing_process='selfmasking_known')

# ---- do the training
trainer.train(notmiwae, batch_size=batch_size, max_iter=max_iter, name=name + 'notmiwae')

# ---- find imputation RMSE
RMSE_notmiwae, x_notmiwae = utils.not_imputationRMSE(notmiwae, Xtrain, Xz, Xnan, S, L)

np.save('x_notmiwae.npy', x_notmiwae)
# Out:
# Creating graph...
# Saving session...
# Saving session...
# 0/10000 updates, 0.17 s, 71377.97 train_loss, 71212.30 val_loss
# Saving session...
# 100/10000 updates, 5.86 s, 2148.63 train_loss, 2266.06 val_loss
# Saving session...
# 200/10000 updates, 5.48 s, 1818.09 train_loss, 1764.18 val_loss
# Saving session...
# 300/10000 updates, 5.60 s, 1434.45 train_loss, 1473.75 val_loss
# Saving session...
# 400/10000 updates, 5.50 s, 1188.45 train_loss, 1168.62 val_loss
# Saving session...
# 500/10000 updates, 5.73 s, 684.79 train_loss, 674.74 val_loss
# Saving session...
# 600/10000 updates, 4.71 s, 411.79 train_loss, 405.78 val_loss
# Saving session...
# 700/10000 updates, 4.80 s, 176.46 train_loss, 157.95 val_loss
# Saving session...
# 800/10000 updates, 4.64 s, 127.15 train_loss, -58.13 val_loss
# 900/10000 updates, 4.90 s, 742.47 train_loss, 26.70 val_loss
# Saving session...
# 1000/10000 updates, 4.46 s, -185.05 train_loss, -147.99 val_loss
# 1100/10000 updates, 4.65 s, -251.98 train_loss, -62.89 val_loss
# Saving session...
# 1200/10000 updates, 4.59 s, -213.74 train_loss, -162.07 val_loss
# Saving session...
# 1300/10000 updates, 4.72 s, -259.28 train_loss, -249.54 val_loss
# 1400/10000 updates, 4.71 s, -276.44 train_loss, -205.73 val_loss
# 1500/10000 updates, 4.57 s, -286.00 train_loss, -211.57 val_loss
# 1600/10000 updates, 4.67 s, -163.19 train_loss, -195.45 val_loss
# Saving session...
# 1700/10000 updates, 4.60 s, -80.99 train_loss, -292.08 val_loss
# 1800/10000 updates, 4.67 s, -279.48 train_loss, -269.92 val_loss
# 1900/10000 updates, 4.66 s, 43.59 train_loss, 593.64 val_loss
# 2000/10000 updates, 4.58 s, -282.68 train_loss, -240.66 val_loss
# 2100/10000 updates, 4.57 s, -244.93 train_loss, -255.68 val_loss
# 2200/10000 updates, 4.68 s, -383.05 train_loss, -198.55 val_loss
# 2300/10000 updates, 4.72 s, -242.25 train_loss, -258.33 val_loss
# 2400/10000 updates, 4.75 s, 95.18 train_loss, -36.00 val_loss
# 2500/10000 updates, 4.73 s, -243.01 train_loss, -234.06 val_loss
# 2600/10000 updates, 4.68 s, -240.61 train_loss, -157.31 val_loss
# 2700/10000 updates, 4.69 s, -226.47 train_loss, -198.17 val_loss
# 2800/10000 updates, 4.96 s, -295.26 train_loss, -277.44 val_loss
# 2900/10000 updates, 5.43 s, -352.79 train_loss, -261.98 val_loss
# Saving session...
# 3000/10000 updates, 4.95 s, -301.53 train_loss, -334.57 val_loss
# 3100/10000 updates, 4.90 s, -283.57 train_loss, -306.75 val_loss
# 3200/10000 updates, 4.68 s, -360.36 train_loss, -325.69 val_loss
# 3300/10000 updates, 4.77 s, -323.21 train_loss, -209.88 val_loss
# Saving session...
# 3400/10000 updates, 4.68 s, -333.81 train_loss, -344.09 val_loss
# 3500/10000 updates, 4.77 s, -342.81 train_loss, -253.94 val_loss
# 3600/10000 updates, 4.70 s, -80.70 train_loss, -277.77 val_loss
# 3700/10000 updates, 4.99 s, -236.83 train_loss, -253.26 val_loss
# 3800/10000 updates, 5.13 s, -327.30 train_loss, -303.39 val_loss
# 3900/10000 updates, 4.91 s, -276.36 train_loss, -313.74 val_loss
# 4000/10000 updates, 5.08 s, -307.76 train_loss, -337.90 val_loss
# 4100/10000 updates, 5.23 s, -289.38 train_loss, -279.05 val_loss
# 4200/10000 updates, 5.11 s, -315.91 train_loss, -326.25 val_loss
# Saving session...
# 4300/10000 updates, 5.24 s, -360.80 train_loss, -361.36 val_loss
# 4400/10000 updates, 5.02 s, -365.89 train_loss, -336.54 val_loss
# 4500/10000 updates, 4.93 s, -370.30 train_loss, -303.11 val_loss
# Saving session...
# 4600/10000 updates, 4.90 s, -377.34 train_loss, -369.85 val_loss
# 4700/10000 updates, 4.91 s, -271.93 train_loss, -282.60 val_loss
# 4800/10000 updates, 4.99 s, -303.46 train_loss, -332.68 val_loss
# 4900/10000 updates, 5.11 s, -248.51 train_loss, -325.96 val_loss
# 5000/10000 updates, 5.58 s, -371.24 train_loss, -352.65 val_loss
# 5100/10000 updates, 4.99 s, -349.29 train_loss, -343.49 val_loss
# 5200/10000 updates, 5.45 s, -380.82 train_loss, -368.27 val_loss
# 5300/10000 updates, 5.50 s, -74.63 train_loss, -92.18 val_loss
# 5400/10000 updates, 5.80 s, -305.06 train_loss, -269.66 val_loss
# 5500/10000 updates, 4.74 s, -343.35 train_loss, -289.98 val_loss
# 5600/10000 updates, 5.10 s, -366.67 train_loss, -368.94 val_loss
# 5700/10000 updates, 5.04 s, -393.53 train_loss, -357.90 val_loss
# Saving session...
# 5800/10000 updates, 5.27 s, -408.39 train_loss, -370.45 val_loss
# 5900/10000 updates, 4.84 s, -443.76 train_loss, -362.03 val_loss
# 6000/10000 updates, 5.44 s, -402.42 train_loss, -320.19 val_loss
# 6100/10000 updates, 5.20 s, -190.86 train_loss, -343.74 val_loss
# 6200/10000 updates, 5.65 s, -320.95 train_loss, -322.23 val_loss
# Saving session...
# 6300/10000 updates, 5.96 s, -353.36 train_loss, -373.66 val_loss
# 6400/10000 updates, 5.61 s, -366.41 train_loss, -348.68 val_loss
# 6500/10000 updates, 5.36 s, -365.22 train_loss, -367.63 val_loss
# 6600/10000 updates, 5.91 s, -350.55 train_loss, -354.54 val_loss
# 6700/10000 updates, 5.93 s, -284.75 train_loss, -202.29 val_loss
# 6800/10000 updates, 5.80 s, -260.66 train_loss, -247.18 val_loss
# 6900/10000 updates, 5.56 s, -367.65 train_loss, -232.36 val_loss
# 7000/10000 updates, 5.07 s, -351.58 train_loss, -273.23 val_loss
# 7100/10000 updates, 5.24 s, -166.19 train_loss, -205.96 val_loss
# 7200/10000 updates, 5.35 s, -400.38 train_loss, -346.50 val_loss
# 7300/10000 updates, 5.00 s, -358.03 train_loss, -330.47 val_loss
# 7400/10000 updates, 5.52 s, -294.16 train_loss, -319.39 val_loss
# 7500/10000 updates, 4.75 s, -365.54 train_loss, -314.62 val_loss
# 7600/10000 updates, 5.11 s, -382.19 train_loss, -371.40 val_loss
# 7700/10000 updates, 5.37 s, -316.58 train_loss, -327.96 val_loss
# 7800/10000 updates, 5.53 s, -301.45 train_loss, -338.30 val_loss
# 7900/10000 updates, 4.97 s, -410.42 train_loss, -368.76 val_loss
# 8000/10000 updates, 5.90 s, -354.92 train_loss, -350.53 val_loss
# 8100/10000 updates, 4.59 s, -382.85 train_loss, -367.65 val_loss
# 8200/10000 updates, 5.69 s, -320.73 train_loss, -345.23 val_loss
# 8300/10000 updates, 4.94 s, -362.38 train_loss, -346.63 val_loss
# 8400/10000 updates, 4.90 s, -325.34 train_loss, -302.93 val_loss
# 8500/10000 updates, 4.82 s, -347.10 train_loss, -337.71 val_loss
# 8600/10000 updates, 4.90 s, -370.16 train_loss, -349.98 val_loss
# 8700/10000 updates, 4.79 s, -408.70 train_loss, -365.39 val_loss
# 8800/10000 updates, 4.79 s, -176.65 train_loss, -310.72 val_loss
# 8900/10000 updates, 4.84 s, -87.63 train_loss, -327.05 val_loss
# 9000/10000 updates, 4.89 s, -407.59 train_loss, -310.21 val_loss
# 9100/10000 updates, 4.79 s, -360.61 train_loss, -341.64 val_loss
# 9200/10000 updates, 4.66 s, -329.75 train_loss, -287.45 val_loss
# Saving session...
# 9300/10000 updates, 5.14 s, -361.62 train_loss, -374.66 val_loss
# 9400/10000 updates, 4.78 s, -284.88 train_loss, -330.22 val_loss
# 9500/10000 updates, 4.86 s, -305.45 train_loss, -361.44 val_loss
# 9600/10000 updates, 4.73 s, -401.09 train_loss, -349.06 val_loss
# 9700/10000 updates, 5.28 s, -293.80 train_loss, -367.45 val_loss
# 9800/10000 updates, 4.66 s, -369.40 train_loss, -359.45 val_loss
# Saving session...
# 9900/10000 updates, 5.40 s, -413.18 train_loss, -389.61 val_loss
# 0 / 1000
# 100 / 1000
# 200 / 1000
# 300 / 1000
# 400 / 1000
# 500 / 1000
# 600 / 1000
# 700 / 1000
# 800 / 1000
# 900 / 1000

# %%
print("RMSE: {:.3f}".format(RMSE_notmiwae))
# Out:
# RMSE: 0.153

# %%
x_notmiwae = np.load('x_notmiwae.npy')

# %%
x_obs = x_data[mask]
x_miss = x_data[~mask]

x_est = x_notmiwae

x_est_obs = x_est[mask]
x_est_miss = x_est[~mask]

# %%
scatter_compare_individual_entries_panel(x_obs, x_miss, x_est_obs, x_est_miss)

# %%
hist_compare_individual_entries(x_obs, x_miss, x_est_obs, x_est_miss)
