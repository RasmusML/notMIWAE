# %% [markdown]
# # Single-cell Proteomics Synthetic Data Generation

# %% [markdown]
# The goal of this notebook is to simulate a crude single-cell proteomics datasets with a MNAR mechanism, and show that not-MIWAE performs better than MIWAE.

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

from MIWAE import MIWAE
from notMIWAE import notMIWAE
import trainer
import utils

np.random.seed(42)
# Out:
# 2023-11-09 23:24:15.789939: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-11-09 23:24:15.791808: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-09 23:24:15.821190: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-09 23:24:15.821221: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-09 23:24:15.821247: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-09 23:24:15.827143: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-09 23:24:15.827803: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-09 23:24:16.521253: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# Plotting functions for later.

# %%
def scatter_compare_individual_entries_panel(x_obs, x_miss, x_est_obs, x_est_miss):
    fig, axes = plt.subplots(ncols=2, figsize=(12, 5))
    
    ax = axes[0]
    ax.scatter(x_obs, x_est_obs, s=1, alpha=0.1)
    lims = [np.min([ax.get_xlim(), ax.get_ylim()]), np.max([ax.get_xlim(), ax.get_ylim()])]
    ax.plot(lims, lims, "--", c="k")

    mse = np.mean((x_obs - x_est_obs)**2)
    ax.text(0.05, 0.95, f"MSE: {mse:.2f}", transform=ax.transAxes, fontsize=12, verticalalignment="top", bbox=dict(facecolor="white", alpha=0.8))

    ax.set_xlabel("Observed")
    ax.set_ylabel("Imputed")
    ax.set_title("Observed")
    ax.grid(True)
    ax.set_axisbelow(True)

    ax = axes[1]
    ax.scatter(x_miss, x_est_miss, s=1, alpha=0.1)
    lims = [np.min([ax.get_xlim(), ax.get_ylim()]), np.max([ax.get_xlim(), ax.get_ylim()])]
    ax.plot(lims, lims, "--", c="k")

    mse = np.mean((x_miss - x_est_miss)**2)
    ax.text(0.05, 0.95, f"MSE: {mse:.2f}", transform=ax.transAxes, fontsize=12, verticalalignment="top", bbox=dict(facecolor="white", alpha=0.8))

    ax.set_xlabel("Observed")
    ax.set_ylabel("Imputed")
    ax.set_title("Missing")
    ax.grid(True)

# %%
def hist_compare_individual_entries(x_obs, x_miss, x_est_obs, x_est_miss):
    fig, axes = plt.subplots(ncols=2, figsize=(12, 5))

    x_min = np.min([np.min(x_obs), np.min(x_miss), np.min(x_est_obs), np.min(x_est_miss)])
    x_max = np.max([np.max(x_obs), np.max(x_miss), np.max(x_est_obs), np.max(x_est_miss)])

    ax = axes[0]
    ax.hist([x_obs, x_miss], color=["blue", "red"], bins=50, edgecolor="black", linewidth=1.2, stacked=True)
    ax.set_title("Data")
    ax.set_xlabel("x")
    ax.set_ylabel("(stacked) count")
    ax.set_xlim(x_min, x_max)
    ax.grid(True)
    ax.set_axisbelow(True)
    ax.legend(labels=["$x_{obs}$", "$x_{miss}$"], fontsize=12)

    ax = axes[1]
    ax.hist([x_est_obs, x_est_miss], color=["blue", "red"], bins=50, edgecolor="black", linewidth=1.2, stacked=True)
    ax.set_title("Model")
    ax.set_xlabel("x")
    ax.set_ylabel("(stacked) count")
    ax.set_xlim(x_min, x_max)
    ax.grid(True)
    ax.set_axisbelow(True)
    ax.legend(labels=["$x_{obs}$", "$x_{miss}$"], fontsize=12)

# %% [markdown]
# ## Data generation

# %% [markdown]
# Let's start by generating the synthetic data and visualizing it.

# %%
def logistic(x, k=1, x0=0, L=1):
    return L / (1 + np.exp(-k * (x - x0)))


def simulate_data(n_cells=1000, n_proteins=900):
    # all cells are from the same group (cell-type)
    # the cell type has some protein distribution / signature
    cell_type_signature = np.random.uniform(5, 12, n_proteins)

    # each cell is a bit different
    cell_variation = np.random.normal(0, 1, n_cells)

    intensity = cell_type_signature.reshape(1, -1) + cell_variation.reshape(-1, 1)

    # the measurement is noisy
    x = np.random.normal(intensity, 0.1)

    # MNAR mechanism: self-masking (x -> m)
    # entries with low intensity are less likely to be sampled
    detection_prob = logistic(x, k=2, x0=7) # set x0=6, if you want less missing values

    # sample using a bernoulli distribution
    mask = np.random.binomial(1, detection_prob)
    mask = mask.astype(bool)

    return x, detection_prob, mask

# %% [markdown]
# Let's simulate some data:

# %%
x_data, detection_prob, mask = simulate_data()

# %%
x_nan = x_data.copy()
x_nan[~mask] = np.nan

x_0 = x_data.copy()
x_0[~mask] = 0

# %%
print("Missing entries: {:.2f}%".format(np.isnan(x_nan).sum() / x_nan.size * 100))
# Out:
# Missing entries: 29.27%

# %% [markdown]
# Let's plot the data. "White" are the missing values.

# %%
fig, ax = plt.subplots(figsize=(8, 5))
sns.heatmap(x_nan, cmap="viridis", xticklabels=False, yticklabels=False, ax=ax)
ax.set_xlabel("Proteins")
ax.set_ylabel("Cells")
ax.set_title("Expression matrix with missing values")
# Out:
# Text(0.5, 1.0, 'Expression matrix with missing values')

# %% [markdown]
# Let's look at the missigness pattern entry-wise and protein-wise:

# %%
fig, axes = plt.subplots(ncols=2, figsize=(12, 5))

# plot entry intensity vs detection probability
ax = axes[0]

p_obs = detection_prob[mask]
x_obs = x_data[mask]

p_miss = detection_prob[~mask]
x_miss = x_data[~mask]

n = 5_000

ax.scatter(x_miss[:n], p_miss[:n], color="red", alpha=.1, s=4)
ax.scatter(x_obs[:n], p_obs[:n], color="blue", alpha=.1, s=4)
ax.set_title("entry intensity vs detection probability")
ax.set_xlabel("entry intensity")
ax.set_ylabel("detection probability")
ax.grid(True)
ax.set_axisbelow(True)

# plot the average protein intensity vs the detection proportion
ax = axes[1]
x_obs_protein = np.nanmean(x_nan, axis=0)
p_protein = 1 - np.nanmean(np.isnan(x_nan), axis=0)

ax.scatter(x_obs_protein, p_protein, color="blue", alpha=1, s=6)
ax.set_title("avg protein intensity vs detection proportion")
ax.set_xlabel("protein intensity")
ax.set_ylabel("detection proportion")
ax.grid(True)
ax.set_axisbelow(True)

# %%
fig, ax = plt.subplots(1, 1, figsize=(5, 5))

ax.hist([x_obs, x_miss], color=["blue", "red"], bins=50, edgecolor="black", linewidth=1.2, stacked=True)
ax.set_title("Data")
ax.set_xlabel("x")
ax.set_ylabel("(stacked) count")
ax.set_xlim(np.min(x_data), np.max(x_data))
ax.grid(True)
ax.set_axisbelow(True)
ax.legend(labels=["$x_{obs}$", "$x_{miss}$"], fontsize=12)

# %% [markdown]
# ## Model Comparison

# %% [markdown]
# Set the parameters for the models.

# %%
name = '/tmp/best'

# model specification
n_hidden = 128
n_samples = 20
n_latent = 16
mprocess = 'selfmasking' #'selfmasking_known'
out_dist='gauss'

# training
max_iter = 20_000
batch_size = 32

# imputation
L = 10000

# %% [markdown]
# Let's run.

# %%
N, D = x_data.shape

Xtrain = x_data.copy()
Xval_org = x_data.copy()

Xnan = x_nan.copy()
Xz = x_0.copy()
S = mask.copy()

Xval = x_nan.copy()
Xvalz = x_0.copy()

# %%
tf.compat.v1.disable_eager_execution()

# %% [markdown]
# ### MIWAE

# %%
miwae = MIWAE(Xnan, Xval, n_latent=n_latent, n_samples=n_samples, n_hidden=n_hidden, name=name, out_dist=out_dist)

# ---- do the training
trainer.train(miwae, batch_size=batch_size, max_iter=max_iter, name=name + 'miwae')

# ---- find imputation RMSE
RMSE_miwae, x_miwae = utils.imputationRMSE(miwae, Xtrain, Xz, Xnan, S, L)

np.save('x_miwae.npy', x_miwae)
# Out:
# Creating graph...
# 2023-11-09 23:24:20.281736: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:382] MLIR V1 optimization pass is not enabled
# Saving session...
# Saving session...
# 0/20000 updates, 0.29 s, 61432.24 train_loss, 63506.62 val_loss
# Saving session...
# 100/20000 updates, 2.47 s, 1952.50 train_loss, 1975.86 val_loss
# Saving session...
# 200/20000 updates, 2.76 s, 1597.45 train_loss, 1547.73 val_loss
# Saving session...
# 300/20000 updates, 2.99 s, 1322.30 train_loss, 1300.55 val_loss
# Saving session...
# 400/20000 updates, 2.61 s, 1055.80 train_loss, 1012.46 val_loss
# Saving session...
# 500/20000 updates, 3.06 s, 674.04 train_loss, 683.17 val_loss
# Saving session...
# 600/20000 updates, 2.60 s, 482.29 train_loss, 509.41 val_loss
# Saving session...
# 700/20000 updates, 2.33 s, 626.90 train_loss, 242.90 val_loss
# Saving session...
# 800/20000 updates, 2.56 s, 205.76 train_loss, 235.69 val_loss
# Saving session...
# 900/20000 updates, 2.70 s, -18.18 train_loss, -19.20 val_loss
# Saving session...
# 1000/20000 updates, 2.64 s, -88.92 train_loss, -34.43 val_loss
# Saving session...
# 1100/20000 updates, 2.87 s, 36.40 train_loss, -41.15 val_loss
# Saving session...
# 1200/20000 updates, 2.73 s, -84.47 train_loss, -52.97 val_loss
# 1300/20000 updates, 2.50 s, -6.62 train_loss, 8.02 val_loss
# Saving session...
# 1400/20000 updates, 2.59 s, -259.40 train_loss, -106.86 val_loss
# 1500/20000 updates, 2.63 s, 117.73 train_loss, 63.23 val_loss
# 1600/20000 updates, 2.72 s, -239.55 train_loss, -56.26 val_loss
# 1700/20000 updates, 2.61 s, -112.17 train_loss, -35.79 val_loss
# Saving session...
# 1800/20000 updates, 2.47 s, 120.76 train_loss, -154.52 val_loss
# 1900/20000 updates, 2.59 s, -34.14 train_loss, -95.78 val_loss
# 2000/20000 updates, 2.60 s, -112.00 train_loss, -124.62 val_loss
# 2100/20000 updates, 2.56 s, -78.40 train_loss, -112.41 val_loss
# 2200/20000 updates, 2.60 s, 123.22 train_loss, 15.15 val_loss
# 2300/20000 updates, 2.61 s, 155.08 train_loss, 6.89 val_loss
# 2400/20000 updates, 2.58 s, -97.29 train_loss, -119.88 val_loss
# 2500/20000 updates, 2.63 s, -36.35 train_loss, -64.31 val_loss
# 2600/20000 updates, 2.53 s, -253.48 train_loss, -80.60 val_loss
# 2700/20000 updates, 2.61 s, -68.11 train_loss, -94.98 val_loss
# 2800/20000 updates, 2.61 s, -252.33 train_loss, -72.74 val_loss
# 2900/20000 updates, 2.58 s, -121.73 train_loss, -92.19 val_loss
# 3000/20000 updates, 2.65 s, 166.36 train_loss, -94.33 val_loss
# 3100/20000 updates, 2.57 s, -35.55 train_loss, -79.58 val_loss
# 3200/20000 updates, 2.64 s, -192.05 train_loss, -116.21 val_loss
# 3300/20000 updates, 2.57 s, -189.41 train_loss, -124.44 val_loss
# 3400/20000 updates, 2.61 s, -81.46 train_loss, -71.32 val_loss
# 3500/20000 updates, 2.62 s, -251.53 train_loss, -133.61 val_loss
# 3600/20000 updates, 2.54 s, -51.76 train_loss, -91.27 val_loss
# 3700/20000 updates, 2.61 s, -32.88 train_loss, -84.28 val_loss
# Saving session...
# 3800/20000 updates, 2.61 s, -155.02 train_loss, -171.98 val_loss
# 3900/20000 updates, 2.67 s, -33.53 train_loss, -105.91 val_loss
# 4000/20000 updates, 2.63 s, -61.15 train_loss, -108.64 val_loss
# 4100/20000 updates, 2.55 s, -197.66 train_loss, -131.46 val_loss
# 4200/20000 updates, 2.62 s, -177.29 train_loss, -137.64 val_loss
# 4300/20000 updates, 2.63 s, -112.46 train_loss, -27.74 val_loss
# 4400/20000 updates, 2.60 s, -223.82 train_loss, -149.82 val_loss
# 4500/20000 updates, 2.65 s, -44.91 train_loss, -110.44 val_loss
# 4600/20000 updates, 2.59 s, 206.05 train_loss, -123.08 val_loss
# 4700/20000 updates, 2.63 s, -126.41 train_loss, -97.93 val_loss
# 4800/20000 updates, 2.58 s, -58.64 train_loss, -109.33 val_loss
# 4900/20000 updates, 2.65 s, -113.81 train_loss, -95.64 val_loss
# 5000/20000 updates, 2.83 s, 39.50 train_loss, -126.77 val_loss
# 5100/20000 updates, 1.73 s, -171.30 train_loss, -118.11 val_loss
# 5200/20000 updates, 1.97 s, 93.83 train_loss, 88.14 val_loss
# 5300/20000 updates, 2.24 s, -195.27 train_loss, -128.72 val_loss
# 5400/20000 updates, 2.98 s, -14.33 train_loss, -96.63 val_loss
# 5500/20000 updates, 2.79 s, -70.07 train_loss, -136.11 val_loss
# 5600/20000 updates, 2.76 s, -210.38 train_loss, -67.11 val_loss
# 5700/20000 updates, 2.69 s, -183.90 train_loss, -79.18 val_loss
# 5800/20000 updates, 2.71 s, -104.10 train_loss, 51.74 val_loss
# 5900/20000 updates, 2.32 s, -170.06 train_loss, -116.07 val_loss
# 6000/20000 updates, 2.48 s, -212.98 train_loss, -128.13 val_loss
# 6100/20000 updates, 2.79 s, -201.26 train_loss, -109.93 val_loss
# 6200/20000 updates, 3.09 s, 31.56 train_loss, 52.96 val_loss
# 6300/20000 updates, 2.69 s, -159.54 train_loss, -108.73 val_loss
# 6400/20000 updates, 2.70 s, -161.33 train_loss, -79.23 val_loss
# 6500/20000 updates, 2.56 s, -121.72 train_loss, -150.79 val_loss
# 6600/20000 updates, 2.66 s, -0.92 train_loss, -97.90 val_loss
# 6700/20000 updates, 2.51 s, -101.36 train_loss, -124.76 val_loss
# 6800/20000 updates, 2.63 s, -68.05 train_loss, -92.67 val_loss
# 6900/20000 updates, 2.52 s, -229.76 train_loss, -111.78 val_loss
# 7000/20000 updates, 2.58 s, -118.28 train_loss, -103.33 val_loss
# Saving session...
# 7100/20000 updates, 2.42 s, -3.38 train_loss, -176.40 val_loss
# 7200/20000 updates, 2.68 s, -164.19 train_loss, -150.44 val_loss
# 7300/20000 updates, 2.60 s, 18.56 train_loss, -56.73 val_loss
# 7400/20000 updates, 2.57 s, -45.83 train_loss, -138.68 val_loss
# 7500/20000 updates, 2.57 s, -150.28 train_loss, -149.44 val_loss
# 7600/20000 updates, 2.88 s, -135.05 train_loss, -110.79 val_loss
# 7700/20000 updates, 2.65 s, -170.63 train_loss, -155.25 val_loss
# 7800/20000 updates, 2.54 s, -229.18 train_loss, -139.69 val_loss
# 7900/20000 updates, 2.59 s, -108.51 train_loss, -127.60 val_loss
# 8000/20000 updates, 2.62 s, -34.21 train_loss, -50.28 val_loss
# 8100/20000 updates, 2.62 s, 46.83 train_loss, -126.14 val_loss
# 8200/20000 updates, 2.59 s, -197.32 train_loss, -124.36 val_loss
# 8300/20000 updates, 2.57 s, 10.47 train_loss, -83.04 val_loss
# 8400/20000 updates, 2.61 s, -155.25 train_loss, -128.47 val_loss
# 8500/20000 updates, 2.54 s, -115.34 train_loss, -123.98 val_loss
# 8600/20000 updates, 2.65 s, -157.40 train_loss, -140.44 val_loss
# 8700/20000 updates, 2.54 s, -144.64 train_loss, -105.93 val_loss
# 8800/20000 updates, 2.66 s, -86.98 train_loss, -91.84 val_loss
# 8900/20000 updates, 2.42 s, -235.16 train_loss, -134.41 val_loss
# 9000/20000 updates, 2.69 s, -155.84 train_loss, -76.41 val_loss
# 9100/20000 updates, 2.66 s, -157.55 train_loss, -160.79 val_loss
# 9200/20000 updates, 2.66 s, -251.59 train_loss, -103.01 val_loss
# 9300/20000 updates, 2.56 s, -94.99 train_loss, -156.01 val_loss
# 9400/20000 updates, 2.67 s, -135.75 train_loss, -169.79 val_loss
# 9500/20000 updates, 2.60 s, -166.72 train_loss, -114.90 val_loss
# 9600/20000 updates, 2.59 s, -143.21 train_loss, -29.76 val_loss
# 9700/20000 updates, 2.59 s, -151.21 train_loss, -157.11 val_loss
# 9800/20000 updates, 2.64 s, -171.41 train_loss, 11.25 val_loss
# 9900/20000 updates, 2.36 s, -40.06 train_loss, -146.12 val_loss
# 10000/20000 updates, 2.67 s, -163.14 train_loss, -136.99 val_loss
# 10100/20000 updates, 2.56 s, -39.24 train_loss, -122.94 val_loss
# 10200/20000 updates, 2.46 s, -213.06 train_loss, -158.09 val_loss
# 10300/20000 updates, 2.37 s, 285.77 train_loss, -98.02 val_loss
# 10400/20000 updates, 2.66 s, -109.87 train_loss, -129.66 val_loss
# 10500/20000 updates, 2.67 s, -170.33 train_loss, -124.26 val_loss
# 10600/20000 updates, 2.93 s, -215.78 train_loss, -130.71 val_loss
# 10700/20000 updates, 2.66 s, -185.14 train_loss, -144.16 val_loss
# 10800/20000 updates, 2.60 s, -133.61 train_loss, -100.71 val_loss
# 10900/20000 updates, 2.88 s, -133.82 train_loss, -133.54 val_loss
# 11000/20000 updates, 2.87 s, -11.00 train_loss, -96.34 val_loss
# 11100/20000 updates, 2.81 s, -251.43 train_loss, -134.08 val_loss
# 11200/20000 updates, 2.52 s, -119.41 train_loss, -111.86 val_loss
# 11300/20000 updates, 2.39 s, -115.06 train_loss, -86.07 val_loss
# 11400/20000 updates, 2.65 s, -223.89 train_loss, -114.41 val_loss
# 11500/20000 updates, 2.75 s, -251.66 train_loss, -126.35 val_loss
# 11600/20000 updates, 2.80 s, -21.51 train_loss, -28.09 val_loss
# 11700/20000 updates, 2.81 s, -54.87 train_loss, -111.03 val_loss
# 11800/20000 updates, 2.76 s, -137.89 train_loss, -102.85 val_loss
# 11900/20000 updates, 2.81 s, -262.40 train_loss, -121.56 val_loss
# 12000/20000 updates, 2.82 s, -191.56 train_loss, -144.44 val_loss
# 12100/20000 updates, 2.76 s, -106.96 train_loss, -112.01 val_loss
# 12200/20000 updates, 2.86 s, -232.15 train_loss, -97.76 val_loss
# 12300/20000 updates, 2.81 s, -173.95 train_loss, -133.87 val_loss
# 12400/20000 updates, 2.81 s, -171.49 train_loss, -155.02 val_loss
# 12500/20000 updates, 2.74 s, -118.41 train_loss, -168.17 val_loss
# 12600/20000 updates, 2.88 s, -178.56 train_loss, -140.35 val_loss
# 12700/20000 updates, 2.73 s, -152.88 train_loss, -155.16 val_loss
# 12800/20000 updates, 2.72 s, -182.23 train_loss, -121.37 val_loss
# 12900/20000 updates, 2.87 s, -197.86 train_loss, -136.01 val_loss
# 13000/20000 updates, 2.90 s, -78.52 train_loss, -90.35 val_loss
# 13100/20000 updates, 2.86 s, -277.91 train_loss, -158.54 val_loss
# 13200/20000 updates, 2.79 s, -30.98 train_loss, -89.86 val_loss
# 13300/20000 updates, 2.80 s, -93.29 train_loss, -114.25 val_loss
# 13400/20000 updates, 2.76 s, -81.60 train_loss, -124.02 val_loss
# 13500/20000 updates, 2.74 s, -118.20 train_loss, -113.20 val_loss
# 13600/20000 updates, 2.62 s, -148.95 train_loss, -113.82 val_loss
# 13700/20000 updates, 2.77 s, -90.91 train_loss, -58.22 val_loss
# 13800/20000 updates, 2.89 s, 174.76 train_loss, -95.11 val_loss
# 13900/20000 updates, 2.70 s, -86.04 train_loss, -145.96 val_loss
# 14000/20000 updates, 2.29 s, 36.12 train_loss, -139.87 val_loss
# 14100/20000 updates, 2.45 s, -117.31 train_loss, -132.19 val_loss
# 14200/20000 updates, 2.76 s, -183.54 train_loss, -122.31 val_loss
# 14300/20000 updates, 2.64 s, 49.10 train_loss, -127.52 val_loss
# 14400/20000 updates, 2.42 s, 215.09 train_loss, -124.58 val_loss
# 14500/20000 updates, 2.60 s, -127.10 train_loss, -144.47 val_loss
# 14600/20000 updates, 2.89 s, -210.59 train_loss, -125.17 val_loss
# 14700/20000 updates, 2.68 s, -74.27 train_loss, -131.41 val_loss
# 14800/20000 updates, 2.82 s, -186.97 train_loss, -105.00 val_loss
# 14900/20000 updates, 2.53 s, -260.66 train_loss, -172.04 val_loss
# 15000/20000 updates, 2.79 s, -98.81 train_loss, -155.87 val_loss
# 15100/20000 updates, 3.06 s, -137.63 train_loss, -107.89 val_loss
# 15200/20000 updates, 3.29 s, -189.08 train_loss, -140.81 val_loss
# 15300/20000 updates, 3.54 s, -202.32 train_loss, -59.36 val_loss
# 15400/20000 updates, 3.48 s, -172.69 train_loss, -140.64 val_loss
# 15500/20000 updates, 3.03 s, 88.10 train_loss, -141.05 val_loss
# 15600/20000 updates, 3.27 s, -145.09 train_loss, -99.56 val_loss
# 15700/20000 updates, 3.42 s, 1212.29 train_loss, -23.56 val_loss
# 15800/20000 updates, 3.43 s, -205.95 train_loss, -122.17 val_loss
# 15900/20000 updates, 3.43 s, -71.69 train_loss, -141.40 val_loss
# 16000/20000 updates, 3.14 s, -172.53 train_loss, -46.23 val_loss
# 16100/20000 updates, 3.48 s, -191.09 train_loss, -102.74 val_loss
# 16200/20000 updates, 3.42 s, -185.65 train_loss, -136.15 val_loss
# 16300/20000 updates, 3.65 s, -203.23 train_loss, -140.03 val_loss
# 16400/20000 updates, 2.95 s, 70.40 train_loss, 181.39 val_loss
# 16500/20000 updates, 2.89 s, -68.98 train_loss, -88.69 val_loss
# 16600/20000 updates, 2.87 s, -120.27 train_loss, -106.17 val_loss
# 16700/20000 updates, 2.82 s, -195.62 train_loss, -171.73 val_loss
# 16800/20000 updates, 2.86 s, -289.76 train_loss, -160.77 val_loss
# 16900/20000 updates, 2.80 s, -277.38 train_loss, -155.04 val_loss
# 17000/20000 updates, 2.91 s, -66.19 train_loss, -147.98 val_loss
# 17100/20000 updates, 2.88 s, -210.44 train_loss, -121.57 val_loss
# 17200/20000 updates, 2.88 s, -210.58 train_loss, -146.71 val_loss
# 17300/20000 updates, 2.77 s, -245.23 train_loss, -147.90 val_loss
# 17400/20000 updates, 2.86 s, -113.23 train_loss, -136.90 val_loss
# 17500/20000 updates, 2.76 s, -132.60 train_loss, -122.11 val_loss
# 17600/20000 updates, 2.84 s, -248.83 train_loss, -79.34 val_loss
# 17700/20000 updates, 2.57 s, -54.64 train_loss, -127.78 val_loss
# 17800/20000 updates, 2.86 s, -221.50 train_loss, -63.37 val_loss
# 17900/20000 updates, 2.74 s, -153.54 train_loss, -92.08 val_loss
# 18000/20000 updates, 2.76 s, -231.03 train_loss, -98.39 val_loss
# 18100/20000 updates, 2.74 s, -33.40 train_loss, -96.10 val_loss
# 18200/20000 updates, 2.85 s, -157.27 train_loss, -114.47 val_loss
# 18300/20000 updates, 2.76 s, -133.47 train_loss, -51.98 val_loss
# 18400/20000 updates, 2.84 s, 1.76 train_loss, -117.18 val_loss
# 18500/20000 updates, 2.71 s, 17.22 train_loss, -70.85 val_loss
# 18600/20000 updates, 2.84 s, -12.94 train_loss, -84.97 val_loss
# 18700/20000 updates, 2.73 s, -30.82 train_loss, -39.60 val_loss
# 18800/20000 updates, 2.83 s, -48.38 train_loss, -109.24 val_loss
# 18900/20000 updates, 2.76 s, -177.74 train_loss, -132.92 val_loss
# 19000/20000 updates, 2.85 s, -114.65 train_loss, -109.53 val_loss
# 19100/20000 updates, 2.77 s, -179.94 train_loss, -107.71 val_loss
# Saving session...
# 19200/20000 updates, 2.86 s, -136.29 train_loss, -176.67 val_loss
# 19300/20000 updates, 2.79 s, -101.52 train_loss, -124.26 val_loss
# 19400/20000 updates, 2.84 s, -204.77 train_loss, -128.93 val_loss
# 19500/20000 updates, 2.79 s, -234.21 train_loss, -122.48 val_loss
# 19600/20000 updates, 2.84 s, -157.03 train_loss, -127.70 val_loss
# 19700/20000 updates, 2.77 s, -79.68 train_loss, -156.50 val_loss
# 19800/20000 updates, 2.86 s, -100.79 train_loss, -132.81 val_loss
# 19900/20000 updates, 2.72 s, -198.02 train_loss, -145.79 val_loss
# 0 / 1000
# 100 / 1000
# 200 / 1000
# 300 / 1000
# 400 / 1000
# 500 / 1000
# 600 / 1000
# 700 / 1000
# 800 / 1000
# 900 / 1000

# %%
print("RMSE: {:.3f}".format(RMSE_miwae))
# Out:
# RMSE: 0.231

# %%
x_miwae = np.load('x_miwae.npy')

# %%
x_obs = x_data[mask]
x_miss = x_data[~mask]

x_est = x_miwae

x_est_obs = x_est[mask]
x_est_miss = x_est[~mask]

# %%
scatter_compare_individual_entries_panel(x_obs, x_miss, x_est_obs, x_est_miss)

# %%
hist_compare_individual_entries(x_obs, x_miss, x_est_obs, x_est_miss)

# %% [markdown]
# ### not-MIWAE

# %%
notmiwae = notMIWAE(Xnan, Xval, n_latent=n_latent, n_samples=n_samples, n_hidden=n_hidden, missing_process=mprocess, name=name, out_dist=out_dist)

# ---- do the training
trainer.train(notmiwae, batch_size=batch_size, max_iter=max_iter, name=name + 'notmiwae')

# ---- find imputation RMSE
RMSE_notmiwae, x_notmiwae = utils.not_imputationRMSE(notmiwae, Xtrain, Xz, Xnan, S, L)

np.save('x_notmiwae.npy', x_notmiwae)
# Out:
# Creating graph...
# Saving session...
# Saving session...
# 0/20000 updates, 0.17 s, 61831.96 train_loss, 63107.09 val_loss
# Saving session...
# 100/20000 updates, 3.87 s, 2420.93 train_loss, 2403.87 val_loss
# Saving session...
# 200/20000 updates, 3.91 s, 2043.27 train_loss, 2002.58 val_loss
# Saving session...
# 300/20000 updates, 4.22 s, 1806.88 train_loss, 1766.99 val_loss
# Saving session...
# 400/20000 updates, 4.12 s, 1446.58 train_loss, 1473.05 val_loss
# Saving session...
# 500/20000 updates, 4.24 s, 1066.23 train_loss, 1121.69 val_loss
# Saving session...
# 600/20000 updates, 4.11 s, 790.09 train_loss, 849.09 val_loss
# Saving session...
# 700/20000 updates, 4.14 s, 557.01 train_loss, 586.51 val_loss
# Saving session...
# 800/20000 updates, 4.09 s, 459.50 train_loss, 455.72 val_loss
# 900/20000 updates, 4.28 s, 536.35 train_loss, 532.68 val_loss
# 1000/20000 updates, 4.05 s, 399.57 train_loss, 516.68 val_loss
# Saving session...
# 1100/20000 updates, 4.20 s, 452.03 train_loss, 373.31 val_loss
# 1200/20000 updates, 4.11 s, 674.74 train_loss, 592.74 val_loss
# 1300/20000 updates, 4.22 s, 393.13 train_loss, 382.38 val_loss
# 1400/20000 updates, 4.12 s, 348.06 train_loss, 458.55 val_loss
# 1500/20000 updates, 4.21 s, 684.42 train_loss, 376.94 val_loss
# 1600/20000 updates, 3.89 s, 216.68 train_loss, 386.37 val_loss
# Saving session...
# 1700/20000 updates, 3.75 s, 249.94 train_loss, 332.15 val_loss
# Saving session...
# 1800/20000 updates, 4.20 s, 310.18 train_loss, 302.51 val_loss
# 1900/20000 updates, 4.42 s, 420.27 train_loss, 330.19 val_loss
# 2000/20000 updates, 4.03 s, 213.03 train_loss, 355.90 val_loss
# 2100/20000 updates, 4.44 s, 271.02 train_loss, 378.77 val_loss
# 2200/20000 updates, 4.27 s, 281.75 train_loss, 306.64 val_loss
# Saving session...
# 2300/20000 updates, 4.21 s, 217.92 train_loss, 285.95 val_loss
# 2400/20000 updates, 4.19 s, 237.37 train_loss, 291.65 val_loss
# 2500/20000 updates, 4.26 s, 374.41 train_loss, 288.26 val_loss
# 2600/20000 updates, 4.40 s, 287.91 train_loss, 316.15 val_loss
# Saving session...
# 2700/20000 updates, 4.49 s, 154.65 train_loss, 279.05 val_loss
# 2800/20000 updates, 4.32 s, 215.65 train_loss, 292.81 val_loss
# Saving session...
# 2900/20000 updates, 4.23 s, 274.48 train_loss, 242.87 val_loss
# 3000/20000 updates, 4.21 s, 356.99 train_loss, 305.61 val_loss
# 3100/20000 updates, 4.52 s, 223.72 train_loss, 294.16 val_loss
# 3200/20000 updates, 4.37 s, 330.25 train_loss, 252.41 val_loss
# 3300/20000 updates, 4.32 s, 396.23 train_loss, 263.53 val_loss
# 3400/20000 updates, 4.29 s, 190.98 train_loss, 247.89 val_loss
# 3500/20000 updates, 4.51 s, 278.00 train_loss, 243.18 val_loss
# 3600/20000 updates, 4.04 s, 365.29 train_loss, 295.81 val_loss
# 3700/20000 updates, 4.05 s, 100.47 train_loss, 276.49 val_loss
# 3800/20000 updates, 4.01 s, 188.04 train_loss, 270.54 val_loss
# Saving session...
# 3900/20000 updates, 4.28 s, 172.00 train_loss, 214.58 val_loss
# 4000/20000 updates, 4.25 s, 287.67 train_loss, 289.70 val_loss
# 4100/20000 updates, 4.41 s, 141.71 train_loss, 225.34 val_loss
# Saving session...
# 4200/20000 updates, 4.03 s, 245.40 train_loss, 191.38 val_loss
# 4300/20000 updates, 4.71 s, 213.50 train_loss, 245.18 val_loss
# 4400/20000 updates, 3.97 s, 156.26 train_loss, 236.05 val_loss
# 4500/20000 updates, 4.40 s, 177.77 train_loss, 202.29 val_loss
# 4600/20000 updates, 4.36 s, 340.61 train_loss, 290.44 val_loss
# 4700/20000 updates, 4.47 s, 300.35 train_loss, 226.77 val_loss
# 4800/20000 updates, 4.24 s, 46.91 train_loss, 225.38 val_loss
# 4900/20000 updates, 4.44 s, 239.15 train_loss, 203.85 val_loss
# 5000/20000 updates, 4.20 s, 181.31 train_loss, 206.04 val_loss
# 5100/20000 updates, 4.32 s, 224.08 train_loss, 195.26 val_loss
# 5200/20000 updates, 4.25 s, 182.95 train_loss, 217.24 val_loss
# 5300/20000 updates, 4.33 s, 171.72 train_loss, 242.29 val_loss
# 5400/20000 updates, 3.91 s, 141.16 train_loss, 212.75 val_loss
# Saving session...
# 5500/20000 updates, 4.21 s, 36.05 train_loss, 146.90 val_loss
# 5600/20000 updates, 4.16 s, 144.45 train_loss, 159.17 val_loss
# Saving session...
# 5700/20000 updates, 4.21 s, 138.44 train_loss, 136.56 val_loss
# 5800/20000 updates, 4.08 s, 226.81 train_loss, 221.66 val_loss
# 5900/20000 updates, 4.21 s, 163.26 train_loss, 164.79 val_loss
# 6000/20000 updates, 4.07 s, 185.41 train_loss, 144.02 val_loss
# Saving session...
# 6100/20000 updates, 4.17 s, 79.32 train_loss, 134.23 val_loss
# 6200/20000 updates, 4.15 s, 131.90 train_loss, 167.21 val_loss
# 6300/20000 updates, 4.23 s, 206.91 train_loss, 198.62 val_loss
# 6400/20000 updates, 4.10 s, 123.50 train_loss, 134.49 val_loss
# Saving session...
# 6500/20000 updates, 4.16 s, 207.08 train_loss, 132.10 val_loss
# Saving session...
# 6600/20000 updates, 4.15 s, 39.41 train_loss, 122.64 val_loss
# Saving session...
# 6700/20000 updates, 4.29 s, 99.97 train_loss, 105.34 val_loss
# Saving session...
# 6800/20000 updates, 4.16 s, 118.89 train_loss, 82.29 val_loss
# Saving session...
# 6900/20000 updates, 4.26 s, 57.99 train_loss, 78.94 val_loss
# 7000/20000 updates, 4.16 s, 339.54 train_loss, 139.91 val_loss
# 7100/20000 updates, 4.20 s, 181.57 train_loss, 175.37 val_loss
# Saving session...
# 7200/20000 updates, 4.09 s, 57.58 train_loss, 72.49 val_loss
# 7300/20000 updates, 4.27 s, 220.45 train_loss, 196.28 val_loss
# 7400/20000 updates, 4.09 s, 82.10 train_loss, 81.91 val_loss
# 7500/20000 updates, 4.20 s, 70.98 train_loss, 144.94 val_loss
# Saving session...
# 7600/20000 updates, 4.05 s, 1124.03 train_loss, 53.09 val_loss
# 7700/20000 updates, 4.30 s, 60.47 train_loss, 181.56 val_loss
# 7800/20000 updates, 3.86 s, 33.16 train_loss, 84.07 val_loss
# 7900/20000 updates, 4.23 s, -5.06 train_loss, 62.45 val_loss
# 8000/20000 updates, 4.03 s, 21.30 train_loss, 56.74 val_loss
# 8100/20000 updates, 4.21 s, 96.46 train_loss, 105.83 val_loss
# 8200/20000 updates, 4.15 s, 41.28 train_loss, 94.35 val_loss
# 8300/20000 updates, 4.20 s, 65.55 train_loss, 142.38 val_loss
# 8400/20000 updates, 4.12 s, 104.66 train_loss, 67.48 val_loss
# 8500/20000 updates, 4.21 s, 5.04 train_loss, 74.60 val_loss
# 8600/20000 updates, 4.17 s, 186.19 train_loss, 100.02 val_loss
# 8700/20000 updates, 3.98 s, 498.19 train_loss, 103.75 val_loss
# 8800/20000 updates, 3.95 s, -19.15 train_loss, 65.50 val_loss
# Saving session...
# 8900/20000 updates, 3.81 s, 15.97 train_loss, 48.50 val_loss
# 9000/20000 updates, 4.07 s, -73.73 train_loss, 64.42 val_loss
# 9100/20000 updates, 4.47 s, 109.65 train_loss, 102.78 val_loss
# 9200/20000 updates, 4.28 s, 180.64 train_loss, 141.89 val_loss
# 9300/20000 updates, 4.46 s, 27.13 train_loss, 92.88 val_loss
# Saving session...
# 9400/20000 updates, 4.13 s, -19.24 train_loss, 44.54 val_loss
# 9500/20000 updates, 4.22 s, 73.09 train_loss, 108.69 val_loss
# 9600/20000 updates, 4.11 s, 207.92 train_loss, 77.10 val_loss
# 9700/20000 updates, 3.37 s, 26.20 train_loss, 55.91 val_loss
# 9800/20000 updates, 2.90 s, 3.75 train_loss, 49.89 val_loss
# 9900/20000 updates, 3.19 s, 88.68 train_loss, 79.44 val_loss
# 10000/20000 updates, 2.79 s, 1867.55 train_loss, 102.99 val_loss
# 10100/20000 updates, 2.78 s, 31.36 train_loss, 62.09 val_loss
# 10200/20000 updates, 2.48 s, 179.24 train_loss, 95.89 val_loss
# 10300/20000 updates, 3.04 s, 356.37 train_loss, 65.30 val_loss
# 10400/20000 updates, 3.46 s, 78.64 train_loss, 110.97 val_loss
# 10500/20000 updates, 3.87 s, 104.01 train_loss, 75.72 val_loss
# 10600/20000 updates, 3.65 s, 132.03 train_loss, 55.63 val_loss
# 10700/20000 updates, 3.87 s, 150.49 train_loss, 160.58 val_loss
# 10800/20000 updates, 3.38 s, 93.59 train_loss, 83.20 val_loss
# 10900/20000 updates, 3.94 s, -2.24 train_loss, 51.57 val_loss
# 11000/20000 updates, 3.47 s, 81.04 train_loss, 137.50 val_loss
# 11100/20000 updates, 2.90 s, 107.12 train_loss, 86.65 val_loss
# 11200/20000 updates, 2.97 s, 65.06 train_loss, 99.92 val_loss
# 11300/20000 updates, 3.91 s, 88.88 train_loss, 50.79 val_loss
# 11400/20000 updates, 4.27 s, -74.79 train_loss, 156.72 val_loss
# 11500/20000 updates, 4.23 s, 198.91 train_loss, 99.43 val_loss
# 11600/20000 updates, 4.14 s, 149.08 train_loss, 98.27 val_loss
# 11700/20000 updates, 3.29 s, -59.41 train_loss, 74.28 val_loss
# 11800/20000 updates, 3.47 s, 210.43 train_loss, 76.55 val_loss
# 11900/20000 updates, 3.70 s, 24.41 train_loss, 91.14 val_loss
# 12000/20000 updates, 3.73 s, -81.91 train_loss, 67.30 val_loss
# 12100/20000 updates, 4.01 s, 92.51 train_loss, 113.66 val_loss
# 12200/20000 updates, 3.87 s, 119.35 train_loss, 83.29 val_loss
# 12300/20000 updates, 3.58 s, 61.15 train_loss, 73.92 val_loss
# 12400/20000 updates, 3.79 s, -35.72 train_loss, 63.60 val_loss
# 12500/20000 updates, 3.99 s, -10.99 train_loss, 60.38 val_loss
# 12600/20000 updates, 3.84 s, 106.89 train_loss, 133.20 val_loss
# 12700/20000 updates, 3.78 s, 375.60 train_loss, 83.97 val_loss
# 12800/20000 updates, 3.87 s, -9.37 train_loss, 64.65 val_loss
# 12900/20000 updates, 3.85 s, 33.91 train_loss, 82.77 val_loss
# 13000/20000 updates, 4.02 s, -11.74 train_loss, 104.44 val_loss
# 13100/20000 updates, 4.07 s, 84.11 train_loss, 81.58 val_loss
# 13200/20000 updates, 3.91 s, 41.38 train_loss, 66.77 val_loss
# 13300/20000 updates, 3.87 s, 223.07 train_loss, 119.95 val_loss
# 13400/20000 updates, 3.74 s, 97.58 train_loss, 86.59 val_loss
# 13500/20000 updates, 3.79 s, 178.80 train_loss, 169.87 val_loss
# 13600/20000 updates, 3.29 s, 154.40 train_loss, 85.59 val_loss
# 13700/20000 updates, 4.02 s, 245.86 train_loss, 193.50 val_loss
# 13800/20000 updates, 4.06 s, 61.82 train_loss, 58.49 val_loss
# 13900/20000 updates, 4.37 s, -18.80 train_loss, 69.60 val_loss
# 14000/20000 updates, 4.33 s, 21.57 train_loss, 71.05 val_loss
# 14100/20000 updates, 4.37 s, 44.28 train_loss, 95.32 val_loss
# 14200/20000 updates, 4.26 s, 87.63 train_loss, 105.79 val_loss
# 14300/20000 updates, 4.26 s, 174.04 train_loss, 86.62 val_loss
# 14400/20000 updates, 4.32 s, 845.61 train_loss, 62.89 val_loss
# 14500/20000 updates, 4.46 s, 357.89 train_loss, 74.72 val_loss
# 14600/20000 updates, 4.39 s, -10.10 train_loss, 149.87 val_loss
# Saving session...
# 14700/20000 updates, 4.41 s, 148.39 train_loss, 37.94 val_loss
# 14800/20000 updates, 3.96 s, 21.26 train_loss, 90.84 val_loss
# 14900/20000 updates, 4.25 s, 106.20 train_loss, 136.71 val_loss
# 15000/20000 updates, 4.02 s, 169.58 train_loss, 102.21 val_loss
# 15100/20000 updates, 4.10 s, 5.71 train_loss, 151.24 val_loss
# 15200/20000 updates, 4.27 s, 80.56 train_loss, 85.49 val_loss
# 15300/20000 updates, 4.26 s, 433.67 train_loss, 87.96 val_loss
# 15400/20000 updates, 4.16 s, -77.62 train_loss, 40.02 val_loss
# 15500/20000 updates, 4.44 s, 108.55 train_loss, 95.84 val_loss
# Saving session...
# 15600/20000 updates, 4.03 s, 25.23 train_loss, 34.84 val_loss
# 15700/20000 updates, 4.54 s, 67.78 train_loss, 110.71 val_loss
# 15800/20000 updates, 4.11 s, -32.90 train_loss, 77.18 val_loss
# 15900/20000 updates, 4.27 s, 80.82 train_loss, 54.07 val_loss
# Saving session...
# 16000/20000 updates, 4.20 s, -64.65 train_loss, 26.49 val_loss
# 16100/20000 updates, 4.47 s, 72.22 train_loss, 115.30 val_loss
# 16200/20000 updates, 4.17 s, 107.93 train_loss, 68.75 val_loss
# 16300/20000 updates, 4.25 s, -9.96 train_loss, 65.82 val_loss
# 16400/20000 updates, 4.15 s, 26.25 train_loss, 117.55 val_loss
# 16500/20000 updates, 4.59 s, 139.21 train_loss, 94.44 val_loss
# 16600/20000 updates, 4.03 s, 40.85 train_loss, 106.81 val_loss
# 16700/20000 updates, 4.22 s, 83.80 train_loss, 88.16 val_loss
# 16800/20000 updates, 4.26 s, 113.14 train_loss, 52.33 val_loss
# 16900/20000 updates, 4.44 s, 11.15 train_loss, 57.27 val_loss
# 17000/20000 updates, 4.35 s, -103.45 train_loss, 69.59 val_loss
# 17100/20000 updates, 4.29 s, 38.11 train_loss, 72.41 val_loss
# 17200/20000 updates, 4.43 s, 74.93 train_loss, 66.49 val_loss
# 17300/20000 updates, 4.53 s, -0.44 train_loss, 95.52 val_loss
# 17400/20000 updates, 4.24 s, -8.82 train_loss, 95.79 val_loss
# 17500/20000 updates, 4.33 s, 200.12 train_loss, 82.96 val_loss
# 17600/20000 updates, 4.00 s, 113.70 train_loss, 73.53 val_loss
# 17700/20000 updates, 4.24 s, 169.44 train_loss, 55.75 val_loss
# 17800/20000 updates, 4.38 s, -41.02 train_loss, 71.43 val_loss
# 17900/20000 updates, 4.59 s, -11.73 train_loss, 81.15 val_loss
# 18000/20000 updates, 4.20 s, 43.63 train_loss, 70.08 val_loss
# 18100/20000 updates, 4.51 s, -5.14 train_loss, 110.12 val_loss
# 18200/20000 updates, 4.32 s, 12.73 train_loss, 46.63 val_loss
# 18300/20000 updates, 4.35 s, 58.88 train_loss, 39.32 val_loss
# 18400/20000 updates, 4.28 s, -13.07 train_loss, 68.45 val_loss
# 18500/20000 updates, 4.20 s, -4.47 train_loss, 51.44 val_loss
# 18600/20000 updates, 4.22 s, -15.48 train_loss, 59.77 val_loss
# 18700/20000 updates, 4.49 s, 153.97 train_loss, 52.30 val_loss
# 18800/20000 updates, 4.29 s, 301.96 train_loss, 139.55 val_loss
# 18900/20000 updates, 4.34 s, 310.47 train_loss, 117.57 val_loss
# 19000/20000 updates, 4.32 s, 6.53 train_loss, 76.78 val_loss
# 19100/20000 updates, 4.36 s, -25.00 train_loss, 56.59 val_loss
# 19200/20000 updates, 3.95 s, -52.65 train_loss, 62.96 val_loss
# 19300/20000 updates, 4.37 s, 46.66 train_loss, 63.96 val_loss
# 19400/20000 updates, 4.37 s, 50.00 train_loss, 122.09 val_loss
# 19500/20000 updates, 4.34 s, -2.76 train_loss, 36.37 val_loss
# 19600/20000 updates, 4.00 s, -3.79 train_loss, 64.76 val_loss
# 19700/20000 updates, 4.44 s, 212.19 train_loss, 106.05 val_loss
# 19800/20000 updates, 4.33 s, 82.75 train_loss, 117.57 val_loss
# 19900/20000 updates, 4.22 s, -23.79 train_loss, 76.93 val_loss
# 0 / 1000
# 100 / 1000
# 200 / 1000
# 300 / 1000
# 400 / 1000
# 500 / 1000
# 600 / 1000
# 700 / 1000
# 800 / 1000
# 900 / 1000

# %%
print("RMSE: {:.3f}".format(RMSE_notmiwae))
# Out:
# RMSE: 2.017

# %%
x_notmiwae = np.load('x_notmiwae.npy')

# %%
x_obs = x_data[mask]
x_miss = x_data[~mask]

x_est = x_notmiwae

x_est_obs = x_est[mask]
x_est_miss = x_est[~mask]

# %%
scatter_compare_individual_entries_panel(x_obs, x_miss, x_est_obs, x_est_miss)

# %%
hist_compare_individual_entries(x_obs, x_miss, x_est_obs, x_est_miss)

# %%
W, b = notmiwae.sess.run([notmiwae.W, notmiwae.b])

# %%
fig, ax = plt.subplots(ncols=1, figsize=(6, 5))

p_obs = detection_prob[mask]
x_obs = x_data[mask]

p_miss = detection_prob[~mask]
x_miss = x_data[~mask]

n = 5_000

ax.scatter(x_miss[:n], p_miss[:n], color="red", alpha=.1, s=2)
ax.scatter(x_obs[:n], p_obs[:n], color="blue", alpha=.1, s=2)
ax.set_title("entry intensity vs detection probability")
ax.set_xlabel("entry intensity")
ax.set_ylabel("detection probability")
ax.grid(True)
ax.set_axisbelow(True)

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

for n in range(W.shape[-1]):
    xs = np.linspace(0, 18, 100)
    logit = -W[0, 0, n] * (xs - b[0, 0, n])
    ys = sigmoid(logit)
    ax.plot(xs, ys, color="black", alpha=.3, linewidth=4)
