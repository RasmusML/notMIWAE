# %% [markdown]
# # Single-cell Proteomics Synthetic Data Generation

# %% [markdown]
# The goal of this notebook is to simulate a crude single-cell proteomics datasets with a MNAR mechanism, and show that not-MIWAE performs better than MIWAE.

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

from MIWAE import MIWAE
from notMIWAE import notMIWAE
import trainer
import utils

np.random.seed(42)
# Out:
# 2023-11-09 19:53:04.312791: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-11-09 19:53:04.314537: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-09 19:53:04.337170: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-09 19:53:04.337209: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-09 19:53:04.337233: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-09 19:53:04.342135: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-09 19:53:04.342569: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-09 19:53:04.975564: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# Plotting functions for later.

# %%
def scatter_compare_individual_entries_panel(x_obs, x_miss, x_est_obs, x_est_miss):
    fig, axes = plt.subplots(ncols=2, figsize=(12, 5))
    
    ax = axes[0]
    ax.scatter(x_obs, x_est_obs, s=1, alpha=0.1)
    lims = [np.min([ax.get_xlim(), ax.get_ylim()]), np.max([ax.get_xlim(), ax.get_ylim()])]
    ax.plot(lims, lims, "--", c="k")

    mse = np.mean((x_obs - x_est_obs)**2)
    ax.text(0.05, 0.95, f"MSE: {mse:.2f}", transform=ax.transAxes, fontsize=12, verticalalignment="top", bbox=dict(facecolor="white", alpha=0.8))

    ax.set_xlabel("Observed")
    ax.set_ylabel("Imputed")
    ax.set_title("Observed")
    ax.grid(True)
    ax.set_axisbelow(True)

    ax = axes[1]
    ax.scatter(x_miss, x_est_miss, s=1, alpha=0.1)
    lims = [np.min([ax.get_xlim(), ax.get_ylim()]), np.max([ax.get_xlim(), ax.get_ylim()])]
    ax.plot(lims, lims, "--", c="k")

    mse = np.mean((x_miss - x_est_miss)**2)
    ax.text(0.05, 0.95, f"MSE: {mse:.2f}", transform=ax.transAxes, fontsize=12, verticalalignment="top", bbox=dict(facecolor="white", alpha=0.8))

    ax.set_xlabel("Observed")
    ax.set_ylabel("Imputed")
    ax.set_title("Missing")
    ax.grid(True)

# %%
def hist_compare_individual_entries(x_obs, x_miss, x_est_obs, x_est_miss):
    fig, axes = plt.subplots(ncols=2, figsize=(12, 5))

    x_min = np.min([np.min(x_obs), np.min(x_miss), np.min(x_est_obs), np.min(x_est_miss)])
    x_max = np.max([np.max(x_obs), np.max(x_miss), np.max(x_est_obs), np.max(x_est_miss)])

    ax = axes[0]
    ax.hist([x_obs, x_miss], color=["blue", "red"], bins=50, edgecolor="black", linewidth=1.2, stacked=True)
    ax.set_title("Data")
    ax.set_xlabel("x")
    ax.set_ylabel("(stacked) count")
    ax.set_xlim(x_min, x_max)
    ax.grid(True)
    ax.set_axisbelow(True)
    ax.legend(labels=["$x_{obs}$", "$x_{miss}$"], fontsize=12)

    ax = axes[1]
    ax.hist([x_est_obs, x_est_miss], color=["blue", "red"], bins=50, edgecolor="black", linewidth=1.2, stacked=True)
    ax.set_title("Model")
    ax.set_xlabel("x")
    ax.set_ylabel("(stacked) count")
    ax.set_xlim(x_min, x_max)
    ax.grid(True)
    ax.set_axisbelow(True)
    ax.legend(labels=["$x_{obs}$", "$x_{miss}$"], fontsize=12)

# %% [markdown]
# ## Data generation

# %% [markdown]
# Let's start by generating the synthetic data and visualizing it.

# %%
def logistic(x, k=1, x0=0, L=1):
    return L / (1 + np.exp(-k * (x - x0)))


def simulate_data(n_cells=1000, n_proteins=900):
    # all cells are from the same group (cell-type)
    # the cell type has some protein distribution / signature
    cell_type_signature = np.random.uniform(5, 12, n_proteins)

    # each cell is a bit different
    cell_variation = np.random.normal(0, 1, n_cells)

    intensity = cell_type_signature.reshape(1, -1) + cell_variation.reshape(-1, 1)

    # the measurement is noisy
    x = np.random.normal(intensity, 0.1)

    # MNAR mechanism: self-masking (x -> m)
    # entries with low intensity are less likely to be sampled
    detection_prob = logistic(x, k=2, x0=7) # set x0=6, if you want less missing values

    # sample using a bernoulli distribution
    mask = np.random.binomial(1, detection_prob)
    mask = mask.astype(bool)

    return x, detection_prob, mask

# %% [markdown]
# Let's simulate some data:

# %%
x_data, detection_prob, mask = simulate_data()


x_nan = x_data.copy()
x_nan[~mask] = np.nan

x_0 = x_data.copy()
x_0[~mask] = 0

# %%
print("Missing entries: {:.2f}%".format(np.isnan(x_nan).sum() / x_nan.size * 100))
# Out:
# Missing entries: 29.27%

# %% [markdown]
# Let's plot the data. "White" are the missing values.

# %%
fig, ax = plt.subplots(figsize=(8, 5))
sns.heatmap(x_nan, cmap="viridis", xticklabels=False, yticklabels=False, ax=ax)
ax.set_xlabel("Proteins")
ax.set_ylabel("Cells")
ax.set_title("Expression matrix with missing values")
# Out:
# Text(0.5, 1.0, 'Expression matrix with missing values')

# %% [markdown]
# Let's look at the missigness pattern entry-wise and protein-wise:

# %%
fig, axes = plt.subplots(ncols=2, figsize=(12, 5))

# plot entry intensity vs detection probability
ax = axes[0]

p_obs = detection_prob[mask]
x_obs = x_data[mask]

p_miss = detection_prob[~mask]
x_miss = x_data[~mask]

n = 5_000

ax.scatter(x_miss[:n], p_miss[:n], color="red", alpha=.1, s=4)
ax.scatter(x_obs[:n], p_obs[:n], color="blue", alpha=.1, s=4)
ax.set_title("entry intensity vs detection probability")
ax.set_xlabel("entry intensity")
ax.set_ylabel("detection probability")
ax.grid(True)
ax.set_axisbelow(True)

# plot the average protein intensity vs the detection proportion
ax = axes[1]
x_obs_protein = np.nanmean(x_nan, axis=0)
p_protein = 1 - np.nanmean(np.isnan(x_nan), axis=0)

ax.scatter(x_obs_protein, p_protein, color="blue", alpha=1, s=6)
ax.set_title("avg protein intensity vs detection proportion")
ax.set_xlabel("protein intensity")
ax.set_ylabel("detection proportion")
ax.grid(True)
ax.set_axisbelow(True)

# %%
fig, ax = plt.subplots(1, 1, figsize=(5, 5))

ax.hist([x_obs, x_miss], color=["blue", "red"], bins=50, edgecolor="black", linewidth=1.2, stacked=True)
ax.set_title("Data")
ax.set_xlabel("x")
ax.set_ylabel("(stacked) count")
ax.set_xlim(np.min(x_data), np.max(x_data))
ax.grid(True)
ax.set_axisbelow(True)
ax.legend(labels=["$x_{obs}$", "$x_{miss}$"], fontsize=12)

# %% [markdown]
# ## Model Comparison

# %% [markdown]
# Set the parameters for the models.

# %%
name = '/tmp/best'

# model specification
n_hidden = 128
n_samples = 20
n_latent = 16
mprocess = 'selfmasking' #'selfmasking_known'
out_dist='gauss'

# training
max_iter = 20_000
batch_size = 32

# imputation
L = 10000

# %% [markdown]
# Let's run.

# %%
standardize = False # similiar to scVI, we don't normalize further.

if standardize:
    x_data = x_data - np.mean(x_data, axis=0)
    x_data = x_data / np.std(x_data, axis=0)

# %%
x_data, detection_prob, mask = simulate_data()

x_nan = x_data.copy()
x_nan[~mask] = np.nan

x_0 = x_data.copy()
x_0[~mask] = 0

# %%
N, D = x_data.shape

Xtrain = x_data.copy()
Xval_org = x_data.copy()

Xnan = x_nan.copy()
Xz = x_0.copy()
S = mask.copy()

Xval = x_nan.copy()
Xvalz = x_0.copy()

# %%
tf.compat.v1.disable_eager_execution()

# %% [markdown]
# ### MIWAE

# %%
miwae = MIWAE(Xnan, Xval, n_latent=n_latent, n_samples=n_samples, n_hidden=n_hidden, name=name, out_dist=out_dist)

# ---- do the training
trainer.train(miwae, batch_size=batch_size, max_iter=max_iter, name=name + 'miwae')

# ---- find imputation RMSE
RMSE_miwae, x_miwae = utils.imputationRMSE(miwae, Xtrain, Xz, Xnan, S, L)

np.save('x_miwae.npy', x_miwae)
# Out:
# Creating graph...
# 2023-11-09 19:53:08.115115: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:382] MLIR V1 optimization pass is not enabled
# Saving session...
# Saving session...
# 0/20000 updates, 0.29 s, 64859.20 train_loss, 62189.11 val_loss
# Saving session...
# 100/20000 updates, 2.67 s, 1987.36 train_loss, 1983.19 val_loss
# Saving session...
# 200/20000 updates, 3.13 s, 1503.35 train_loss, 1555.17 val_loss
# Saving session...
# 300/20000 updates, 2.34 s, 1300.96 train_loss, 1301.17 val_loss
# Saving session...
# 400/20000 updates, 2.35 s, 1101.22 train_loss, 1026.54 val_loss
# Saving session...
# 500/20000 updates, 2.82 s, 937.87 train_loss, 647.98 val_loss
# Saving session...
# 600/20000 updates, 2.64 s, 472.92 train_loss, 554.85 val_loss
# Saving session...
# 700/20000 updates, 2.58 s, 126.10 train_loss, 108.56 val_loss
# Saving session...
# 800/20000 updates, 2.88 s, 53.61 train_loss, 65.38 val_loss
# Saving session...
# 900/20000 updates, 3.00 s, 199.27 train_loss, 45.45 val_loss
# Saving session...
# 1000/20000 updates, 2.98 s, -188.19 train_loss, -61.51 val_loss
# Saving session...
# 1100/20000 updates, 2.83 s, -213.14 train_loss, -95.02 val_loss
# Saving session...
# 1200/20000 updates, 2.60 s, -31.30 train_loss, -105.82 val_loss
# 1300/20000 updates, 2.51 s, -74.72 train_loss, -29.16 val_loss
# 1400/20000 updates, 2.75 s, -2.50 train_loss, 0.32 val_loss
# 1500/20000 updates, 2.73 s, -109.43 train_loss, -75.95 val_loss
# 1600/20000 updates, 2.67 s, 5.39 train_loss, 7.24 val_loss
# 1700/20000 updates, 2.99 s, 146.06 train_loss, -16.48 val_loss
# 1800/20000 updates, 2.79 s, -119.42 train_loss, -97.24 val_loss
# 1900/20000 updates, 2.96 s, -152.25 train_loss, -101.54 val_loss
# 2000/20000 updates, 2.94 s, -120.23 train_loss, -98.07 val_loss
# Saving session...
# 2100/20000 updates, 2.48 s, -117.85 train_loss, -112.96 val_loss
# 2200/20000 updates, 3.04 s, -224.40 train_loss, -77.57 val_loss
# 2300/20000 updates, 2.81 s, -225.07 train_loss, -86.11 val_loss
# 2400/20000 updates, 2.76 s, -80.23 train_loss, -88.19 val_loss
# 2500/20000 updates, 2.98 s, -139.98 train_loss, -34.29 val_loss
# 2600/20000 updates, 3.04 s, -89.39 train_loss, -80.79 val_loss
# Saving session...
# 2700/20000 updates, 2.86 s, -236.34 train_loss, -121.08 val_loss
# 2800/20000 updates, 2.75 s, -167.02 train_loss, -111.87 val_loss
# 2900/20000 updates, 2.39 s, -55.96 train_loss, -109.89 val_loss
# 3000/20000 updates, 2.65 s, -138.61 train_loss, -63.31 val_loss
# 3100/20000 updates, 2.62 s, 75.65 train_loss, -111.14 val_loss
# 3200/20000 updates, 2.72 s, -113.74 train_loss, -61.14 val_loss
# 3300/20000 updates, 2.68 s, 45.09 train_loss, -42.57 val_loss
# 3400/20000 updates, 2.71 s, -113.91 train_loss, -111.48 val_loss
# 3500/20000 updates, 2.46 s, 13.70 train_loss, -37.74 val_loss
# 3600/20000 updates, 2.28 s, -178.86 train_loss, -111.19 val_loss
# Saving session...
# 3700/20000 updates, 2.35 s, -104.46 train_loss, -130.23 val_loss
# 3800/20000 updates, 1.93 s, -233.86 train_loss, -113.97 val_loss
# Saving session...
# 3900/20000 updates, 2.64 s, -150.17 train_loss, -130.38 val_loss
# 4000/20000 updates, 2.54 s, -25.57 train_loss, -78.90 val_loss
# 4100/20000 updates, 2.48 s, 54.28 train_loss, 15.34 val_loss
# 4200/20000 updates, 2.53 s, -215.28 train_loss, -104.70 val_loss
# 4300/20000 updates, 2.65 s, 22.59 train_loss, -78.80 val_loss
# 4400/20000 updates, 2.67 s, -125.08 train_loss, -83.13 val_loss
# 4500/20000 updates, 2.51 s, -288.18 train_loss, -108.00 val_loss
# 4600/20000 updates, 2.61 s, -47.31 train_loss, -127.99 val_loss
# 4700/20000 updates, 2.69 s, -115.24 train_loss, -108.58 val_loss
# 4800/20000 updates, 2.72 s, -24.86 train_loss, -106.19 val_loss
# 4900/20000 updates, 2.70 s, -203.13 train_loss, -105.74 val_loss
# 5000/20000 updates, 2.69 s, -173.41 train_loss, -33.94 val_loss
# 5100/20000 updates, 2.74 s, -93.61 train_loss, -98.06 val_loss
# 5200/20000 updates, 2.86 s, -35.54 train_loss, -74.76 val_loss
# 5300/20000 updates, 2.88 s, -139.38 train_loss, -0.44 val_loss
# 5400/20000 updates, 2.52 s, 39.08 train_loss, 13.88 val_loss
# 5500/20000 updates, 2.72 s, -22.33 train_loss, -31.73 val_loss
# 5600/20000 updates, 2.62 s, 4.05 train_loss, -112.46 val_loss
# 5700/20000 updates, 2.14 s, -128.73 train_loss, -121.37 val_loss
# Saving session...
# 5800/20000 updates, 2.52 s, -125.43 train_loss, -133.58 val_loss
# 5900/20000 updates, 2.90 s, -180.61 train_loss, -69.76 val_loss
# Saving session...
# 6000/20000 updates, 2.71 s, -196.39 train_loss, -142.28 val_loss
# 6100/20000 updates, 2.87 s, -128.10 train_loss, -97.20 val_loss
# 6200/20000 updates, 2.64 s, 26.93 train_loss, 21.72 val_loss
# 6300/20000 updates, 2.17 s, 15.25 train_loss, 44.23 val_loss
# 6400/20000 updates, 2.37 s, 46.44 train_loss, -24.50 val_loss
# 6500/20000 updates, 2.50 s, -66.73 train_loss, -29.77 val_loss
# 6600/20000 updates, 2.25 s, -106.14 train_loss, -23.58 val_loss
# 6700/20000 updates, 2.48 s, -72.89 train_loss, -88.99 val_loss
# 6800/20000 updates, 2.10 s, -45.68 train_loss, -121.68 val_loss
# 6900/20000 updates, 2.86 s, -222.61 train_loss, 24.06 val_loss
# 7000/20000 updates, 2.66 s, -223.56 train_loss, -99.37 val_loss
# 7100/20000 updates, 2.94 s, -223.67 train_loss, -111.09 val_loss
# 7200/20000 updates, 2.25 s, -150.70 train_loss, -140.68 val_loss
# 7300/20000 updates, 3.07 s, -12.54 train_loss, -53.65 val_loss
# 7400/20000 updates, 2.82 s, 117.61 train_loss, -107.04 val_loss
# 7500/20000 updates, 3.06 s, 34.77 train_loss, -50.87 val_loss
# 7600/20000 updates, 3.02 s, 7.14 train_loss, -3.73 val_loss
# 7700/20000 updates, 2.94 s, -161.27 train_loss, -107.44 val_loss
# 7800/20000 updates, 2.82 s, 114.48 train_loss, -28.83 val_loss
# 7900/20000 updates, 2.09 s, -95.65 train_loss, -84.01 val_loss
# 8000/20000 updates, 2.67 s, -210.26 train_loss, -111.58 val_loss
# 8100/20000 updates, 2.30 s, -144.71 train_loss, -96.68 val_loss
# 8200/20000 updates, 1.77 s, -270.80 train_loss, 50.95 val_loss
# 8300/20000 updates, 2.05 s, -194.63 train_loss, -65.49 val_loss
# 8400/20000 updates, 2.45 s, 139.29 train_loss, -133.87 val_loss
# 8500/20000 updates, 1.49 s, 107.36 train_loss, 50.27 val_loss
# 8600/20000 updates, 1.79 s, -198.92 train_loss, -97.90 val_loss
# 8700/20000 updates, 1.82 s, -237.74 train_loss, -102.42 val_loss
# 8800/20000 updates, 1.65 s, -5.09 train_loss, 35.35 val_loss
# 8900/20000 updates, 2.01 s, 137.73 train_loss, -74.14 val_loss
# 9000/20000 updates, 2.36 s, -81.48 train_loss, -101.75 val_loss
# 9100/20000 updates, 2.19 s, -95.41 train_loss, -72.23 val_loss
# 9200/20000 updates, 2.64 s, -265.42 train_loss, -107.83 val_loss
# 9300/20000 updates, 2.10 s, -171.99 train_loss, -119.37 val_loss
# 9400/20000 updates, 2.23 s, -144.38 train_loss, -78.76 val_loss
# 9500/20000 updates, 2.37 s, 3.37 train_loss, -96.55 val_loss
# 9600/20000 updates, 2.59 s, -159.93 train_loss, -129.41 val_loss
# 9700/20000 updates, 2.90 s, -66.91 train_loss, -125.78 val_loss
# 9800/20000 updates, 2.99 s, -158.31 train_loss, -108.25 val_loss
# 9900/20000 updates, 2.89 s, -86.79 train_loss, -55.44 val_loss
# Saving session...
# 10000/20000 updates, 2.69 s, -22.58 train_loss, -149.33 val_loss
# 10100/20000 updates, 3.00 s, -141.65 train_loss, -111.30 val_loss
# 10200/20000 updates, 2.97 s, -284.26 train_loss, -90.78 val_loss
# 10300/20000 updates, 2.52 s, 15.36 train_loss, -65.47 val_loss
# 10400/20000 updates, 2.26 s, -18.94 train_loss, -119.59 val_loss
# 10500/20000 updates, 2.39 s, -14.94 train_loss, 29.15 val_loss
# 10600/20000 updates, 2.48 s, -97.05 train_loss, -139.39 val_loss
# 10700/20000 updates, 1.66 s, -96.53 train_loss, -110.86 val_loss
# 10800/20000 updates, 2.74 s, -131.22 train_loss, -94.40 val_loss
# 10900/20000 updates, 2.58 s, -155.35 train_loss, -96.31 val_loss
# 11000/20000 updates, 2.71 s, 25.52 train_loss, -142.98 val_loss
# 11100/20000 updates, 2.63 s, -39.40 train_loss, -64.17 val_loss
# 11200/20000 updates, 2.30 s, -218.64 train_loss, -113.02 val_loss
# 11300/20000 updates, 2.75 s, -39.53 train_loss, -86.51 val_loss
# 11400/20000 updates, 2.74 s, -45.10 train_loss, -43.12 val_loss
# 11500/20000 updates, 2.76 s, -102.58 train_loss, -97.93 val_loss
# 11600/20000 updates, 2.72 s, -231.62 train_loss, -76.91 val_loss
# 11700/20000 updates, 2.76 s, -131.80 train_loss, -147.16 val_loss
# 11800/20000 updates, 2.18 s, 115.65 train_loss, -104.99 val_loss
# 11900/20000 updates, 2.58 s, -169.11 train_loss, -90.37 val_loss
# 12000/20000 updates, 2.90 s, -97.81 train_loss, -118.48 val_loss
# 12100/20000 updates, 2.47 s, -198.66 train_loss, -124.35 val_loss
# 12200/20000 updates, 2.96 s, -13.17 train_loss, -19.12 val_loss
# 12300/20000 updates, 3.09 s, -218.05 train_loss, -84.41 val_loss
# 12400/20000 updates, 3.03 s, -32.44 train_loss, -108.52 val_loss
# 12500/20000 updates, 3.13 s, -159.13 train_loss, -77.33 val_loss
# 12600/20000 updates, 2.38 s, -89.20 train_loss, -95.41 val_loss
# 12700/20000 updates, 2.36 s, -175.79 train_loss, -18.51 val_loss
# 12800/20000 updates, 2.97 s, -13.57 train_loss, -67.80 val_loss
# 12900/20000 updates, 2.25 s, 116.45 train_loss, -81.88 val_loss
# 13000/20000 updates, 2.77 s, -150.43 train_loss, -48.57 val_loss
# 13100/20000 updates, 2.48 s, 179.28 train_loss, -60.61 val_loss
# 13200/20000 updates, 2.27 s, -127.74 train_loss, -115.36 val_loss
# 13300/20000 updates, 1.91 s, -81.48 train_loss, -14.93 val_loss
# 13400/20000 updates, 2.56 s, -156.96 train_loss, -82.38 val_loss
# 13500/20000 updates, 2.85 s, -92.44 train_loss, -95.60 val_loss
# 13600/20000 updates, 2.52 s, -170.03 train_loss, -120.71 val_loss
# 13700/20000 updates, 2.14 s, -158.65 train_loss, -103.78 val_loss
# 13800/20000 updates, 2.69 s, -40.37 train_loss, -59.26 val_loss
# 13900/20000 updates, 2.22 s, -150.18 train_loss, -116.75 val_loss
# 14000/20000 updates, 2.46 s, -195.67 train_loss, -120.21 val_loss
# 14100/20000 updates, 2.67 s, -169.56 train_loss, -131.71 val_loss
# 14200/20000 updates, 2.33 s, 107.07 train_loss, -112.79 val_loss
# 14300/20000 updates, 1.99 s, -11.47 train_loss, -45.38 val_loss
# 14400/20000 updates, 2.24 s, -41.84 train_loss, -100.91 val_loss
# 14500/20000 updates, 2.73 s, -1.26 train_loss, -119.19 val_loss
# 14600/20000 updates, 2.84 s, -105.06 train_loss, -103.14 val_loss
# 14700/20000 updates, 2.21 s, -198.47 train_loss, -94.79 val_loss
# 14800/20000 updates, 1.81 s, -211.86 train_loss, -124.13 val_loss
# 14900/20000 updates, 1.53 s, 286.51 train_loss, 280.98 val_loss
# 15000/20000 updates, 1.41 s, -206.77 train_loss, -41.31 val_loss
# 15100/20000 updates, 1.16 s, -119.20 train_loss, -3.57 val_loss
# 15200/20000 updates, 1.76 s, 52.34 train_loss, -29.99 val_loss
# 15300/20000 updates, 2.11 s, 1013.34 train_loss, -14.83 val_loss
# 15400/20000 updates, 2.36 s, -4.55 train_loss, -73.39 val_loss
# 15500/20000 updates, 3.11 s, -179.30 train_loss, -76.94 val_loss
# 15600/20000 updates, 2.86 s, -30.01 train_loss, -71.07 val_loss
# 15700/20000 updates, 3.03 s, -87.95 train_loss, -118.53 val_loss
# 15800/20000 updates, 2.08 s, 10.19 train_loss, -58.74 val_loss
# 15900/20000 updates, 2.83 s, -43.97 train_loss, -87.82 val_loss
# 16000/20000 updates, 2.91 s, -107.06 train_loss, -37.76 val_loss
# 16100/20000 updates, 2.62 s, -244.22 train_loss, -93.76 val_loss
# 16200/20000 updates, 2.08 s, -102.27 train_loss, -102.77 val_loss
# 16300/20000 updates, 2.27 s, -108.99 train_loss, -111.97 val_loss
# 16400/20000 updates, 2.98 s, -78.60 train_loss, -88.15 val_loss
# 16500/20000 updates, 2.63 s, 64.97 train_loss, -76.97 val_loss
# 16600/20000 updates, 2.50 s, -154.78 train_loss, -96.95 val_loss
# 16700/20000 updates, 2.81 s, -104.04 train_loss, -120.14 val_loss
# 16800/20000 updates, 2.95 s, -71.77 train_loss, -116.73 val_loss
# 16900/20000 updates, 2.86 s, -203.28 train_loss, -39.81 val_loss
# 17000/20000 updates, 2.96 s, -129.43 train_loss, -133.39 val_loss
# 17100/20000 updates, 2.93 s, -64.96 train_loss, -109.77 val_loss
# 17200/20000 updates, 3.01 s, -17.02 train_loss, -59.20 val_loss
# 17300/20000 updates, 2.93 s, -174.54 train_loss, -97.45 val_loss
# 17400/20000 updates, 2.91 s, 18.59 train_loss, -101.79 val_loss
# 17500/20000 updates, 2.87 s, 386.30 train_loss, -87.61 val_loss
# 17600/20000 updates, 2.89 s, -175.33 train_loss, -89.14 val_loss
# 17700/20000 updates, 2.97 s, -173.93 train_loss, -82.20 val_loss
# 17800/20000 updates, 2.84 s, -65.44 train_loss, -89.62 val_loss
# 17900/20000 updates, 2.96 s, 52.72 train_loss, -111.15 val_loss
# 18000/20000 updates, 2.93 s, -23.94 train_loss, -37.79 val_loss
# 18100/20000 updates, 2.97 s, -95.54 train_loss, -70.72 val_loss
# 18200/20000 updates, 2.94 s, -53.53 train_loss, -83.66 val_loss
# 18300/20000 updates, 2.82 s, -198.26 train_loss, -117.13 val_loss
# 18400/20000 updates, 2.81 s, -314.97 train_loss, -73.47 val_loss
# 18500/20000 updates, 2.76 s, -78.72 train_loss, -65.10 val_loss
# 18600/20000 updates, 2.98 s, -162.56 train_loss, -120.41 val_loss
# 18700/20000 updates, 2.93 s, -79.26 train_loss, -61.69 val_loss
# 18800/20000 updates, 2.97 s, -17.53 train_loss, -126.30 val_loss
# 18900/20000 updates, 2.97 s, -192.78 train_loss, -89.30 val_loss
# 19000/20000 updates, 2.92 s, -241.51 train_loss, -148.39 val_loss
# 19100/20000 updates, 2.95 s, -135.52 train_loss, -105.57 val_loss
# 19200/20000 updates, 2.98 s, -144.30 train_loss, -109.27 val_loss
# 19300/20000 updates, 2.92 s, -116.83 train_loss, -107.03 val_loss
# 19400/20000 updates, 2.97 s, -158.41 train_loss, -55.43 val_loss
# 19500/20000 updates, 2.96 s, -128.24 train_loss, -107.25 val_loss
# 19600/20000 updates, 2.91 s, 140.02 train_loss, -48.28 val_loss
# 19700/20000 updates, 2.82 s, -74.53 train_loss, -122.62 val_loss
# 19800/20000 updates, 2.99 s, -80.05 train_loss, -122.12 val_loss
# 19900/20000 updates, 2.88 s, -146.71 train_loss, -64.34 val_loss
# 0 / 1000
# 100 / 1000
# 200 / 1000
# 300 / 1000
# 400 / 1000
# 500 / 1000
# 600 / 1000
# 700 / 1000
# 800 / 1000
# 900 / 1000

# %%
print("RMSE: {:.3f}".format(RMSE_miwae))
# Out:
# RMSE: 0.199

# %%
x_miwae = np.load('x_miwae.npy')

# %%
x_obs = x_data[mask]
x_miss = x_data[~mask]

x_est = x_miwae

x_est_obs = x_est[mask]
x_est_miss = x_est[~mask]

# %%
scatter_compare_individual_entries_panel(x_obs, x_miss, x_est_obs, x_est_miss)

# %%
hist_compare_individual_entries(x_obs, x_miss, x_est_obs, x_est_miss)

# %% [markdown]
# ### not-MIWAE

# %%
notmiwae = notMIWAE(Xnan, Xval, n_latent=n_latent, n_samples=n_samples, n_hidden=n_hidden, missing_process=mprocess, name=name, out_dist=out_dist)

# ---- do the training
trainer.train(notmiwae, batch_size=batch_size, max_iter=max_iter, name=name + 'notmiwae')

# ---- find imputation RMSE
RMSE_notmiwae, x_notmiwae = utils.not_imputationRMSE(notmiwae, Xtrain, Xz, Xnan, S, L)

np.save('x_notmiwae.npy', x_notmiwae)
# Out:
# Creating graph...
# Saving session...
# Saving session...
# 0/20000 updates, 0.22 s, 65840.81 train_loss, 62120.74 val_loss
# Saving session...
# 100/20000 updates, 2.48 s, 2692.66 train_loss, 2637.80 val_loss
# Saving session...
# 200/20000 updates, 3.28 s, 2222.11 train_loss, 2234.97 val_loss
# Saving session...
# 300/20000 updates, 3.34 s, 1948.14 train_loss, 2000.96 val_loss
# Saving session...
# 400/20000 updates, 3.97 s, 1722.67 train_loss, 1771.51 val_loss
# Saving session...
# 500/20000 updates, 3.93 s, 1362.89 train_loss, 1423.30 val_loss
# Saving session...
# 600/20000 updates, 3.24 s, 996.22 train_loss, 997.75 val_loss
# Saving session...
# 700/20000 updates, 3.20 s, 947.50 train_loss, 771.75 val_loss
# Saving session...
# 800/20000 updates, 3.85 s, 773.89 train_loss, 697.91 val_loss
# Saving session...
# 900/20000 updates, 3.91 s, 465.75 train_loss, 644.26 val_loss
# Saving session...
# 1000/20000 updates, 3.89 s, 515.24 train_loss, 519.93 val_loss
# Saving session...
# 1100/20000 updates, 3.73 s, 399.42 train_loss, 453.29 val_loss
# Saving session...
# 1200/20000 updates, 3.34 s, 408.93 train_loss, 452.47 val_loss
# 1300/20000 updates, 3.37 s, 422.06 train_loss, 502.26 val_loss
# Saving session...
# 1400/20000 updates, 2.76 s, 434.94 train_loss, 379.22 val_loss
# 1500/20000 updates, 2.32 s, 338.87 train_loss, 455.25 val_loss
# 1600/20000 updates, 2.27 s, 437.10 train_loss, 427.35 val_loss
# Saving session...
# 1700/20000 updates, 2.64 s, 330.50 train_loss, 367.55 val_loss
# Saving session...
# 1800/20000 updates, 2.66 s, 275.57 train_loss, 339.38 val_loss
# 1900/20000 updates, 2.60 s, 260.26 train_loss, 366.46 val_loss
# 2000/20000 updates, 2.34 s, 315.81 train_loss, 346.87 val_loss
# 2100/20000 updates, 2.53 s, 946.01 train_loss, 477.74 val_loss
# 2200/20000 updates, 2.60 s, 311.53 train_loss, 346.71 val_loss
# 2300/20000 updates, 2.65 s, 383.20 train_loss, 364.93 val_loss
# Saving session...
# 2400/20000 updates, 2.57 s, 287.21 train_loss, 305.33 val_loss
# 2500/20000 updates, 2.75 s, 341.08 train_loss, 404.11 val_loss
# 2600/20000 updates, 2.50 s, 609.92 train_loss, 415.57 val_loss
# 2700/20000 updates, 2.40 s, 437.76 train_loss, 334.83 val_loss
# 2800/20000 updates, 2.44 s, 348.05 train_loss, 331.03 val_loss
# 2900/20000 updates, 2.59 s, 416.93 train_loss, 317.86 val_loss
# 3000/20000 updates, 2.66 s, 341.59 train_loss, 310.06 val_loss
# 3100/20000 updates, 2.36 s, 474.62 train_loss, 308.12 val_loss
# Saving session...
# 3200/20000 updates, 2.59 s, 286.73 train_loss, 290.73 val_loss
# 3300/20000 updates, 2.67 s, 204.04 train_loss, 304.67 val_loss
# Saving session...
# 3400/20000 updates, 2.46 s, 240.84 train_loss, 251.55 val_loss
# 3500/20000 updates, 2.73 s, 215.12 train_loss, 333.68 val_loss
# 3600/20000 updates, 2.52 s, 317.88 train_loss, 368.73 val_loss
# 3700/20000 updates, 2.60 s, 268.47 train_loss, 278.04 val_loss
# Saving session...
# 3800/20000 updates, 2.73 s, 318.49 train_loss, 246.60 val_loss
# 3900/20000 updates, 2.64 s, 335.75 train_loss, 331.62 val_loss
# 4000/20000 updates, 2.65 s, 207.96 train_loss, 260.04 val_loss
# 4100/20000 updates, 2.85 s, 272.74 train_loss, 281.88 val_loss
# 4200/20000 updates, 2.61 s, 169.56 train_loss, 273.80 val_loss
# 4300/20000 updates, 2.53 s, 171.89 train_loss, 247.40 val_loss
# 4400/20000 updates, 2.63 s, 268.04 train_loss, 267.79 val_loss
# 4500/20000 updates, 2.67 s, 405.61 train_loss, 268.61 val_loss
# 4600/20000 updates, 2.58 s, 213.72 train_loss, 266.82 val_loss
# Saving session...
# 4700/20000 updates, 2.72 s, 196.60 train_loss, 227.37 val_loss
# Saving session...
# 4800/20000 updates, 2.83 s, 226.39 train_loss, 207.97 val_loss
# 4900/20000 updates, 2.85 s, 243.66 train_loss, 236.87 val_loss
# Saving session...
# 5000/20000 updates, 2.59 s, 205.87 train_loss, 206.77 val_loss
# 5100/20000 updates, 2.83 s, 247.32 train_loss, 245.16 val_loss
# 5200/20000 updates, 2.79 s, 494.43 train_loss, 210.53 val_loss
# 5300/20000 updates, 2.89 s, 214.55 train_loss, 257.41 val_loss
# 5400/20000 updates, 2.89 s, 189.16 train_loss, 227.08 val_loss
# 5500/20000 updates, 2.81 s, 183.42 train_loss, 221.86 val_loss
# 5600/20000 updates, 3.01 s, 155.70 train_loss, 256.10 val_loss
# 5700/20000 updates, 3.04 s, 484.28 train_loss, 240.56 val_loss
# 5800/20000 updates, 3.18 s, 244.67 train_loss, 208.02 val_loss
# 5900/20000 updates, 3.11 s, 321.91 train_loss, 214.41 val_loss
# Saving session...
# 6000/20000 updates, 3.41 s, 107.32 train_loss, 152.23 val_loss
# 6100/20000 updates, 3.62 s, 168.90 train_loss, 250.33 val_loss
# 6200/20000 updates, 3.42 s, 64.68 train_loss, 193.34 val_loss
# 6300/20000 updates, 3.39 s, 250.81 train_loss, 204.43 val_loss
# 6400/20000 updates, 3.42 s, 135.35 train_loss, 227.56 val_loss
# 6500/20000 updates, 3.43 s, 251.14 train_loss, 181.72 val_loss
# 6600/20000 updates, 3.60 s, 149.35 train_loss, 219.01 val_loss
# 6700/20000 updates, 3.56 s, 321.82 train_loss, 236.57 val_loss
# Saving session...
# 6800/20000 updates, 3.65 s, 87.70 train_loss, 144.46 val_loss
# 6900/20000 updates, 3.81 s, 160.44 train_loss, 168.46 val_loss
# 7000/20000 updates, 3.78 s, 209.68 train_loss, 206.00 val_loss
# Saving session...
# 7100/20000 updates, 3.81 s, 157.79 train_loss, 140.82 val_loss
# 7200/20000 updates, 3.79 s, 52.65 train_loss, 158.68 val_loss
# 7300/20000 updates, 3.68 s, 121.28 train_loss, 154.04 val_loss
# 7400/20000 updates, 3.80 s, 47.64 train_loss, 150.77 val_loss
# 7500/20000 updates, 3.84 s, 138.37 train_loss, 162.87 val_loss
# 7600/20000 updates, 3.83 s, 155.42 train_loss, 165.01 val_loss
# 7700/20000 updates, 3.91 s, 168.39 train_loss, 211.64 val_loss
# Saving session...
# 7800/20000 updates, 3.88 s, 28.97 train_loss, 116.82 val_loss
# 7900/20000 updates, 3.92 s, 214.31 train_loss, 140.61 val_loss
# 8000/20000 updates, 3.81 s, 120.46 train_loss, 129.70 val_loss
# 8100/20000 updates, 3.90 s, 29.56 train_loss, 125.22 val_loss
# 8200/20000 updates, 3.85 s, 19.05 train_loss, 140.68 val_loss
# Saving session...
# 8300/20000 updates, 3.81 s, 59.84 train_loss, 110.74 val_loss
# 8400/20000 updates, 3.84 s, 213.17 train_loss, 167.67 val_loss
# Saving session...
# 8500/20000 updates, 3.97 s, 241.16 train_loss, 91.51 val_loss
# 8600/20000 updates, 3.84 s, 57.55 train_loss, 181.78 val_loss
# 8700/20000 updates, 3.95 s, 96.85 train_loss, 155.39 val_loss
# 8800/20000 updates, 3.85 s, 238.55 train_loss, 110.88 val_loss
# 8900/20000 updates, 3.79 s, 133.54 train_loss, 139.33 val_loss
# 9000/20000 updates, 4.08 s, 176.50 train_loss, 125.47 val_loss
# 9100/20000 updates, 3.90 s, 241.90 train_loss, 102.61 val_loss
# Saving session...
# 9200/20000 updates, 3.76 s, 46.17 train_loss, 87.73 val_loss
# 9300/20000 updates, 4.14 s, 418.33 train_loss, 422.28 val_loss
# 9400/20000 updates, 3.99 s, 347.78 train_loss, 388.32 val_loss
# 9500/20000 updates, 4.14 s, 254.67 train_loss, 214.70 val_loss
# 9600/20000 updates, 3.96 s, 318.48 train_loss, 310.54 val_loss
# 9700/20000 updates, 4.09 s, 85.52 train_loss, 490.29 val_loss
# 9800/20000 updates, 4.07 s, 83.75 train_loss, 122.33 val_loss
# 9900/20000 updates, 4.21 s, 54.96 train_loss, 160.96 val_loss
# 10000/20000 updates, 4.26 s, 271.68 train_loss, 191.69 val_loss
# 10100/20000 updates, 4.41 s, 287.39 train_loss, 105.60 val_loss
# 10200/20000 updates, 4.37 s, 74.10 train_loss, 113.34 val_loss
# 10300/20000 updates, 4.18 s, 51.82 train_loss, 116.94 val_loss
# 10400/20000 updates, 4.50 s, -2.24 train_loss, 123.58 val_loss
# Saving session...
# 10500/20000 updates, 4.18 s, 358.07 train_loss, 76.57 val_loss
# 10600/20000 updates, 4.46 s, -25.63 train_loss, 124.47 val_loss
# 10700/20000 updates, 4.51 s, 16.76 train_loss, 144.21 val_loss
# 10800/20000 updates, 4.42 s, 217.72 train_loss, 126.64 val_loss
# 10900/20000 updates, 4.74 s, 113.38 train_loss, 97.25 val_loss
# Saving session...
# 11000/20000 updates, 4.52 s, 400.53 train_loss, 69.18 val_loss
# 11100/20000 updates, 4.69 s, 117.29 train_loss, 106.57 val_loss
# 11200/20000 updates, 4.56 s, 138.65 train_loss, 107.75 val_loss
# Saving session...
# 11300/20000 updates, 4.83 s, 22.65 train_loss, 57.41 val_loss
# 11400/20000 updates, 4.50 s, 141.91 train_loss, 83.63 val_loss
# 11500/20000 updates, 4.71 s, -38.14 train_loss, 117.51 val_loss
# 11600/20000 updates, 4.55 s, 91.08 train_loss, 81.18 val_loss
# 11700/20000 updates, 4.74 s, 283.21 train_loss, 172.48 val_loss
# 11800/20000 updates, 4.78 s, 184.37 train_loss, 64.32 val_loss
# 11900/20000 updates, 4.72 s, 128.80 train_loss, 66.97 val_loss
# 12000/20000 updates, 4.86 s, 6.28 train_loss, 110.52 val_loss
# 12100/20000 updates, 4.81 s, 175.42 train_loss, 128.59 val_loss
# 12200/20000 updates, 4.94 s, 341.96 train_loss, 83.60 val_loss
# 12300/20000 updates, 5.20 s, 134.10 train_loss, 90.44 val_loss
# 12400/20000 updates, 4.90 s, 172.19 train_loss, 63.22 val_loss
# 12500/20000 updates, 4.86 s, 63.77 train_loss, 61.11 val_loss
# 12600/20000 updates, 5.12 s, 34.76 train_loss, 87.72 val_loss
# 12700/20000 updates, 5.01 s, 18.86 train_loss, 128.61 val_loss
# 12800/20000 updates, 5.21 s, 133.94 train_loss, 181.34 val_loss
# 12900/20000 updates, 4.91 s, 57.87 train_loss, 178.10 val_loss
# 13000/20000 updates, 4.98 s, 347.49 train_loss, 146.40 val_loss
# 13100/20000 updates, 5.04 s, 34.77 train_loss, 168.91 val_loss
# 13200/20000 updates, 5.30 s, 208.32 train_loss, 121.60 val_loss
# 13300/20000 updates, 4.97 s, 48.56 train_loss, 140.02 val_loss
# 13400/20000 updates, 5.51 s, -9.92 train_loss, 74.14 val_loss
# 13500/20000 updates, 5.31 s, 134.93 train_loss, 82.65 val_loss
# 13600/20000 updates, 5.27 s, 95.32 train_loss, 120.54 val_loss
# 13700/20000 updates, 5.31 s, 129.31 train_loss, 77.78 val_loss
# 13800/20000 updates, 4.24 s, 212.76 train_loss, 174.27 val_loss
# 13900/20000 updates, 3.31 s, 366.54 train_loss, 198.96 val_loss
# 14000/20000 updates, 3.06 s, 114.93 train_loss, 63.46 val_loss
# 14100/20000 updates, 3.01 s, 112.87 train_loss, 96.81 val_loss
# 14200/20000 updates, 2.99 s, 115.70 train_loss, 111.77 val_loss
# 14300/20000 updates, 3.12 s, 162.57 train_loss, 72.67 val_loss
# 14400/20000 updates, 3.02 s, 57.65 train_loss, 112.28 val_loss
# 14500/20000 updates, 3.00 s, 20.20 train_loss, 94.28 val_loss
# 14600/20000 updates, 3.05 s, 152.62 train_loss, 114.31 val_loss
# 14700/20000 updates, 3.21 s, 81.67 train_loss, 109.68 val_loss
# 14800/20000 updates, 3.04 s, 175.47 train_loss, 80.37 val_loss
# 14900/20000 updates, 3.05 s, 81.03 train_loss, 103.00 val_loss
# 15000/20000 updates, 3.00 s, 247.28 train_loss, 95.37 val_loss
# Saving session...
# 15100/20000 updates, 3.05 s, 59.08 train_loss, 46.42 val_loss
# 15200/20000 updates, 3.09 s, 47.31 train_loss, 92.24 val_loss
# 15300/20000 updates, 2.99 s, 59.25 train_loss, 143.80 val_loss
# 15400/20000 updates, 3.09 s, 347.22 train_loss, 112.16 val_loss
# 15500/20000 updates, 2.95 s, -76.45 train_loss, 100.91 val_loss
# 15600/20000 updates, 3.08 s, 21.78 train_loss, 115.14 val_loss
# 15700/20000 updates, 3.04 s, 68.98 train_loss, 83.58 val_loss
# 15800/20000 updates, 3.11 s, 76.60 train_loss, 106.93 val_loss
# 15900/20000 updates, 3.04 s, 122.09 train_loss, 79.16 val_loss
# 16000/20000 updates, 3.17 s, 383.94 train_loss, 52.86 val_loss
# 16100/20000 updates, 3.21 s, -28.42 train_loss, 93.87 val_loss
# 16200/20000 updates, 3.22 s, -100.02 train_loss, 83.42 val_loss
# 16300/20000 updates, 3.41 s, 168.12 train_loss, 78.26 val_loss
# 16400/20000 updates, 3.43 s, 173.38 train_loss, 48.41 val_loss
# 16500/20000 updates, 3.52 s, 76.50 train_loss, 76.07 val_loss
# 16600/20000 updates, 3.60 s, -31.47 train_loss, 96.19 val_loss
# 16700/20000 updates, 3.61 s, 50.96 train_loss, 125.05 val_loss
# 16800/20000 updates, 3.79 s, 224.54 train_loss, 80.17 val_loss
# 16900/20000 updates, 3.86 s, 196.07 train_loss, 68.38 val_loss
# 17000/20000 updates, 4.03 s, 191.99 train_loss, 114.42 val_loss
# 17100/20000 updates, 4.00 s, -42.46 train_loss, 89.52 val_loss
# 17200/20000 updates, 4.30 s, 503.44 train_loss, 53.45 val_loss
# 17300/20000 updates, 4.35 s, 25.21 train_loss, 86.65 val_loss
# 17400/20000 updates, 4.62 s, 73.89 train_loss, 114.48 val_loss
# 17500/20000 updates, 4.62 s, 109.96 train_loss, 82.52 val_loss
# 17600/20000 updates, 4.63 s, 3.41 train_loss, 96.82 val_loss
# 17700/20000 updates, 4.73 s, 22.81 train_loss, 68.32 val_loss
# 17800/20000 updates, 4.99 s, 14.75 train_loss, 50.72 val_loss
# 17900/20000 updates, 4.75 s, 106.88 train_loss, 86.02 val_loss
# 18000/20000 updates, 5.08 s, -20.22 train_loss, 132.70 val_loss
# 18100/20000 updates, 4.77 s, 98.52 train_loss, 75.86 val_loss
# 18200/20000 updates, 4.87 s, 30.45 train_loss, 51.16 val_loss
# 18300/20000 updates, 5.05 s, 82.80 train_loss, 73.41 val_loss
# 18400/20000 updates, 5.10 s, 14.05 train_loss, 80.51 val_loss
# 18500/20000 updates, 5.25 s, 209.69 train_loss, 106.69 val_loss
# 18600/20000 updates, 5.46 s, 30.46 train_loss, 96.71 val_loss
# 18700/20000 updates, 5.74 s, -11.64 train_loss, 67.17 val_loss
# 18800/20000 updates, 5.00 s, 41.88 train_loss, 58.70 val_loss
# 18900/20000 updates, 5.23 s, 283.77 train_loss, 136.11 val_loss
# 19000/20000 updates, 5.21 s, 40.98 train_loss, 102.12 val_loss
# 19100/20000 updates, 5.61 s, 52.02 train_loss, 114.92 val_loss
# 19200/20000 updates, 5.63 s, 324.41 train_loss, 161.93 val_loss
# 19300/20000 updates, 5.60 s, 67.35 train_loss, 103.77 val_loss
# 19400/20000 updates, 5.55 s, 171.50 train_loss, 69.67 val_loss
# 19500/20000 updates, 5.40 s, 148.99 train_loss, 57.31 val_loss
# 19600/20000 updates, 5.64 s, 26.27 train_loss, 55.82 val_loss
# 19700/20000 updates, 5.67 s, -23.92 train_loss, 107.39 val_loss
# 19800/20000 updates, 5.93 s, -72.33 train_loss, 110.09 val_loss
# 19900/20000 updates, 5.81 s, 336.53 train_loss, 100.07 val_loss
# 0 / 1000
# 100 / 1000
# 200 / 1000
# 300 / 1000
# 400 / 1000
# 500 / 1000
# 600 / 1000
# 700 / 1000
# 800 / 1000
# 900 / 1000

# %%
print("RMSE: {:.3f}".format(RMSE_notmiwae))
# Out:
# RMSE: 1.515

# %%
x_notmiwae = np.load('x_notmiwae.npy')

# %%
x_obs = x_data[mask]
x_miss = x_data[~mask]

x_est = x_notmiwae

x_est_obs = x_est[mask]
x_est_miss = x_est[~mask]

# %%
scatter_compare_individual_entries_panel(x_obs, x_miss, x_est_obs, x_est_miss)

# %%
hist_compare_individual_entries(x_obs, x_miss, x_est_obs, x_est_miss)

# %%
W, b = notmiwae.sess.run([notmiwae.W, notmiwae.b])

# %%
fig, ax = plt.subplots(ncols=1, figsize=(6, 5))

p_obs = detection_prob[mask]
x_obs = x_data[mask]

p_miss = detection_prob[~mask]
x_miss = x_data[~mask]

n = 5_000

ax.scatter(x_miss[:n], p_miss[:n], color="red", alpha=.1, s=2)
ax.scatter(x_obs[:n], p_obs[:n], color="blue", alpha=.1, s=2)
ax.set_title("entry intensity vs detection probability")
ax.set_xlabel("entry intensity")
ax.set_ylabel("detection probability")
ax.grid(True)
ax.set_axisbelow(True)

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

for n in range(W.shape[-1]):
    xs = np.linspace(0, 18, 100)
    logit = -W[0, 0, n] * (xs - b[0, 0, n])
    ys = sigmoid(logit)
    ax.plot(xs, ys, color="black", alpha=.3, linewidth=4)
