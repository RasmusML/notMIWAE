# %% [markdown]
# # Single-cell Proteomics Synthetic Data Generation

# %% [markdown]
# The goal of this notebook is to simulate a crude single-cell proteomics datasets with a MNAR mechanism, and show that not-MIWAE performs better than MIWAE.

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

from MIWAE import MIWAE
from notMIWAE import notMIWAE
import trainer
import utils

np.random.seed(42)
# Out:
# 2023-11-20 17:36:30.000970: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-11-20 17:36:30.002869: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-20 17:36:30.027425: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-20 17:36:30.027455: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-20 17:36:30.027474: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-20 17:36:30.032569: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-20 17:36:30.032944: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-20 17:36:30.617174: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# Plotting functions for later.

# %%
def scatter_compare_individual_entries_panel(x_obs, x_miss, x_est_obs, x_est_miss):
    fig, axes = plt.subplots(ncols=2, figsize=(12, 5))
    
    ax = axes[0]
    ax.scatter(x_obs, x_est_obs, s=1, alpha=0.1)
    lims = [np.min([ax.get_xlim(), ax.get_ylim()]), np.max([ax.get_xlim(), ax.get_ylim()])]
    ax.plot(lims, lims, "--", c="k")

    mse = np.mean((x_obs - x_est_obs)**2)
    ax.text(0.05, 0.95, f"MSE: {mse:.2f}", transform=ax.transAxes, fontsize=12, verticalalignment="top", bbox=dict(facecolor="white", alpha=0.8))

    ax.set_xlabel("Observed")
    ax.set_ylabel("Imputed")
    ax.set_title("Observed")
    ax.grid(True)
    ax.set_axisbelow(True)

    ax = axes[1]
    ax.scatter(x_miss, x_est_miss, s=1, alpha=0.1)
    lims = [np.min([ax.get_xlim(), ax.get_ylim()]), np.max([ax.get_xlim(), ax.get_ylim()])]
    ax.plot(lims, lims, "--", c="k")

    mse = np.mean((x_miss - x_est_miss)**2)
    ax.text(0.05, 0.95, f"MSE: {mse:.2f}", transform=ax.transAxes, fontsize=12, verticalalignment="top", bbox=dict(facecolor="white", alpha=0.8))

    ax.set_xlabel("Observed")
    ax.set_ylabel("Imputed")
    ax.set_title("Missing")
    ax.grid(True)

# %%
def hist_compare_individual_entries(x_obs, x_miss, x_est_obs, x_est_miss):
    fig, axes = plt.subplots(ncols=2, figsize=(12, 5))

    x_min = np.min([np.min(x_obs), np.min(x_miss), np.min(x_est_obs), np.min(x_est_miss)])
    x_max = np.max([np.max(x_obs), np.max(x_miss), np.max(x_est_obs), np.max(x_est_miss)])

    ax = axes[0]
    ax.hist([x_obs, x_miss], color=["blue", "red"], bins=50, edgecolor="black", linewidth=1.2, stacked=True)
    ax.set_title("Data")
    ax.set_xlabel("x")
    ax.set_ylabel("(stacked) count")
    ax.set_xlim(x_min, x_max)
    ax.grid(True)
    ax.set_axisbelow(True)
    ax.legend(labels=["$x_{obs}$", "$x_{miss}$"], fontsize=12)

    ax = axes[1]
    ax.hist([x_est_obs, x_est_miss], color=["blue", "red"], bins=50, edgecolor="black", linewidth=1.2, stacked=True)
    ax.set_title("Model")
    ax.set_xlabel("x")
    ax.set_ylabel("(stacked) count")
    ax.set_xlim(x_min, x_max)
    ax.grid(True)
    ax.set_axisbelow(True)
    ax.legend(labels=["$x_{obs}$", "$x_{miss}$"], fontsize=12)

# %% [markdown]
# ## Data generation

# %% [markdown]
# Let's start by generating the synthetic data and visualizing it.

# %%
def logistic(x, k=1, x0=0, L=1):
    return L / (1 + np.exp(-k * (x - x0)))

def sigmoid(x):
    return 1 / (1 + np.exp(-x))


def simulate_data(n_cells=2000, n_proteins=1000):
    # all cells are from the same group (cell-type)
    # the cell type has some protein distribution / signature
    cell_type_signature = np.random.uniform(5, 12, n_proteins)

    # each cell is a bit different
    cell_variation = np.random.normal(0, 1, n_cells)

    intensity = cell_type_signature.reshape(1, -1) + cell_variation.reshape(-1, 1)

    # the measurement is noisy
    x = np.random.normal(intensity, 0.1)

    # MNAR mechanism: self-masking (x -> m)
    # entries with low intensity are less likely to be sampled
    #detection_prob = logistic(x, k=2, x0=7) # set x0=6, if you want less missing values
    detection_prob = sigmoid(2*x - 14)

    # sample using a bernoulli distribution
    mask = np.random.binomial(1, detection_prob)
    mask = mask.astype(bool)

    return x, detection_prob, mask

# %% [markdown]
# Let's simulate some data:

# %%
x_data, detection_prob, mask = simulate_data()

# %%
x_nan = x_data.copy()
x_nan[~mask] = np.nan

x_0 = x_data.copy()
x_0[~mask] = 0

# %%
print("Missing entries: {:.2f}%".format(np.isnan(x_nan).sum() / x_nan.size * 100))
# Out:
# Missing entries: 29.75%

# %% [markdown]
# Let's plot the data. "White" are the missing values.

# %%
fig, ax = plt.subplots(figsize=(8, 5))
sns.heatmap(x_nan, cmap="viridis", xticklabels=False, yticklabels=False, ax=ax)
ax.set_xlabel("Proteins")
ax.set_ylabel("Cells")
ax.set_title("Expression matrix with missing values")
# Out:
# Text(0.5, 1.0, 'Expression matrix with missing values')

# %% [markdown]
# Let's look at the missigness pattern entry-wise and protein-wise:

# %%
fig, axes = plt.subplots(ncols=2, figsize=(12, 5))

# plot entry intensity vs detection probability
ax = axes[0]

p_obs = detection_prob[mask]
x_obs = x_data[mask]

p_miss = detection_prob[~mask]
x_miss = x_data[~mask]

n = 5_000

ax.scatter(x_miss[:n], p_miss[:n], color="red", alpha=.1, s=4)
ax.scatter(x_obs[:n], p_obs[:n], color="blue", alpha=.1, s=4)
ax.set_title("entry intensity vs detection probability")
ax.set_xlabel("entry intensity")
ax.set_ylabel("detection probability")
ax.grid(True)
ax.set_axisbelow(True)

# plot the average protein intensity vs the detection proportion
ax = axes[1]
x_obs_protein = np.nanmean(x_nan, axis=0)
p_protein = 1 - np.nanmean(np.isnan(x_nan), axis=0)

ax.scatter(x_obs_protein, p_protein, color="blue", alpha=1, s=6)
ax.set_title("avg protein intensity vs detection proportion")
ax.set_xlabel("protein intensity")
ax.set_ylabel("detection proportion")
ax.grid(True)
ax.set_axisbelow(True)

# %%
fig, ax = plt.subplots(1, 1, figsize=(5, 5))

ax.hist([x_obs, x_miss], color=["blue", "red"], bins=50, edgecolor="black", linewidth=1.2, stacked=True)
ax.set_title("Data")
ax.set_xlabel("x")
ax.set_ylabel("(stacked) count")
ax.set_xlim(np.min(x_data), np.max(x_data))
ax.grid(True)
ax.set_axisbelow(True)
ax.legend(labels=["$x_{obs}$", "$x_{miss}$"], fontsize=12)

# %% [markdown]
# ## Model Comparison

# %% [markdown]
# Set the parameters for the models.

# %%
name = '/tmp/best'

# model specification
n_hidden = 128
n_samples = 20
n_latent = 16
out_dist='gauss'

# training
max_iter = 10_000
batch_size = 64

# imputation
L = 1000

# %% [markdown]
# Let's run.

# %%
N, D = x_data.shape

Xtrain = x_data.copy()
Xval_org = x_data.copy()

Xnan = x_nan.copy()
Xz = x_0.copy()
S = mask.copy()

Xval = x_nan.copy()
Xvalz = x_0.copy()

# %%
tf.compat.v1.disable_eager_execution()

# %% [markdown]
# ### MIWAE

# %%
miwae = MIWAE(Xnan, Xval, n_latent=n_latent, n_samples=n_samples, n_hidden=n_hidden, name=name, out_dist=out_dist)

# ---- do the training
trainer.train(miwae, batch_size=batch_size, max_iter=max_iter, name=name + 'miwae')

# ---- find imputation RMSE
RMSE_miwae, x_miwae = utils.imputationRMSE(miwae, Xtrain, Xz, Xnan, S, L)

np.save('x_miwae.npy', x_miwae)
# Out:
# Creating graph...
# 2023-11-20 17:36:34.318980: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:382] MLIR V1 optimization pass is not enabled
# Saving session...
# Saving session...
# 0/10000 updates, 0.24 s, 71747.41 train_loss, 68255.58 val_loss
# Saving session...
# 100/10000 updates, 4.65 s, 2065.93 train_loss, 2136.48 val_loss
# Saving session...
# 200/10000 updates, 4.75 s, 1612.68 train_loss, 1682.65 val_loss
# Saving session...
# 300/10000 updates, 4.12 s, 1432.20 train_loss, 1402.59 val_loss
# Saving session...
# 400/10000 updates, 4.01 s, 1062.59 train_loss, 1079.53 val_loss
# Saving session...
# 500/10000 updates, 4.81 s, 644.73 train_loss, 643.58 val_loss
# Saving session...
# 600/10000 updates, 3.88 s, 315.04 train_loss, 309.23 val_loss
# Saving session...
# 700/10000 updates, 4.11 s, 63.50 train_loss, 96.38 val_loss
# Saving session...
# 800/10000 updates, 4.08 s, 124.08 train_loss, 62.34 val_loss
# Saving session...
# 900/10000 updates, 4.22 s, -158.46 train_loss, -42.74 val_loss
# Saving session...
# 1000/10000 updates, 4.11 s, -149.51 train_loss, -149.14 val_loss
# 1100/10000 updates, 4.36 s, -127.10 train_loss, -101.73 val_loss
# 1200/10000 updates, 3.97 s, -145.10 train_loss, -127.28 val_loss
# 1300/10000 updates, 4.10 s, 18.40 train_loss, -33.42 val_loss
# 1400/10000 updates, 4.42 s, -119.54 train_loss, -137.37 val_loss
# 1500/10000 updates, 4.23 s, -40.05 train_loss, -55.62 val_loss
# 1600/10000 updates, 4.19 s, 43.68 train_loss, -33.95 val_loss
# 1700/10000 updates, 4.10 s, -196.96 train_loss, -95.58 val_loss
# 1800/10000 updates, 4.63 s, -109.78 train_loss, -28.29 val_loss
# 1900/10000 updates, 3.90 s, 8.53 train_loss, -135.48 val_loss
# 2000/10000 updates, 4.61 s, -50.49 train_loss, -96.36 val_loss
# Saving session...
# 2100/10000 updates, 4.33 s, -81.58 train_loss, -154.39 val_loss
# Saving session...
# 2200/10000 updates, 4.38 s, -205.66 train_loss, -166.94 val_loss
# 2300/10000 updates, 3.93 s, -154.65 train_loss, -133.73 val_loss
# 2400/10000 updates, 4.34 s, -234.88 train_loss, -137.29 val_loss
# Saving session...
# 2500/10000 updates, 3.80 s, -210.73 train_loss, -169.75 val_loss
# 2600/10000 updates, 4.30 s, -68.44 train_loss, -111.55 val_loss
# Saving session...
# 2700/10000 updates, 4.20 s, -138.94 train_loss, -200.44 val_loss
# 2800/10000 updates, 4.03 s, -174.42 train_loss, -159.03 val_loss
# 2900/10000 updates, 4.08 s, -167.37 train_loss, -181.60 val_loss
# 3000/10000 updates, 4.32 s, -212.20 train_loss, -178.75 val_loss
# 3100/10000 updates, 4.04 s, -159.91 train_loss, -159.94 val_loss
# 3200/10000 updates, 4.30 s, -161.79 train_loss, -125.68 val_loss
# 3300/10000 updates, 4.17 s, -195.31 train_loss, -166.99 val_loss
# 3400/10000 updates, 4.42 s, 16.38 train_loss, -120.56 val_loss
# 3500/10000 updates, 4.21 s, -91.62 train_loss, -168.72 val_loss
# 3600/10000 updates, 4.09 s, -272.25 train_loss, -180.72 val_loss
# 3700/10000 updates, 4.25 s, 81.11 train_loss, -21.88 val_loss
# 3800/10000 updates, 3.99 s, -209.23 train_loss, -182.63 val_loss
# 3900/10000 updates, 3.90 s, -184.34 train_loss, -169.90 val_loss
# 4000/10000 updates, 4.16 s, -167.90 train_loss, -139.38 val_loss
# 4100/10000 updates, 4.47 s, -235.39 train_loss, -151.23 val_loss
# 4200/10000 updates, 4.48 s, 43.80 train_loss, -14.32 val_loss
# 4300/10000 updates, 4.59 s, -118.81 train_loss, -108.18 val_loss
# 4400/10000 updates, 4.73 s, -156.02 train_loss, -172.84 val_loss
# 4500/10000 updates, 4.09 s, -104.22 train_loss, -156.83 val_loss
# 4600/10000 updates, 3.96 s, -229.45 train_loss, -157.42 val_loss
# 4700/10000 updates, 3.99 s, 76.00 train_loss, -125.39 val_loss
# 4800/10000 updates, 5.20 s, -128.64 train_loss, -152.61 val_loss
# 4900/10000 updates, 5.11 s, -184.61 train_loss, -149.52 val_loss
# 5000/10000 updates, 4.76 s, -96.19 train_loss, -119.40 val_loss
# 5100/10000 updates, 4.34 s, -41.60 train_loss, -149.23 val_loss
# 5200/10000 updates, 4.77 s, -198.73 train_loss, -174.69 val_loss
# 5300/10000 updates, 3.99 s, -63.65 train_loss, -164.12 val_loss
# 5400/10000 updates, 4.39 s, -171.45 train_loss, -137.07 val_loss
# 5500/10000 updates, 4.69 s, -200.42 train_loss, -167.24 val_loss
# 5600/10000 updates, 4.65 s, -147.21 train_loss, -151.61 val_loss
# 5700/10000 updates, 4.09 s, -151.82 train_loss, -168.68 val_loss
# 5800/10000 updates, 4.64 s, -252.18 train_loss, -179.98 val_loss
# 5900/10000 updates, 4.97 s, -251.61 train_loss, -178.22 val_loss
# 6000/10000 updates, 5.10 s, -197.96 train_loss, -176.42 val_loss
# 6100/10000 updates, 4.79 s, -171.83 train_loss, -186.11 val_loss
# 6200/10000 updates, 4.40 s, -183.48 train_loss, -151.67 val_loss
# 6300/10000 updates, 4.24 s, -206.16 train_loss, -186.56 val_loss
# 6400/10000 updates, 4.41 s, 255.92 train_loss, -53.54 val_loss
# 6500/10000 updates, 4.94 s, -110.54 train_loss, -123.91 val_loss
# 6600/10000 updates, 4.88 s, -72.69 train_loss, -98.81 val_loss
# 6700/10000 updates, 5.09 s, -129.49 train_loss, -169.17 val_loss
# 6800/10000 updates, 5.44 s, -58.27 train_loss, -131.00 val_loss
# 6900/10000 updates, 5.10 s, -42.75 train_loss, -152.04 val_loss
# 7000/10000 updates, 4.79 s, -218.20 train_loss, -174.64 val_loss
# 7100/10000 updates, 4.54 s, -145.71 train_loss, -132.18 val_loss
# 7200/10000 updates, 4.17 s, -239.64 train_loss, -178.84 val_loss
# 7300/10000 updates, 5.09 s, -153.32 train_loss, -189.00 val_loss
# 7400/10000 updates, 4.94 s, -116.18 train_loss, -168.80 val_loss
# 7500/10000 updates, 4.96 s, -218.08 train_loss, -156.05 val_loss
# 7600/10000 updates, 5.12 s, -61.11 train_loss, -140.97 val_loss
# 7700/10000 updates, 5.28 s, -198.13 train_loss, -175.56 val_loss
# 7800/10000 updates, 5.19 s, -177.63 train_loss, -177.04 val_loss
# 7900/10000 updates, 5.13 s, -161.72 train_loss, -147.26 val_loss
# 8000/10000 updates, 3.88 s, 196.49 train_loss, -96.97 val_loss
# 8100/10000 updates, 4.33 s, -172.22 train_loss, -155.78 val_loss
# 8200/10000 updates, 4.21 s, -150.80 train_loss, -186.46 val_loss
# 8300/10000 updates, 5.32 s, -166.19 train_loss, -155.64 val_loss
# 8400/10000 updates, 5.12 s, -188.12 train_loss, -174.07 val_loss
# 8500/10000 updates, 4.65 s, -192.43 train_loss, -179.28 val_loss
# 8600/10000 updates, 4.95 s, -286.07 train_loss, -184.11 val_loss
# 8700/10000 updates, 4.33 s, -260.01 train_loss, -113.86 val_loss
# 8800/10000 updates, 3.93 s, -232.02 train_loss, -193.67 val_loss
# 8900/10000 updates, 5.03 s, -220.50 train_loss, -145.11 val_loss
# 9000/10000 updates, 5.20 s, -208.86 train_loss, -188.64 val_loss
# 9100/10000 updates, 4.53 s, -66.45 train_loss, -139.38 val_loss
# 9200/10000 updates, 4.78 s, -211.59 train_loss, -174.60 val_loss
# 9300/10000 updates, 5.42 s, -99.78 train_loss, -145.84 val_loss
# 9400/10000 updates, 5.11 s, -197.60 train_loss, -175.49 val_loss
# 9500/10000 updates, 5.06 s, -53.66 train_loss, -67.43 val_loss
# 9600/10000 updates, 5.08 s, 117.62 train_loss, -2.50 val_loss
# 9700/10000 updates, 5.24 s, -170.60 train_loss, -148.45 val_loss
# 9800/10000 updates, 4.29 s, -188.91 train_loss, -118.09 val_loss
# 9900/10000 updates, 4.09 s, -179.10 train_loss, -96.32 val_loss
# 0 / 2000
# 100 / 2000
# 200 / 2000
# 300 / 2000
# 400 / 2000
# 500 / 2000
# 600 / 2000
# 700 / 2000
# 800 / 2000
# 900 / 2000
# 1000 / 2000
# 1100 / 2000
# 1200 / 2000
# 1300 / 2000
# 1400 / 2000
# 1500 / 2000
# 1600 / 2000
# 1700 / 2000
# 1800 / 2000
# 1900 / 2000

# %%
print("RMSE: {:.3f}".format(RMSE_miwae))
# Out:
# RMSE: 0.326

# %%
x_miwae = np.load('x_miwae.npy')

# %%
x_obs = x_data[mask]
x_miss = x_data[~mask]

x_est = x_miwae

x_est_obs = x_est[mask]
x_est_miss = x_est[~mask]

# %%
scatter_compare_individual_entries_panel(x_obs, x_miss, x_est_obs, x_est_miss)

# %%
hist_compare_individual_entries(x_obs, x_miss, x_est_obs, x_est_miss)

# %% [markdown]
# ### not-MIWAE (self-masking)

# %%
notmiwae = notMIWAE(Xnan, Xval, n_latent=n_latent, n_samples=n_samples, n_hidden=n_hidden, name=name, out_dist=out_dist, mechanism_weight=0.1, missing_process='selfmasking')

# ---- do the training
trainer.train(notmiwae, batch_size=batch_size, max_iter=max_iter, name=name + 'notmiwae')

# ---- find imputation RMSE
RMSE_notmiwae, x_notmiwae = utils.not_imputationRMSE(notmiwae, Xtrain, Xz, Xnan, S, L)

np.save('x_notmiwae.npy', x_notmiwae)
# Out:
# Creating graph...
# Saving session...
# Saving session...
# 0/10000 updates, 0.17 s, 70580.92 train_loss, 69377.73 val_loss
# Saving session...
# 100/10000 updates, 4.41 s, 2199.71 train_loss, 2247.08 val_loss
# Saving session...
# 200/10000 updates, 3.79 s, 1791.03 train_loss, 1755.53 val_loss
# Saving session...
# 300/10000 updates, 4.17 s, 1476.46 train_loss, 1487.40 val_loss
# Saving session...
# 400/10000 updates, 4.01 s, 1167.61 train_loss, 1183.91 val_loss
# Saving session...
# 500/10000 updates, 4.60 s, 738.95 train_loss, 749.43 val_loss
# Saving session...
# 600/10000 updates, 4.92 s, 422.05 train_loss, 396.01 val_loss
# Saving session...
# 700/10000 updates, 5.48 s, 287.02 train_loss, 189.63 val_loss
# Saving session...
# 800/10000 updates, 5.41 s, 6.53 train_loss, 19.23 val_loss
# Saving session...
# 900/10000 updates, 5.30 s, -124.73 train_loss, -40.26 val_loss
# 1000/10000 updates, 5.53 s, -106.04 train_loss, -26.87 val_loss
# 1100/10000 updates, 5.38 s, 49.50 train_loss, -37.55 val_loss
# Saving session...
# 1200/10000 updates, 5.45 s, -16.96 train_loss, -56.64 val_loss
# 1300/10000 updates, 5.13 s, -50.91 train_loss, -37.67 val_loss
# 1400/10000 updates, 5.40 s, 110.91 train_loss, 207.15 val_loss
# Saving session...
# 1500/10000 updates, 5.62 s, -159.83 train_loss, -94.70 val_loss
# Saving session...
# 1600/10000 updates, 5.80 s, -161.61 train_loss, -104.29 val_loss
# Saving session...
# 1700/10000 updates, 5.27 s, 4.05 train_loss, -109.70 val_loss
# 1800/10000 updates, 5.93 s, -114.53 train_loss, -104.41 val_loss
# 1900/10000 updates, 5.61 s, -65.08 train_loss, -60.44 val_loss
# 2000/10000 updates, 5.76 s, -65.59 train_loss, -69.08 val_loss
# 2100/10000 updates, 5.12 s, -76.36 train_loss, -27.57 val_loss
# 2200/10000 updates, 5.14 s, -121.05 train_loss, -64.12 val_loss
# 2300/10000 updates, 5.46 s, -45.23 train_loss, -89.81 val_loss
# Saving session...
# 2400/10000 updates, 5.60 s, -181.80 train_loss, -120.67 val_loss
# Saving session...
# 2500/10000 updates, 5.31 s, -148.78 train_loss, -130.26 val_loss
# 2600/10000 updates, 5.58 s, -72.58 train_loss, -123.54 val_loss
# 2700/10000 updates, 6.06 s, -29.93 train_loss, -93.04 val_loss
# 2800/10000 updates, 6.28 s, 57.86 train_loss, -64.92 val_loss
# 2900/10000 updates, 5.54 s, -129.40 train_loss, -104.94 val_loss
# 3000/10000 updates, 5.05 s, -125.17 train_loss, -78.59 val_loss
# 3100/10000 updates, 5.23 s, -112.92 train_loss, -74.76 val_loss
# 3200/10000 updates, 5.60 s, -129.30 train_loss, -104.94 val_loss
# 3300/10000 updates, 5.39 s, -192.11 train_loss, -104.55 val_loss
# 3400/10000 updates, 5.18 s, -58.94 train_loss, -98.95 val_loss
# 3500/10000 updates, 5.77 s, -25.25 train_loss, -119.60 val_loss
# 3600/10000 updates, 5.51 s, -77.85 train_loss, -64.34 val_loss
# 3700/10000 updates, 5.10 s, 4.68 train_loss, -51.30 val_loss
# 3800/10000 updates, 6.40 s, 258.48 train_loss, -86.85 val_loss
# Saving session...
# 3900/10000 updates, 5.97 s, -182.60 train_loss, -153.75 val_loss
# 4000/10000 updates, 5.49 s, -19.95 train_loss, -114.42 val_loss
# 4100/10000 updates, 5.10 s, -193.64 train_loss, -143.93 val_loss
# 4200/10000 updates, 5.04 s, -144.15 train_loss, -125.77 val_loss
# 4300/10000 updates, 5.38 s, -168.43 train_loss, -81.69 val_loss
# 4400/10000 updates, 5.76 s, -89.07 train_loss, -138.26 val_loss
# 4500/10000 updates, 5.47 s, -176.54 train_loss, -126.34 val_loss
# 4600/10000 updates, 5.30 s, -186.42 train_loss, -147.14 val_loss
# 4700/10000 updates, 5.68 s, -148.43 train_loss, -128.79 val_loss
# 4800/10000 updates, 5.51 s, -162.82 train_loss, -140.33 val_loss
# 4900/10000 updates, 5.60 s, -87.09 train_loss, -100.54 val_loss
# 5000/10000 updates, 5.68 s, -179.32 train_loss, -141.38 val_loss
# 5100/10000 updates, 5.88 s, -112.83 train_loss, -117.24 val_loss
# 5200/10000 updates, 6.57 s, -164.21 train_loss, -133.35 val_loss
# 5300/10000 updates, 6.62 s, -110.01 train_loss, -44.47 val_loss
# 5400/10000 updates, 7.03 s, 47.79 train_loss, -142.41 val_loss
# 5500/10000 updates, 6.99 s, -216.52 train_loss, -120.54 val_loss
# 5600/10000 updates, 6.91 s, -128.10 train_loss, -146.79 val_loss
# 5700/10000 updates, 6.49 s, 19.09 train_loss, -88.05 val_loss
# 5800/10000 updates, 5.36 s, -84.73 train_loss, -121.10 val_loss
# 5900/10000 updates, 5.59 s, -203.29 train_loss, -127.83 val_loss
# 6000/10000 updates, 5.37 s, -80.39 train_loss, -142.45 val_loss
# 6100/10000 updates, 5.74 s, -235.51 train_loss, -142.88 val_loss
# 6200/10000 updates, 6.03 s, -224.36 train_loss, -122.64 val_loss
# 6300/10000 updates, 5.33 s, -44.75 train_loss, -100.88 val_loss
# 6400/10000 updates, 8.78 s, -167.33 train_loss, -136.48 val_loss
# 6500/10000 updates, 6.85 s, -93.25 train_loss, -129.66 val_loss
# 6600/10000 updates, 6.44 s, -180.99 train_loss, -106.29 val_loss
# 6700/10000 updates, 5.41 s, -9.96 train_loss, -62.05 val_loss
# 6800/10000 updates, 5.27 s, -173.44 train_loss, -148.23 val_loss
# 6900/10000 updates, 5.38 s, 50.90 train_loss, -22.01 val_loss
# 7000/10000 updates, 5.91 s, -180.35 train_loss, -127.98 val_loss
# 7100/10000 updates, 5.33 s, -46.77 train_loss, -89.78 val_loss
# 7200/10000 updates, 6.43 s, -159.28 train_loss, -83.30 val_loss
# 7300/10000 updates, 5.70 s, -118.19 train_loss, -106.97 val_loss
# 7400/10000 updates, 5.41 s, -273.06 train_loss, -116.30 val_loss
# 7500/10000 updates, 6.15 s, -112.58 train_loss, -134.10 val_loss
# 7600/10000 updates, 5.71 s, 13.89 train_loss, -97.64 val_loss
# Saving session...
# 7700/10000 updates, 6.51 s, -193.89 train_loss, -153.98 val_loss
# 7800/10000 updates, 5.80 s, -199.95 train_loss, -128.10 val_loss
# 7900/10000 updates, 5.91 s, -84.48 train_loss, -141.29 val_loss
# 8000/10000 updates, 6.35 s, -81.92 train_loss, -100.78 val_loss
# 8100/10000 updates, 6.16 s, -210.92 train_loss, -118.55 val_loss
# 8200/10000 updates, 6.15 s, -172.50 train_loss, -127.52 val_loss
# 8300/10000 updates, 6.20 s, -93.61 train_loss, -132.04 val_loss
# 8400/10000 updates, 6.47 s, -54.72 train_loss, -0.25 val_loss
# 8500/10000 updates, 5.78 s, -126.37 train_loss, -124.13 val_loss
# 8600/10000 updates, 5.90 s, -238.59 train_loss, -125.80 val_loss
# Saving session...
# 8700/10000 updates, 5.54 s, -120.34 train_loss, -159.64 val_loss
# 8800/10000 updates, 5.41 s, 319.08 train_loss, -118.79 val_loss
# 8900/10000 updates, 5.65 s, -23.57 train_loss, -138.49 val_loss
# 9000/10000 updates, 5.31 s, -114.26 train_loss, -106.03 val_loss
# 9100/10000 updates, 5.36 s, -126.57 train_loss, -128.10 val_loss
# 9200/10000 updates, 5.57 s, -116.53 train_loss, -141.39 val_loss
# Saving session...
# 9300/10000 updates, 5.27 s, -202.89 train_loss, -165.05 val_loss
# 9400/10000 updates, 5.23 s, -259.13 train_loss, -127.28 val_loss
# 9500/10000 updates, 5.84 s, -226.05 train_loss, -136.25 val_loss
# 9600/10000 updates, 6.41 s, -117.75 train_loss, -160.67 val_loss
# 9700/10000 updates, 5.42 s, -151.22 train_loss, -133.25 val_loss
# 9800/10000 updates, 5.76 s, -240.66 train_loss, -122.99 val_loss
# 9900/10000 updates, 5.57 s, -115.62 train_loss, -147.16 val_loss
# 0 / 2000
# 100 / 2000
# 200 / 2000
# 300 / 2000
# 400 / 2000
# 500 / 2000
# 600 / 2000
# 700 / 2000
# 800 / 2000
# 900 / 2000
# 1000 / 2000
# 1100 / 2000
# 1200 / 2000
# 1300 / 2000
# 1400 / 2000
# 1500 / 2000
# 1600 / 2000
# 1700 / 2000
# 1800 / 2000
# 1900 / 2000

# %%
print("RMSE: {:.3f}".format(RMSE_notmiwae))
# Out:
# RMSE: 0.217

# %%
x_notmiwae = np.load('x_notmiwae.npy')

# %%
x_obs = x_data[mask]
x_miss = x_data[~mask]

x_est = x_notmiwae

x_est_obs = x_est[mask]
x_est_miss = x_est[~mask]

# %%
scatter_compare_individual_entries_panel(x_obs, x_miss, x_est_obs, x_est_miss)

# %%
hist_compare_individual_entries(x_obs, x_miss, x_est_obs, x_est_miss)

# %%
W, b = notmiwae.sess.run([notmiwae.W, notmiwae.b])

# %%
fig, ax = plt.subplots(ncols=1, figsize=(6, 5))

p_obs = detection_prob[mask]
x_obs = x_data[mask]

p_miss = detection_prob[~mask]
x_miss = x_data[~mask]

n = 5_000

ax.scatter(x_miss[:n], p_miss[:n], color="red", alpha=.1, s=2)
ax.scatter(x_obs[:n], p_obs[:n], color="blue", alpha=.1, s=2)
ax.set_title("entry intensity vs detection probability")
ax.set_xlabel("entry intensity")
ax.set_ylabel("detection probability")
ax.grid(True)
ax.set_axisbelow(True)

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

for n in range(W.shape[-1]):
    xs = np.linspace(0, 18, 100)
    logit = W[0, 0, n] * xs + b[0, 0, n]
    ys = sigmoid(logit)
    ax.plot(xs, ys, color="black", alpha=.3, linewidth=4)

# %% [markdown]
# ### not-MIWAE (self-masking known)

# %%
notmiwae = notMIWAE(Xnan, Xval, n_latent=n_latent, n_samples=n_samples, n_hidden=n_hidden, name=name, out_dist=out_dist, mechanism_weight=0.1, missing_process='selfmasking_known')

# ---- do the training
trainer.train(notmiwae, batch_size=batch_size, max_iter=max_iter, name=name + 'notmiwae')

# ---- find imputation RMSE
RMSE_notmiwae, x_notmiwae = utils.not_imputationRMSE(notmiwae, Xtrain, Xz, Xnan, S, L)

np.save('x_notmiwae.npy', x_notmiwae)
# Out:
# Creating graph...
# Saving session...
# Saving session...
# 0/10000 updates, 0.25 s, 71037.77 train_loss, 69485.24 val_loss
# Saving session...
# 100/10000 updates, 5.79 s, 2135.26 train_loss, 2179.59 val_loss
# Saving session...
# 200/10000 updates, 5.33 s, 1796.88 train_loss, 1719.22 val_loss
# Saving session...
# 300/10000 updates, 5.37 s, 1428.70 train_loss, 1423.15 val_loss
# Saving session...
# 400/10000 updates, 5.49 s, 1163.15 train_loss, 1090.65 val_loss
# Saving session...
# 500/10000 updates, 5.51 s, 635.10 train_loss, 652.55 val_loss
# Saving session...
# 600/10000 updates, 5.62 s, 284.56 train_loss, 268.33 val_loss
# Saving session...
# 700/10000 updates, 6.09 s, 50.18 train_loss, 140.48 val_loss
# Saving session...
# 800/10000 updates, 6.06 s, 33.80 train_loss, -1.10 val_loss
# 900/10000 updates, 5.64 s, -7.87 train_loss, 21.95 val_loss
# Saving session...
# 1000/10000 updates, 5.77 s, -113.96 train_loss, -107.66 val_loss
# 1100/10000 updates, 5.81 s, -30.28 train_loss, -93.82 val_loss
# 1200/10000 updates, 5.56 s, -100.24 train_loss, -70.22 val_loss
# 1300/10000 updates, 5.42 s, -64.93 train_loss, -82.63 val_loss
# 1400/10000 updates, 5.14 s, -119.22 train_loss, -89.20 val_loss
# 1500/10000 updates, 5.12 s, -133.48 train_loss, 218.14 val_loss
# Saving session...
# 1600/10000 updates, 5.20 s, -176.02 train_loss, -129.83 val_loss
# 1700/10000 updates, 5.50 s, -87.37 train_loss, -87.41 val_loss
# Saving session...
# 1800/10000 updates, 5.76 s, -213.34 train_loss, -165.43 val_loss
# 1900/10000 updates, 5.42 s, -103.08 train_loss, -62.71 val_loss
# 2000/10000 updates, 4.97 s, -97.86 train_loss, -138.87 val_loss
# Saving session...
# 2100/10000 updates, 5.89 s, -201.89 train_loss, -205.35 val_loss
# Saving session...
# 2200/10000 updates, 5.34 s, -273.07 train_loss, -241.14 val_loss
# 2300/10000 updates, 5.65 s, -256.83 train_loss, -163.22 val_loss
# Saving session...
# 2400/10000 updates, 5.15 s, -350.62 train_loss, -302.46 val_loss
# 2500/10000 updates, 5.62 s, -18.34 train_loss, -117.17 val_loss
# 2600/10000 updates, 5.07 s, -195.18 train_loss, -149.55 val_loss
# 2700/10000 updates, 5.66 s, -197.90 train_loss, -117.92 val_loss
# 2800/10000 updates, 5.88 s, -178.83 train_loss, -123.26 val_loss
# 2900/10000 updates, 5.50 s, -162.06 train_loss, -151.19 val_loss
# 3000/10000 updates, 5.52 s, -309.36 train_loss, -262.33 val_loss
# 3100/10000 updates, 5.80 s, -140.96 train_loss, -170.96 val_loss
# Saving session...
# 3200/10000 updates, 5.95 s, -269.11 train_loss, -321.61 val_loss
# 3300/10000 updates, 6.66 s, -68.60 train_loss, -95.56 val_loss
# Saving session...
# 3400/10000 updates, 6.54 s, -374.67 train_loss, -326.92 val_loss
# 3500/10000 updates, 5.41 s, -333.01 train_loss, -273.14 val_loss
# 3600/10000 updates, 7.75 s, -254.50 train_loss, -236.83 val_loss
# 3700/10000 updates, 7.00 s, -39.43 train_loss, -323.33 val_loss
# 3800/10000 updates, 5.59 s, -348.94 train_loss, -293.17 val_loss
# 3900/10000 updates, 5.55 s, -283.74 train_loss, -278.68 val_loss
# Saving session...
# 4000/10000 updates, 5.60 s, -334.43 train_loss, -353.61 val_loss
# 4100/10000 updates, 5.42 s, -405.21 train_loss, -324.37 val_loss
# Saving session...
# 4200/10000 updates, 5.48 s, -399.86 train_loss, -362.73 val_loss
# 4300/10000 updates, 5.56 s, -329.89 train_loss, -304.58 val_loss
# 4400/10000 updates, 5.57 s, -334.61 train_loss, -318.85 val_loss
# 4500/10000 updates, 5.41 s, -307.44 train_loss, -326.21 val_loss
# 4600/10000 updates, 5.18 s, -111.45 train_loss, -332.19 val_loss
# 4700/10000 updates, 5.19 s, -347.08 train_loss, -349.96 val_loss
# 4800/10000 updates, 5.82 s, -361.67 train_loss, -320.96 val_loss
# 4900/10000 updates, 5.29 s, -229.47 train_loss, -248.56 val_loss
# 5000/10000 updates, 5.46 s, -341.59 train_loss, -317.72 val_loss
# 5100/10000 updates, 5.35 s, -356.21 train_loss, -324.61 val_loss
# 5200/10000 updates, 5.15 s, -284.76 train_loss, -334.47 val_loss
# Saving session...
# 5300/10000 updates, 5.21 s, -345.92 train_loss, -363.27 val_loss
# 5400/10000 updates, 5.86 s, -368.00 train_loss, -311.84 val_loss
# 5500/10000 updates, 5.63 s, -180.68 train_loss, -301.39 val_loss
# 5600/10000 updates, 5.81 s, -168.85 train_loss, -279.68 val_loss
# 5700/10000 updates, 6.24 s, -350.39 train_loss, -327.77 val_loss
# 5800/10000 updates, 5.92 s, -269.72 train_loss, -274.08 val_loss
# 5900/10000 updates, 5.42 s, -359.36 train_loss, -332.98 val_loss
# 6000/10000 updates, 5.44 s, -367.00 train_loss, -304.73 val_loss
# 6100/10000 updates, 5.31 s, -204.02 train_loss, -274.60 val_loss
# 6200/10000 updates, 5.73 s, -300.75 train_loss, -298.81 val_loss
# 6300/10000 updates, 5.55 s, -150.38 train_loss, -300.94 val_loss
# 6400/10000 updates, 5.90 s, -299.58 train_loss, -310.24 val_loss
# 6500/10000 updates, 5.53 s, -338.48 train_loss, -316.68 val_loss
# 6600/10000 updates, 5.79 s, -286.27 train_loss, -302.83 val_loss
# 6700/10000 updates, 5.46 s, -397.04 train_loss, -332.43 val_loss
# 6800/10000 updates, 5.76 s, -378.96 train_loss, -349.22 val_loss
# 6900/10000 updates, 5.56 s, -248.16 train_loss, -348.39 val_loss
# 7000/10000 updates, 5.44 s, -394.74 train_loss, -335.05 val_loss
# 7100/10000 updates, 5.46 s, -338.97 train_loss, -328.79 val_loss
# 7200/10000 updates, 5.48 s, -308.40 train_loss, -325.12 val_loss
# 7300/10000 updates, 5.44 s, -393.42 train_loss, -341.73 val_loss
# 7400/10000 updates, 5.68 s, -358.99 train_loss, -313.30 val_loss
# 7500/10000 updates, 5.68 s, -191.84 train_loss, -196.95 val_loss
# 7600/10000 updates, 5.45 s, -192.88 train_loss, -274.26 val_loss
# 7700/10000 updates, 5.57 s, -336.35 train_loss, -156.55 val_loss
# 7800/10000 updates, 5.55 s, -320.08 train_loss, -315.66 val_loss
# Saving session...
# 7900/10000 updates, 5.28 s, -367.99 train_loss, -364.86 val_loss
# 8000/10000 updates, 5.74 s, -243.73 train_loss, -344.29 val_loss
# 8100/10000 updates, 5.25 s, -342.39 train_loss, -331.45 val_loss
# Saving session...
# 8200/10000 updates, 6.19 s, -431.58 train_loss, -373.49 val_loss
# 8300/10000 updates, 5.88 s, -353.47 train_loss, -292.60 val_loss
# 8400/10000 updates, 5.71 s, -410.56 train_loss, -335.67 val_loss
# 8500/10000 updates, 5.82 s, -264.91 train_loss, -225.07 val_loss
# 8600/10000 updates, 6.80 s, -376.47 train_loss, -231.25 val_loss
# 8700/10000 updates, 5.98 s, -320.27 train_loss, -302.27 val_loss
# 8800/10000 updates, 5.63 s, -409.14 train_loss, -323.60 val_loss
# 8900/10000 updates, 5.51 s, -319.70 train_loss, -348.64 val_loss
# 9000/10000 updates, 5.33 s, -337.46 train_loss, -348.01 val_loss
# 9100/10000 updates, 5.37 s, -365.78 train_loss, -341.27 val_loss
# 9200/10000 updates, 5.70 s, -282.89 train_loss, -295.50 val_loss
# 9300/10000 updates, 5.68 s, -409.44 train_loss, -340.83 val_loss
# 9400/10000 updates, 5.38 s, -258.37 train_loss, -300.59 val_loss
# 9500/10000 updates, 5.18 s, -328.49 train_loss, -352.12 val_loss
# 9600/10000 updates, 6.05 s, -333.07 train_loss, -353.80 val_loss
# 9700/10000 updates, 6.42 s, -353.30 train_loss, -353.72 val_loss
# 9800/10000 updates, 5.73 s, -395.57 train_loss, -373.01 val_loss
# 9900/10000 updates, 6.24 s, -397.40 train_loss, -353.44 val_loss
# 0 / 2000
# 100 / 2000
# 200 / 2000
# 300 / 2000
# 400 / 2000
# 500 / 2000
# 600 / 2000
# 700 / 2000
# 800 / 2000
# 900 / 2000
# 1000 / 2000
# 1100 / 2000
# 1200 / 2000
# 1300 / 2000
# 1400 / 2000
# 1500 / 2000
# 1600 / 2000
# 1700 / 2000
# 1800 / 2000
# 1900 / 2000

# %%
print("RMSE: {:.3f}".format(RMSE_notmiwae))
# Out:
# RMSE: 0.138

# %%
x_notmiwae = np.load('x_notmiwae.npy')

# %%
x_obs = x_data[mask]
x_miss = x_data[~mask]

x_est = x_notmiwae

x_est_obs = x_est[mask]
x_est_miss = x_est[~mask]

# %%
scatter_compare_individual_entries_panel(x_obs, x_miss, x_est_obs, x_est_miss)

# %%
hist_compare_individual_entries(x_obs, x_miss, x_est_obs, x_est_miss)
